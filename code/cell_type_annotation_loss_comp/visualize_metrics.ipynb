# %%
# Import packages
from visualize_metrics import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %%
file = "results_and_visualizations/results_benchmark"
VisEnv.read_csv(file=file)

# %% [markdown]
# ### Cell type annotation benchmark

# %%
VisEnv.LossCompBoxPlotVisualization()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation_loss_comp\visualize_metrics.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1 CL + Centroid Loss"] = "Model1 | Centroid + CL Loss"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation_loss_comp\visualize_metrics.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1 CL Loss"] = "Model1 | CL Loss"
# ...

# %% [markdown]
# ### Latent space benchmark

# %%
files = ["Segerstolpe/Benchmark_representation_results",
         "MacParland/Benchmark_representation_results",
         "Baron/Benchmark_representation_results"]
dataset_names = ["Segerstolpe",
                 "MacParland",
                 "Baron"]
VisEnv.BoxPlotVisualization(files=files, dataset_names=dataset_names)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation_loss_comp\visualize_metrics.py:204: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1 CL + Centroid Loss"] = "Model1 | Centroid + CL Loss"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation_loss_comp\visualize_metrics.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1 CL Loss"] = "Model1 | CL Loss"
# ...
