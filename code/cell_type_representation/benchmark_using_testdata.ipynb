# %% [markdown]
# # Benchmark using [scIB](https://github.com/theislab/scib/tree/main)

# %% [markdown]
# Code to run all different models comes from [here](https://scib-metrics.readthedocs.io/en/stable/notebooks/lung_example.html).

# %%
# Load packages
import numpy as np
import pandas as pd
import scanpy as sc
import scib
import warnings
from benchmark_using_testdata import benchmark

warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=PendingDeprecationWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\MScEnv\lib\site-packages\tensorflow\python\framework\dtypes.py:35: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   from tensorflow.tsl.python.lib.core import pywrap_ml_dtypes

# %%
data_path = '../../data/processed/immune_cells/merged/Oetjen_merged.h5ad'
benchmark_env = benchmark(data_path=data_path, 
                          batch_key="patientID", 
                          HVG=True, 
                          HVGs=4000, 
                          Scaled=False,
                          seed=42,
                          folds=5)

# %% [markdown]
# ### Unintegrated

# %%
benchmark_env.unintegrated()
# Out:
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# cell cycle effect...
# Isolated labels F1...
# Compute neighbors on rep Unscaled
# Compute neighbors on rep Unscaled
# Compute neighbors on rep Unscaled
# Compute neighbors on rep Unscaled
# Compute neighbors on rep Unscaled
# Isolated labels ASW...
# Graph connectivity...

# %% [markdown]
# ### [Scanorama](https://github.com/brianhie/scanorama)

# %%
#benchmark_env.scanorama()

# %% [markdown]
# ### [Harmony](https://github.com/lilab-bcb/harmony-pytorch)

# %%
#benchmark_env.harmony()

# %% [markdown]
# ### [scVI](https://github.com/scverse/scvi-tools)

# %%
vae = benchmark_env.scvi()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\MScEnv\lib\site-packages\lightning\fabric\__init__.py:36: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning.fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   __import__("pkg_resources").declare_namespace(__name__)
# c:\Users\user\Documents\GitHub\Masters_Thesis\MScEnv\lib\site-packages\pkg_resources\__init__.py:2350: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(parent)
# ...

# %% [markdown]
# ### [scANVI](https://github.com/scverse/scvi-tools)

# %%
benchmark_env.scanvi(vae=vae)
# Out:
# INFO     Input AnnData not setup with scvi-tools. attempting to transfer AnnData setup
# INFO     Training for 20 epochs.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 20/20: 100%|██████████| 20/20 [01:08<00:00,  3.42s/it, v_num=1, train_loss_step=1.59e+3, train_loss_epoch=1.37e+3]
# `Trainer.fit` stopped: `max_epochs=20` reached.
# Epoch 20/20: 100%|██████████| 20/20 [01:08<00:00,  3.42s/it, v_num=1, train_loss_step=1.59e+3, train_loss_epoch=1.37e+3]
# INFO     Input AnnData not setup with scvi-tools. attempting to transfer AnnData setup
# c:\Users\user\Documents\GitHub\Masters_Thesis\MScEnv\lib\site-packages\scib\metrics\metrics.py:293: DeprecationWarning: Call to deprecated function (or staticmethod) opt_louvain.
#   res_max, nmi_max, nmi_all = opt_louvain(
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# ...

# %% [markdown]
# ### [scGen](https://github.com/theislab/scgen)

# %%
benchmark_env.scgen()
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Epoch 25/100:  25%|██▌       | 25/100 [00:43<02:10,  1.73s/it, v_num=1, train_loss_step=126, train_loss_epoch=133]
# Monitored metric elbo_validation did not improve in the last 10 records. Best score: 661.508. Signaling Trainer to stop.
# INFO     Input AnnData not setup with scvi-tools. attempting to transfer AnnData setup
# INFO     Input AnnData not setup with scvi-tools. attempting to transfer AnnData setup
# c:\Users\user\Documents\GitHub\Masters_Thesis\MScEnv\lib\site-packages\scib\metrics\metrics.py:293: DeprecationWarning: Call to deprecated function (or staticmethod) opt_louvain.
#   res_max, nmi_max, nmi_all = opt_louvain(
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# cell cycle effect...
# Isolated labels F1...
# Compute neighbors on rep scGen
# ...

# %% [markdown]
# ### [SAUCIE](https://github.com/KrishnaswamyLab/SAUCIE)

# %%
# Note: Pause for now. It requires a old version of tensorflow
# benchmark_env.saucie()

# %% [markdown]
# ### [ComBat](https://scanpy.readthedocs.io/en/stable/generated/scanpy.pp.combat.html)

# %%
#benchmark_env.combat()

# %% [markdown]
# ### [DESC](https://github.com/eleozzr/desc)

# %%
#benchmark_env.desc()

# %% [markdown]
# ### [trVAE](https://github.com/theislab/trvaep)

# %%
# Takes to much memory to run
# benchmark_env.trvae()

# %% [markdown]
# ### [FastMNN](https://github.com/chriscainx/mnnpy)

# %%
# Doesn't work great for some reason
#benchmark_env.fastmnn()

# %% [markdown]
# ### [BBKNN](https://github.com/Teichlab/bbknn)

# %%
#benchmark_env.bbknn()

# %% [markdown]
# ### [TOSICA](https://github.com/JackieHanLab/TOSICA/tree/main)

# %%
# Takes to much memory to run
#benchmark_env.tosica()

# %% [markdown]
# ### In-house model

# %%
benchmark_env.in_house_model(save_path='trained_models/cl_dummy_models2/')
# Out:
# Number of parameters: 11301200
# c:\Users\user\Documents\GitHub\Masters_Thesis\MScEnv\lib\site-packages\einops\_torch_specific.py:108: ImportWarning: allow_ops_in_compiled_graph failed to import torch: ensure pytorch >=2.0
#   warnings.warn("allow_ops_in_compiled_graph failed to import torch: ensure pytorch >=2.0", ImportWarning)
# Start Training
#   5%|▌         | 1/20 [01:34<29:50, 94.24s/it]
# Epoch 1 | Training loss: 0.0988 | Validation loss: 0.0997
#  25%|██▌       | 5/20 [06:25<20:16, 81.12s/it]
# Epoch 5 | Training loss: 0.0671 | Validation loss: 0.0642
#  45%|████▌     | 9/20 [10:46<13:23, 73.06s/it]
# Epoch 9 | Training loss: 0.0570 | Validation loss: 0.0557
#  65%|██████▌   | 13/20 [15:37<09:03, 77.70s/it]
# Epoch 13 | Training loss: 0.0545 | Validation loss: 0.0549
#  85%|████████▌ | 17/20 [19:49<03:27, 69.12s/it]
# Epoch 17 | Training loss: 0.0599 | Validation loss: 0.0565
# 100%|██████████| 20/20 [23:32<00:00, 70.60s/it]
# ...

# %% [markdown]
# ### Make dataframe and visualize

# %%
# Load csv dataframe if we want to merge old runs with the new one (saved in benchmark_env.metrics)
benchmark_env.read_csv(name="Benchmark_using_testdata_results")

# %%
benchmark_env.make_benchamrk_results_dataframe()

# %%
benchmark_env.visualize_results()
# Out:
# <style type="text/css">
# #T_f52f9_row0_col0, #T_f52f9_row0_col3, #T_f52f9_row0_col4, #T_f52f9_row0_col5, #T_f52f9_row0_col6, #T_f52f9_row0_col8, #T_f52f9_row0_col10, #T_f52f9_row0_col11, #T_f52f9_row2_col2, #T_f52f9_row2_col9, #T_f52f9_row4_col1, #T_f52f9_row4_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f52f9_row0_col1, #T_f52f9_row0_col7, #T_f52f9_row4_col0, #T_f52f9_row4_col2, #T_f52f9_row4_col3, #T_f52f9_row4_col4, #T_f52f9_row4_col5, #T_f52f9_row4_col6, #T_f52f9_row4_col8, #T_f52f9_row4_col9, #T_f52f9_row4_col10, #T_f52f9_row4_col11 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f52f9_row0_col2, #T_f52f9_row0_col9 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_f52f9_row1_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_f52f9_row1_col1 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_f52f9_row1_col2, #T_f52f9_row3_col10 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# ...

# %%
benchmark_env.save_results_as_csv(name="Benchmark_using_testdata_results")
