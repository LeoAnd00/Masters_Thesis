# %%
# Import packages
from functions.Attention_visualization_functions import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %% [markdown]
# ### Calculate the averaged attention matrix for each cell type

# %%
VisEnv.MakeAttentionMatrix(train_path="../../../data/processed/immune_cells/merged/Oetjen_merged.h5ad",
                           pred_path="../../../data/processed/immune_cells/merged/Oetjen_merged.h5ad",
                           gene2vec_path="../../../data/raw/gene2vec_embeddings/gene2vec_dim_200_iter_9_w2v.txt",
                           model_path="../trained_models/Bone_marrow/Tokenized_HVG_Transformer/seed_42_model",
                           target_key="cell_type",
                           batch_key="patientID",
                           HVGs=2000,
                           HVG_buckets_=1000,
                           batch_size=1)
# Out:
# cuda
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 VisEnv.MakeAttentionMatrix(train_path="../../../data/processed/immune_cells/merged/Oetjen_merged.h5ad",
#       2                            pred_path="../../../data/processed/immune_cells/merged/Oetjen_merged.h5ad",
#       3                            gene2vec_path="../../../data/raw/gene2vec_embeddings/gene2vec_dim_200_iter_9_w2v.txt",
#       4                            model_path="../trained_models/Bone_marrow/Tokenized_HVG_Transformer/seed_42_model",
#       5                            target_key="cell_type",
#       6                            batch_key="patientID",
#       7                            HVGs=2000,
#       8                            HVG_buckets_=1000,
#       9                            batch_size=1)
#
# ...

# %%
VisEnv.GetCellTypeNames()
# Out:
# ['Effector CD4+ T cells', 'Platelets', 'Non-classical monocytes', 'Pro-B cells', 'Natural killer  cells', 'Basophils', 'Progenitor cells', 'Memory CD4+ T cells', 'Neutrophils', 'Naive B cells', 'Myeloid Dendritic cells', 'CD4+ NKT-like cells', 'Classical Monocytes', 'γδ-T cells', 'Plasmacytoid Dendritic cells', 'Erythroid-like and erythroid precursor cells', 'Naive CD4+ T cells', 'Naive CD8+ T cells', 'Memory CD8+ T cells', 'CD8+ NKT-like cells']

# %% [markdown]
# ### Visualize results

# %%
VisEnv.HeatMapVisualization(cell_type="Classical Monocytes", num_of_top_genes=50)
