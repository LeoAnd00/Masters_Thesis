# %%
# Import packages
from functions.metrics_visualization_functions2 import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %% [markdown]
# ### All datasets
# ### Box plot

# %%
files = ["../benchmarks/results/Bone_marrow/Benchmark_results",
         "../benchmarks/results/PBMC/Benchmark_results",
         "../benchmarks/results/Kidney/Benchmark_results",
         "../benchmarks/results/Pancreas/Benchmark_results",
         "../benchmarks/results/All_merged/Benchmark_results"]
dataset_names = ["Bone Marrow Dataset",
                 "PBMC Dataset",
                 "Kidney Dataset",
                 "Pancreas Dataset",
                 "Merged Dataset"]
VisEnv.BoxPlotVisualization(files=files, dataset_names=dataset_names)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:492: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model1_no_val"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:493: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1_val"] = "Model1"
# ...

# %%
files = ["../benchmarks/results/Bone_marrow/Benchmark_results",
         "../benchmarks/results/PBMC/Benchmark_results",
         "../benchmarks/results/Kidney/Benchmark_results",
         "../benchmarks/results/Pancreas/Benchmark_results",
         "../benchmarks/results/All_merged/Benchmark_results"]
dataset_names = ["Bone Marrow Dataset",
                 "PBMC Dataset",
                 "Kidney Dataset",
                 "Pancreas Dataset",
                 "Merged Dataset"]
VisEnv.BoxPlotVisualization_All(files=files, dataset_names=dataset_names)

# %% [markdown]
# ## Bone marrow

# %% [markdown]
# ### Read benchmark files

# %%
directory_path = ["../benchmarks/results/Bone_marrow/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %% [markdown]
# ### Visualize with table

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# #T_431e3_row0_col1, #T_431e3_row4_col21 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_431e3_row0_col2 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_431e3_row0_col3 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_431e3_row0_col4, #T_431e3_row0_col19 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_431e3_row0_col5 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_431e3_row0_col6 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ### Barplot visualization

# %%
image_path = "figures/Generalizability_bone_marrow_metrics"
VisEnv.BarPlotVisualization(image_path=image_path, version=1, dataset_name="Bone Marrow Dataset")
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model 1"

# %%
image_path = "figures/Generalizability_bone_marrow_metrics_appendix"
VisEnv.BarPlotVisualization_Appendix(image_path=image_path, version=1)

# %%
#image_path = "figures/Bone_marrow_metrics_v2"
#VisEnv.BarPlotVisualization(image_path=image_path, version=2)

# %% [markdown]
# ## PBMC

# %%
directory_path = ["../benchmarks/results/PBMC/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# ...

# %%
image_path = "figures/Generalizability_pbmc_metrics"
VisEnv.BarPlotVisualization(image_path=image_path, version=1, dataset_name="PBMC Dataset")
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model 1"

# %%
image_path = "figures/Generalizability_pbmc_metrics_appendix"
VisEnv.BarPlotVisualization_Appendix(image_path=image_path, version=1)

# %% [markdown]
# ## Kidney

# %%
directory_path = ["../benchmarks/results/Kidney/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# #T_c672a_row0_col1, #T_c672a_row0_col7, #T_c672a_row0_col9, #T_c672a_row0_col11, #T_c672a_row0_col13, #T_c672a_row0_col17, #T_c672a_row0_col23, #T_c672a_row1_col6, #T_c672a_row1_col18, #T_c672a_row1_col21, #T_c672a_row4_col5, #T_c672a_row4_col12, #T_c672a_row4_col19, #T_c672a_row5_col2, #T_c672a_row5_col4, #T_c672a_row5_col8, #T_c672a_row5_col10, #T_c672a_row5_col14, #T_c672a_row5_col16, #T_c672a_row5_col20, #T_c672a_row5_col22, #T_c672a_row5_col24, #T_c672a_row6_col3, #T_c672a_row6_col15 {
# ...

# %%
image_path = "figures/Generalizability_kidney_metrics"
VisEnv.BarPlotVisualization(image_path=image_path, version=1, dataset_name="Kidney Dataset")
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model 1"

# %%
image_path = "figures/Generalizability_kidney_metrics_appendix"
VisEnv.BarPlotVisualization_Appendix(image_path=image_path, version=1)

# %% [markdown]
# ## Pancreas

# %%
directory_path = ["../benchmarks/results/Pancreas/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# ...

# %%
image_path = "figures/Generalizability_pancreas_metrics"
VisEnv.BarPlotVisualization(image_path=image_path, version=1, dataset_name="Pancreas Dataset")
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model 1"

# %%
image_path = "figures/Generalizability_pancreas_metrics_appendix"
VisEnv.BarPlotVisualization_Appendix(image_path=image_path, version=1)

# %% [markdown]
# ## All merged

# %%
directory_path = ["../benchmarks/results/All_merged/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:423: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# #T_bb3c6_row0_col1, #T_bb3c6_row0_col4, #T_bb3c6_row0_col6, #T_bb3c6_row0_col7, #T_bb3c6_row0_col12, #T_bb3c6_row0_col14, #T_bb3c6_row0_col17, #T_bb3c6_row0_col18, #T_bb3c6_row0_col21, #T_bb3c6_row0_col23, #T_bb3c6_row1_col2, #T_bb3c6_row1_col8, #T_bb3c6_row1_col11, #T_bb3c6_row1_col13, #T_bb3c6_row2_col9, #T_bb3c6_row2_col19, #T_bb3c6_row3_col5, #T_bb3c6_row3_col15, #T_bb3c6_row3_col19, #T_bb3c6_row4_col10, #T_bb3c6_row4_col16, #T_bb3c6_row4_col20, #T_bb3c6_row4_col22, #T_bb3c6_row4_col24, #T_bb3c6_row6_col3 {
# ...

# %%
image_path = "figures/Generalizability_all_merged_metrics"
VisEnv.BarPlotVisualization(image_path=image_path, version=1, dataset_name="Merged Dataset")
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model 1"

# %%
image_path = "figures/Generalizability_all_merged_metrics_appendix"
VisEnv.BarPlotVisualization_Appendix(image_path=image_path, version=1)
