# %%
# Import packages
from functions.metrics_visualization_functions2 import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %% [markdown]
# ### All datasets
# ### Box plot

# %%
files = ["../benchmarks/results/Bone_marrow/Benchmark_results",
         "../benchmarks/results/PBMC/Benchmark_results",
         "../benchmarks/results/Kidney/Benchmark_results",
         "../benchmarks/results/Pancreas/Benchmark_results",
         "../benchmarks/results/All_merged/Benchmark_results"]
dataset_names = ["Bone Marrow Dataset",
                 "PBMC Dataset",
                 "Kidney Dataset",
                 "Pancreas Dataset",
                 "Merged Dataset"]
image_path = "figures/Overall_metrics"
VisEnv.BoxPlotVisualization(files=files, dataset_names=dataset_names, image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:594: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model2_val"] = "Model2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:595: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model3_val"] = "Model3"

# %%
files = ["../benchmarks/results/Bone_marrow/Benchmark_results",
         "../benchmarks/results/PBMC/Benchmark_results",
         "../benchmarks/results/Kidney/Benchmark_results",
         "../benchmarks/results/Pancreas/Benchmark_results",
         "../benchmarks/results/All_merged/Benchmark_results"]
dataset_names = ["Bone Marrow Dataset",
                 "PBMC Dataset",
                 "Kidney Dataset",
                 "Pancreas Dataset",
                 "Merged Dataset"]
VisEnv.BoxPlotVisualization_All(files=files, dataset_names=dataset_names)

# %% [markdown]
# ## Bone marrow

# %% [markdown]
# ### Read benchmark files

# %%
directory_path = ["../benchmarks/results/Bone_marrow/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %% [markdown]
# ### Visualize with table

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:689: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# #T_5caff_row0_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_5caff_row0_col2, #T_5caff_row6_col15 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_5caff_row0_col3, #T_5caff_row8_col20 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# ...

# %% [markdown]
# ### Barplot visualization

# %%
image_path = "figures/Bone_marrow_metrics_appendix"
VisEnv.BoxPlotVisualization_Appendix(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model2_val"] = "Model2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model3_val"] = "Model3"

# %% [markdown]
# ## PBMC

# %%
directory_path = ["../benchmarks/results/PBMC/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:705: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# #T_c9828_row0_col1, #T_c9828_row2_col7 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_c9828_row0_col2, #T_c9828_row3_col9 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_c9828_row0_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_c9828_row0_col4 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_c9828_row0_col5, #T_c9828_row3_col12 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_c9828_row0_col6, #T_c9828_row9_col7 {
# ...

# %%
image_path = "figures/PBMC_metrics_appendix"
VisEnv.BoxPlotVisualization_Appendix(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model2_val"] = "Model2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model3_val"] = "Model3"

# %% [markdown]
# ## Kidney

# %%
directory_path = ["../benchmarks/results/Kidney/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:705: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# #T_3a482_row0_col1 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_3a482_row0_col2, #T_3a482_row2_col19, #T_3a482_row4_col5 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_3a482_row0_col3, #T_3a482_row7_col21 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_3a482_row0_col4 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_3a482_row0_col5, #T_3a482_row1_col6 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# ...

# %%
image_path = "figures/Kidney_metrics_appendix"
VisEnv.BoxPlotVisualization_Appendix(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model2_val"] = "Model2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model3_val"] = "Model3"

# %% [markdown]
# ## Pancreas

# %%
directory_path = ["../benchmarks/results/Pancreas/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:705: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# #T_97f19_row0_col1, #T_97f19_row0_col7, #T_97f19_row6_col3 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_97f19_row0_col2, #T_97f19_row3_col14 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_97f19_row0_col3, #T_97f19_row3_col11 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_97f19_row0_col4 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_97f19_row0_col5 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# ...

# %%
image_path = "figures/Pancreas_metrics_appendix"
VisEnv.BoxPlotVisualization_Appendix(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model2_val"] = "Model2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model3_val"] = "Model3"

# %% [markdown]
# ## All merged

# %%
directory_path = ["../benchmarks/results/All_merged/Benchmark_results"]
VisEnv.read_csv(files=directory_path)

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:705: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "Model1"] = "Model 1"
# <style type="text/css">
# #T_de662_row0_col1, #T_de662_row0_col6, #T_de662_row0_col7, #T_de662_row0_col12, #T_de662_row0_col17, #T_de662_row0_col23, #T_de662_row1_col8, #T_de662_row1_col11, #T_de662_row1_col13, #T_de662_row1_col21, #T_de662_row2_col2, #T_de662_row2_col16, #T_de662_row2_col18, #T_de662_row3_col9, #T_de662_row3_col19, #T_de662_row5_col5, #T_de662_row5_col15, #T_de662_row5_col19, #T_de662_row5_col20, #T_de662_row6_col4, #T_de662_row6_col10, #T_de662_row6_col14, #T_de662_row6_col22, #T_de662_row6_col24, #T_de662_row8_col3 {
# ...

# %%
image_path = "figures/Merged_metrics_appendix"
VisEnv.BoxPlotVisualization_Appendix(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model2_val"] = "Model2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions2.py:442: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model3_val"] = "Model3"
