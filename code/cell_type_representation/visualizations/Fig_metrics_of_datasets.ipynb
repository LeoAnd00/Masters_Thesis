# %%
# Import packages
from functions.metrics_visualization_functions import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %% [markdown]
# ## Bone marrow

# %% [markdown]
# ### Read benchmark files

# %%
directory_path = "../benchmarks/results/Bone_marrow/"
files = []
seeds = [42,43,44,45,46]
for seed in seeds:
    path = directory_path + f"benchmark_2000_HVGs_seed_{seed}"
    files.append(path)
VisEnv.read_csv(files=files)

# %% [markdown]
# ### Visualize with table

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house HVG Encoder Model"] = "Model 1"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder Model"] = "Model 2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder with HVG Encoder"] = "Model 3"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder with Pathways Model"] = "Model 4"
# <style type="text/css">
# #T_b19ca_row0_col1 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_b19ca_row0_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_b19ca_row0_col3, #T_b19ca_row9_col3 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_b19ca_row0_col4 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_b19ca_row0_col5, #T_b19ca_row1_col5, #T_b19ca_row4_col21, #T_b19ca_row5_col23 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_b19ca_row0_col6, #T_b19ca_row3_col8 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_b19ca_row0_col7 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_b19ca_row0_col8, #T_b19ca_row0_col10, #T_b19ca_row1_col16, #T_b19ca_row3_col18, #T_b19ca_row5_col4, #T_b19ca_row5_col12, #T_b19ca_row5_col22, #T_b19ca_row5_col24, #T_b19ca_row6_col2, #T_b19ca_row6_col6, #T_b19ca_row6_col14, #T_b19ca_row6_col15, #T_b19ca_row6_col20, #T_b19ca_row9_col5, #T_b19ca_row10_col1, #T_b19ca_row10_col9, #T_b19ca_row10_col11, #T_b19ca_row10_col13, #T_b19ca_row10_col17, #T_b19ca_row10_col21, #T_b19ca_row11_col5, #T_b19ca_row12_col3, #T_b19ca_row12_col7, #T_b19ca_row12_col19, #T_b19ca_row12_col23 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b19ca_row0_col9, #T_b19ca_row0_col11, #T_b19ca_row0_col13, #T_b19ca_row0_col17, #T_b19ca_row0_col21, #T_b19ca_row0_col23, #T_b19ca_row1_col9, #T_b19ca_row1_col11, #T_b19ca_row2_col1, #T_b19ca_row2_col2, #T_b19ca_row2_col7, #T_b19ca_row2_col8, #T_b19ca_row2_col10, #T_b19ca_row2_col12, #T_b19ca_row2_col14, #T_b19ca_row2_col18, #T_b19ca_row2_col22, #T_b19ca_row2_col24, #T_b19ca_row3_col4, #T_b19ca_row4_col6, #T_b19ca_row4_col16, #T_b19ca_row4_col20, #T_b19ca_row6_col19, #T_b19ca_row8_col15, #T_b19ca_row10_col5, #T_b19ca_row11_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b19ca_row0_col12, #T_b19ca_row8_col7 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_b19ca_row0_col14, #T_b19ca_row6_col21, #T_b19ca_row7_col7 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_b19ca_row0_col15 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_b19ca_row0_col16 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_b19ca_row0_col18 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_b19ca_row0_col19 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_b19ca_row0_col20, #T_b19ca_row5_col2, #T_b19ca_row6_col12, #T_b19ca_row12_col17 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b19ca_row0_col22 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_b19ca_row0_col24, #T_b19ca_row11_col7 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_b19ca_row1_col1 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_b19ca_row1_col2, #T_b19ca_row1_col4, #T_b19ca_row4_col1, #T_b19ca_row8_col13 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_b19ca_row1_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_b19ca_row1_col6, #T_b19ca_row2_col16 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_b19ca_row1_col7 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_b19ca_row1_col8, #T_b19ca_row11_col19 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_b19ca_row1_col10, #T_b19ca_row5_col8 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_b19ca_row1_col12 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_b19ca_row1_col13, #T_b19ca_row10_col3 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_b19ca_row1_col14, #T_b19ca_row3_col15 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_b19ca_row1_col15 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_b19ca_row1_col17, #T_b19ca_row7_col15, #T_b19ca_row9_col15 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_b19ca_row1_col18 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_b19ca_row1_col19, #T_b19ca_row3_col3 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_b19ca_row1_col20 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_b19ca_row1_col21, #T_b19ca_row1_col23 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_b19ca_row1_col22, #T_b19ca_row12_col13 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_b19ca_row1_col24, #T_b19ca_row3_col20 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_b19ca_row2_col3, #T_b19ca_row6_col18, #T_b19ca_row7_col5 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col4 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col5, #T_b19ca_row5_col13 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_b19ca_row2_col6, #T_b19ca_row4_col23 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col9, #T_b19ca_row2_col11 {
#   background-color: #083573;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col13 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col15 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col17, #T_b19ca_row6_col9 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col19, #T_b19ca_row4_col17, #T_b19ca_row5_col5 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col20 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col21 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_b19ca_row2_col23 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col2, #T_b19ca_row6_col10 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_b19ca_row3_col5, #T_b19ca_row4_col5 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_b19ca_row3_col7 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col9 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col10 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_b19ca_row3_col11 {
#   background-color: #08488e;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col12, #T_b19ca_row11_col11 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_b19ca_row3_col13 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col14, #T_b19ca_row12_col5 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col16, #T_b19ca_row8_col1 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b19ca_row3_col17, #T_b19ca_row4_col9 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col19, #T_b19ca_row5_col17 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col21 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col22, #T_b19ca_row6_col17 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_b19ca_row3_col23, #T_b19ca_row8_col9 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_b19ca_row3_col24, #T_b19ca_row4_col14, #T_b19ca_row9_col17 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_b19ca_row4_col2, #T_b19ca_row9_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_b19ca_row4_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_b19ca_row4_col4 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_b19ca_row4_col7, #T_b19ca_row6_col13 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_b19ca_row4_col8, #T_b19ca_row5_col14, #T_b19ca_row10_col23 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_b19ca_row4_col10, #T_b19ca_row8_col23 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_b19ca_row4_col11 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_b19ca_row4_col12 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_b19ca_row4_col13, #T_b19ca_row8_col11, #T_b19ca_row12_col9 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_b19ca_row4_col15 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_b19ca_row4_col18 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_b19ca_row4_col19 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_b19ca_row4_col22 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_b19ca_row4_col24, #T_b19ca_row6_col1 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_b19ca_row5_col1 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_b19ca_row5_col3 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_b19ca_row5_col6 {
#   background-color: #87bddc;
#   color: #0000

# %% [markdown]
# ### Barplot visualization

# %%
image_path = "figures/Bone_marrow_metrics_v1"
VisEnv.BarPlotVisualization(image_path=image_path, version=1)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house HVG Encoder Model"] = "Model 1"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder Model"] = "Model 2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder with HVG Encoder"] = "Model 3"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder with Pathways Model"] = "Model 4"

# %%
#image_path = "figures/Bone_marrow_metrics_v2"
#VisEnv.BarPlotVisualization(image_path=image_path, version=2)

# %% [markdown]
# ## PBMC

# %%
directory_path = "../benchmarks/results/PBMC/"
files = []
seeds = [42,43,44,45,46]
for seed in seeds:
    path = directory_path + f"benchmark_2000_HVGs_seed_{seed}"
    files.append(path)
VisEnv.read_csv(files=files)

# %%
VisEnv.visualize_results()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house HVG Encoder Model"] = "Model 1"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder Model"] = "Model 2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:154: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder with HVG Encoder"] = "Model 3"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:155: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder with Pathways Model"] = "Model 4"
# <style type="text/css">
# #T_3489e_row0_col1, #T_3489e_row4_col3 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_3489e_row0_col2 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_3489e_row0_col3 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_3489e_row0_col4, #T_3489e_row1_col5, #T_3489e_row6_col15 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_3489e_row0_col5 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_3489e_row0_col6, #T_3489e_row11_col13 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_3489e_row0_col7 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_3489e_row0_col8, #T_3489e_row4_col14 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_3489e_row0_col9, #T_3489e_row0_col11, #T_3489e_row0_col13, #T_3489e_row0_col17, #T_3489e_row0_col21, #T_3489e_row0_col23, #T_3489e_row1_col9, #T_3489e_row1_col11, #T_3489e_row1_col13, #T_3489e_row1_col17, #T_3489e_row2_col1, #T_3489e_row2_col4, #T_3489e_row2_col7, #T_3489e_row2_col9, #T_3489e_row2_col21, #T_3489e_row3_col2, #T_3489e_row3_col6, #T_3489e_row3_col9, #T_3489e_row3_col12, #T_3489e_row3_col14, #T_3489e_row3_col16, #T_3489e_row3_col17, #T_3489e_row3_col20, #T_3489e_row3_col22, #T_3489e_row3_col24, #T_3489e_row4_col8, #T_3489e_row4_col10, #T_3489e_row4_col18, #T_3489e_row6_col3, #T_3489e_row6_col5, #T_3489e_row8_col19, #T_3489e_row10_col15 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_3489e_row0_col10, #T_3489e_row0_col12, #T_3489e_row0_col14, #T_3489e_row0_col18, #T_3489e_row1_col10, #T_3489e_row1_col14, #T_3489e_row1_col18, #T_3489e_row1_col22, #T_3489e_row3_col18, #T_3489e_row5_col24, #T_3489e_row6_col7, #T_3489e_row8_col2, #T_3489e_row8_col4, #T_3489e_row8_col6, #T_3489e_row8_col8, #T_3489e_row8_col15, #T_3489e_row8_col16, #T_3489e_row8_col20, #T_3489e_row8_col21, #T_3489e_row8_col24, #T_3489e_row10_col1, #T_3489e_row10_col3, #T_3489e_row10_col9, #T_3489e_row10_col17, #T_3489e_row11_col5, #T_3489e_row12_col5, #T_3489e_row12_col11, #T_3489e_row12_col13, #T_3489e_row12_col19, #T_3489e_row12_col23 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_3489e_row0_col15, #T_3489e_row1_col7, #T_3489e_row2_col11, #T_3489e_row3_col11 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_3489e_row0_col16 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_3489e_row0_col19, #T_3489e_row3_col21 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_3489e_row0_col20, #T_3489e_row8_col14, #T_3489e_row12_col7 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_3489e_row0_col22, #T_3489e_row7_col7 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_3489e_row0_col24, #T_3489e_row1_col16, #T_3489e_row6_col21 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_3489e_row1_col1, #T_3489e_row2_col15, #T_3489e_row3_col23, #T_3489e_row8_col3, #T_3489e_row8_col9 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_3489e_row1_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_3489e_row1_col3 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_3489e_row1_col4, #T_3489e_row8_col17 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_3489e_row1_col6, #T_3489e_row12_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_3489e_row1_col8 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_3489e_row1_col12, #T_3489e_row2_col10, #T_3489e_row11_col11 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_3489e_row1_col15 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_3489e_row1_col19 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_3489e_row1_col20, #T_3489e_row5_col22 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_3489e_row1_col21, #T_3489e_row1_col23 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_3489e_row1_col24, #T_3489e_row10_col11 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_3489e_row2_col2 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col3, #T_3489e_row5_col11 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_3489e_row2_col5, #T_3489e_row5_col5, #T_3489e_row9_col19, #T_3489e_row12_col15 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col6 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_3489e_row2_col8 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col12 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col13, #T_3489e_row9_col3 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col14 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col16 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_3489e_row2_col17 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col18 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_3489e_row2_col19, #T_3489e_row4_col19, #T_3489e_row7_col9 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col20, #T_3489e_row5_col13 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col22, #T_3489e_row4_col24 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_3489e_row2_col23 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_3489e_row2_col24 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_3489e_row3_col1, #T_3489e_row5_col23 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_3489e_row3_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_3489e_row3_col4 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_3489e_row3_col5 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_3489e_row3_col7, #T_3489e_row3_col13 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_3489e_row3_col8 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_3489e_row3_col10 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_3489e_row3_col15 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_3489e_row3_col19 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_3489e_row4_col1, #T_3489e_row4_col4 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_3489e_row4_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_3489e_row4_col5 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_3489e_row4_col6 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_3489e_row4_col7 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_3489e_row4_col9, #T_3489e_row4_col20 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_3489e_row4_col11 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_3489e_row4_col12 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_3489e_row4_col13 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_3489e_row4_col15 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# #T_3489e_row4_col16, #T_3489e_row10_col7 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_3489e_row4_col17 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_3489e_row4_col21, #T_3489e_row12_col9 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_3489e_row4_col22, #T_3489e_row5_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_3489e_row4_col23 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_3489e_row5_col1 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_3489e_row5_col3 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_3489e_row5_col4, #T_3489e_row9_col17 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_3489e_row5_col6, #T_3489e_row8_col7 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_3489e_row5_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_3489e_row5_col8, #T_3489e_row8_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_3489e_row5_col9, #T_3489e_row6_col19 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_3489e_row5_col10, #T_3489e_row8_col18 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_3489e_row5_col12, #T_3489e_row10_col13 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_3489e_row5_col14 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_3489e_row5_col15 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_3489e_row5_col16 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_3489e_row5_col17 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_3489e_row5_col18, #T_3489e_row11

# %%
image_path = "figures/PBMC_metrics_v1"
VisEnv.BarPlotVisualization(image_path=image_path, version=1)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house HVG Encoder Model"] = "Model 1"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder Model"] = "Model 2"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder with HVG Encoder"] = "Model 3"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_representation\visualizations\functions\metrics_visualization_functions.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Model Type'][metrics['Model Type'] == "In-house Tokenized HVG Transformer Encoder with Pathways Model"] = "Model 4"

# %% [markdown]
# ## Kidney

# %%
"""directory_path = "../benchmarks/results/Kidney/"
files = []
seeds = [42,43,44,45,46]
for seed in seeds:
    path = directory_path + f"benchmark_2000_HVGs_seed_{seed}"
    files.append(path)
VisEnv.read_csv(files=files)"""
# Out:
# 'directory_path = "../benchmarks/results/Kidney/"\nfiles = []\nseeds = [42,43,44,45,46]\nfor seed in seeds:\n    path = directory_path + f"benchmark_2000_HVGs_seed_{seed}"\n    files.append(path)\nVisEnv.read_csv(files=files)'

# %%
#VisEnv.visualize_results()

# %%
#image_path = "figures/Kidney_metrics_v1"
#VisEnv.BarPlotVisualization(image_path=image_path, version=1)

# %% [markdown]
# ## Pancreas

# %%
"""directory_path = "../benchmarks/results/Pancreas/"
files = []
seeds = [42,43,44,45,46]
for seed in seeds:
    path = directory_path + f"benchmark_2000_HVGs_seed_{seed}"
    files.append(path)
VisEnv.read_csv(files=files)"""
# Out:
# 'directory_path = "../benchmarks/results/Pancreas/"\nfiles = []\nseeds = [42,43,44,45,46]\nfor seed in seeds:\n    path = directory_path + f"benchmark_2000_HVGs_seed_{seed}"\n    files.append(path)\nVisEnv.read_csv(files=files)'

# %%
#VisEnv.visualize_results()

# %%
#image_path = "figures/Pancreas_metrics_v1"
#VisEnv.BarPlotVisualization(image_path=image_path, version=1)

# %% [markdown]
# ## All merged

# %%
"""directory_path = "../benchmarks/results/All_merged/"
files = []
seeds = [42,43,44,45,46]
for seed in seeds:
    path = directory_path + f"benchmark_2000_HVGs_seed_{seed}"
    files.append(path)
VisEnv.read_csv(files=files)"""
# Out:
# 'directory_path = "../benchmarks/results/All_merged/"\nfiles = []\nseeds = [42,43,44,45,46]\nfor seed in seeds:\n    path = directory_path + f"benchmark_2000_HVGs_seed_{seed}"\n    files.append(path)\nVisEnv.read_csv(files=files)'

# %%
#VisEnv.visualize_results()

# %%
#image_path = "figures/All_merged_metrics_v1"
#VisEnv.BarPlotVisualization(image_path=image_path, version=1)
