# %%
# Import packages
from functions.metrics_visualization_functions import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %% [markdown]
# ### Read benchmark files

# %%
files = ["../benchmarks/results/Bone_marrow/Benchmark_results",
         "../benchmarks/results/Bone_marrow/Benchmark_results_check_repoducibility"]

VisEnv.read_csv(files=files)

# %% [markdown]
# ### Visualize with table

# %%
VisEnv.visualize_results()
# Out:
# <style type="text/css">
# #T_71de0_row0_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_71de0_row0_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_71de0_row0_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_71de0_row0_col4 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_71de0_row0_col5 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_71de0_row0_col6 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_71de0_row0_col7, #T_71de0_row0_col9, #T_71de0_row0_col12, #T_71de0_row0_col23, #T_71de0_row1_col1, #T_71de0_row1_col2, #T_71de0_row1_col4, #T_71de0_row1_col6, #T_71de0_row1_col11, #T_71de0_row1_col13, #T_71de0_row1_col16, #T_71de0_row1_col17, #T_71de0_row1_col20, #T_71de0_row1_col21, #T_71de0_row2_col8, #T_71de0_row2_col10, #T_71de0_row2_col14, #T_71de0_row2_col18, #T_71de0_row2_col19, #T_71de0_row2_col22, #T_71de0_row2_col24, #T_71de0_row5_col3, #T_71de0_row6_col5, #T_71de0_row9_col15 {
# ...

# %% [markdown]
# ### Barplot visualization

# %%
image_path = "figures/Bone_marrow_metrics_v1"
VisEnv.BarPlotVisualization(image_path=image_path, version=1)

# %%
image_path = "figures/Bone_marrow_metrics_v2"
VisEnv.BarPlotVisualization(image_path=image_path, version=2)
