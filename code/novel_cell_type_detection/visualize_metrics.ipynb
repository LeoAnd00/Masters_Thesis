# %%
# Import packages
from visualize_metrics import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %%
file = "results_and_visualizations/results_benchmark"
VisEnv.read_csv(file=file)

# %% [markdown]
# ### All datasets

# %%
VisEnv.BoxPlotVisualization()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\novel_cell_type_detection\visualize_metrics.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model1_HVGs"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\novel_cell_type_detection\visualize_metrics.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "TOSICA"] = "TOSICA_HVGs"
