# %% [markdown]
# ## scNym: https://github.com/calico/scnym

# %%
import scnym
from scnym.api import scnym_api
import torch
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import scanpy as sc
# Out:
# WARNING:tensorflow:From c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def split_data(data_path: str, 
               fold: int=1,
               folds: int=5,
               batch_key: str="patientID", 
               label_key: str="cell_type",
               seed: int=42,
               HVG: bool=True,
               HVGs: int=2000):
    
    adata = sc.read(data_path, cache=True)

    adata.obs["batch"] = adata.obs[batch_key]

    # Ensure reproducibility
    def rep_seed(seed):
        # Check if a GPU is available
        if torch.cuda.is_available():
            # Set the random seed for PyTorch CUDA (GPU) operations
            torch.cuda.manual_seed(seed)
            # Set the random seed for all CUDA devices (if multiple GPUs are available)
            torch.cuda.manual_seed_all(seed)
        
        # Set the random seed for CPU-based PyTorch operations
        torch.manual_seed(seed)
        
        # Set the random seed for NumPy
        np.random.seed(seed)
        
        # Set the random seed for Python's built-in 'random' module
        random.seed(seed)
        
        # Set the random seed for TensorFlow
        tf.random.set_seed(seed)
        
        # Set CuDNN to deterministic mode for PyTorch (GPU)
        torch.backends.cudnn.deterministic = True
        
        # Disable CuDNN's benchmarking mode for deterministic behavior
        torch.backends.cudnn.benchmark = False

    rep_seed(seed)

    # Initialize Stratified K-Fold
    stratified_kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)

    # Iterate through the folds
    adata_original = adata.copy()
    test_adata_original = adata.copy()
    fold_counter = 0
    for train_index, test_index in stratified_kfold.split(adata_original.X, adata_original.obs[label_key]):
        fold_counter += 1
        
        adata = adata_original[train_index, :].copy()
        test_adata = test_adata_original[test_index, :].copy()

        if HVG:
            sc.pp.highly_variable_genes(adata, n_top_genes=HVGs, flavor="cell_ranger")
            test_adata = test_adata[:, adata.var["highly_variable"]].copy()
            adata = adata[:, adata.var["highly_variable"]].copy()

        # Define cell types to exclude
        exclude_cell_types = ['Mature_B_Cells', 
                            'Plasma_Cells', 
                            'alpha-beta_T_Cells', 
                            'gamma-delta_T_Cells_1', 
                            'gamma-delta_T_Cells_2']

        # Create a boolean mask to select cells that are not in the exclude list
        mask = ~adata.obs['cell_type'].isin(exclude_cell_types)

        # Apply the mask to AnnData object
        adata = adata[mask]
        
        if fold_counter == fold:
            
            return adata, test_adata

# %%
data_path = "../../../data/processed/data_for_evaluating_cell_type_annotation/MacParland.h5ad"

# Iterate through folds
results = None
for fold_idx in range(5):
    fold = fold_idx + 1

    adata_train, adata_test = split_data(data_path=data_path, fold=fold)

    # Train model
    scnym_api(
        adata=adata_train,
        task='train',
        groupby='cell_type',
        out_path='./scnym_outputs',
        config='no_new_identity',
    )

    # Predict test data
    scnym_api(
        adata=adata_test,
        task='predict',
        key_added='scNym',
        config='no_new_identity',
        trained_model='./scnym_outputs'
    )

    # Define cell as Novel if the confidence is below 0.5
    max_scores = adata_test.obs['scNym_confidence']
    for i, max_score in enumerate(max_scores):
        if max_score < 0.5:
            adata_test.obs['scNym'].iloc[i] = "Novel"

    # Save results in dataframe
    if fold == 1:
        results = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                "true_label": adata_test.obs["cell_type"].to_list(), 
                                "fold": [fold]*adata_test.obs['scNym'].shape[0]})
    else:   
        dataframe_temp = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                    "true_label": adata_test.obs["cell_type"].to_list(), 
                                    "fold": [fold]*adata_test.obs['scNym'].shape[0]})
        results = pd.concat([results,dataframe_temp], axis=0)

# Reset index
results.reset_index(drop=True, inplace=True)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (5018, 2000)
# y:  (5018,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.011172466911375523
# running_acc  :  0.07421875
# corrects: 19.000000 | total: 256.000000
# train Loss : 0.0055
# train Acc : 0.5987
# TRAIN EPOCH corrects: 2433.000000 | total: 4064.000000
# val Loss : 0.0033
# val Acc : 0.7788
# VAL EPOCH corrects: 352.000000 | total: 452.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.002683804137632251
# running_acc  :  0.796875
# corrects: 204.000000 | total: 256.000000
# train Loss : 0.0021
# train Acc : 0.8452
# TRAIN EPOCH corrects: 3435.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.8761
# VAL EPOCH corrects: 396.000000 | total: 452.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.001359161571599543
# running_acc  :  0.9296875
# corrects: 238.000000 | total: 256.000000
# train Loss : 0.0013
# train Acc : 0.9053
# TRAIN EPOCH corrects: 3679.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.8650
# VAL EPOCH corrects: 391.000000 | total: 452.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0010675014927983284
# running_acc  :  0.92578125
# corrects: 237.000000 | total: 256.000000
# train Loss : 0.0010
# train Acc : 0.9301
# TRAIN EPOCH corrects: 3780.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.8827
# VAL EPOCH corrects: 399.000000 | total: 452.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.0005576494731940329
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0007
# train Acc : 0.9481
# TRAIN EPOCH corrects: 3853.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9004
# VAL EPOCH corrects: 407.000000 | total: 452.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0006461389129981399
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9542
# TRAIN EPOCH corrects: 3878.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0026
# val Acc : 0.8407
# VAL EPOCH corrects: 380.000000 | total: 452.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0003878157294820994
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9592
# TRAIN EPOCH corrects: 3898.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0010
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0004373550764285028
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9628
# TRAIN EPOCH corrects: 3913.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.0003508591034915298
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9680
# TRAIN EPOCH corrects: 3934.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.8628
# VAL EPOCH corrects: 390.000000 | total: 452.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.00047731815720908344
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9739
# TRAIN EPOCH corrects: 3958.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0008
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.00023695756681263447
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9759
# TRAIN EPOCH corrects: 3966.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.00035879280767403543
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9779
# TRAIN EPOCH corrects: 3974.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.00014748700778000057
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9791
# TRAIN EPOCH corrects: 3979.000000 | total: 4064.000000
# val Loss : 0.0030
# val Acc : 0.8562
# VAL EPOCH corrects: 387.000000 | total: 452.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.0006822547875344753
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9783
# TRAIN EPOCH corrects: 3976.000000 | total: 4064.000000
# val Loss : 0.0008
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  0.00030457074171863496
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9887
# TRAIN EPOCH corrects: 4018.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0007
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  0.00010279567504767329
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9865
# TRAIN EPOCH corrects: 4009.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  0.00012861174764111638
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9887
# TRAIN EPOCH corrects: 4018.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  0.0002385510306339711
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9850
# TRAIN EPOCH corrects: 4003.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  0.00013301760191097856
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9894
# TRAIN EPOCH corrects: 4021.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  0.0001270511420443654
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9916
# TRAIN EPOCH corrects: 4030.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  7.016320887487382e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9919
# TRAIN EPOCH corrects: 4031.000000 | total: 4064.000000
# val Loss : 0.0025
# val Acc : 0.8872
# VAL EPOCH corrects: 401.000000 | total: 452.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  0.00032016640761867166
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9894
# TRAIN EPOCH corrects: 4021.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  0.0002537871478125453
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9909
# TRAIN EPOCH corrects: 4027.000000 | total: 4064.000000
# val Loss : 0.0008
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  7.79278198024258e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9936
# TRAIN EPOCH corrects: 4038.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  3.043819742742926e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 4044.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  0.00018346308206673712
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9926
# TRAIN EPOCH corrects: 4034.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.8960
# VAL EPOCH corrects: 405.000000 | total: 452.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  0.00016465534281451255
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 4043.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  4.77565081382636e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  0.00016617077926639467
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4050.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9115
# VAL EPOCH corrects: 412.000000 | total: 452.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  3.2909283618209884e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9909
# TRAIN EPOCH corrects: 4027.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  3.3621869079070166e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9953
# TRAIN EPOCH corrects: 4045.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  9.258382488042116e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9946
# TRAIN EPOCH corrects: 4042.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  0.0002770315040834248
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9946
# TRAIN EPOCH corrects: 4042.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  0.0001532805326860398
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9961
# TRAIN EPOCH corrects: 4048.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  3.934791311621666e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9926
# TRAIN EPOCH corrects: 4034.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  0.00019090765272267163
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 4043.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  1.8546679712017067e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9943
# TRAIN EPOCH corrects: 4041.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  2.9443452149280347e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9946
# TRAIN EPOCH corrects: 4042.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  6.464059697464108e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9938
# TRAIN EPOCH corrects: 4039.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  0.0001625256845727563
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9926
# TRAIN EPOCH corrects: 4034.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.8894
# VAL EPOCH corrects: 402.000000 | total: 452.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  6.241595110623166e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4051.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 41/99
# ----------
# Iter :  0
# running_loss :  5.263117054710165e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9958
# TRAIN EPOCH corrects: 4047.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 42/99
# ----------
# Iter :  0
# running_loss :  6.905465124873444e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9953
# TRAIN EPOCH corrects: 4045.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 43/99
# ----------
# Iter :  0
# running_loss :  1.5423654986079782e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 4044.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 44/99
# ----------
# Iter :  0
# running_loss :  4.239795816829428e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9963
# TRAIN EPOCH corrects: 4049.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 45/99
# ----------
# Iter :  0
# running_loss :  9.801412488741335e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 46/99
# ----------
# Iter :  0
# running_loss :  3.088863377342932e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9956
# TRAIN EPOCH corrects: 4046.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 47/99
# ----------
# Iter :  0
# running_loss :  9.349725587526336e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9938
# TRAIN EPOCH corrects: 4039.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 48/99
# ----------
# Iter :  0
# running_loss :  4.9364218284608796e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9961
# TRAIN EPOCH corrects: 4048.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 49/99
# ----------
# Iter :  0
# running_loss :  5.5582786444574594e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 50/99
# ----------
# Iter :  0
# running_loss :  2.812469028867781e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4051.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 51/99
# ----------
# Iter :  0
# running_loss :  2.238512024632655e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  4.9273556214757264e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  1.029293161991518e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  3.439100692048669e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  3.355973240104504e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  2.3597414838150144e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  0.00011275066208327189
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4050.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  9.149419383902568e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4050.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9159
# VAL EPOCH corrects: 414.000000 | total: 452.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  4.321498272474855e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  3.0886712920619175e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  1.6407386283390224e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  2.2234529751585796e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9963
# TRAIN EPOCH corrects: 4049.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  5.6237233366118744e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  1.0998162906616926e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  2.4825661967042834e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  3.389276025700383e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  0.00010428194218548015
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9963
# TRAIN EPOCH corrects: 4049.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  3.978029781137593e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9956
# TRAIN EPOCH corrects: 4046.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  2.179210787289776e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4051.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  1.0190267857979052e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  5.09555684402585e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  1.305252590100281e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  4.639339749701321e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  2.5744293452589773e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  4.980015364708379e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  9.026336556416936e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  2.1732214008807205e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  3.1658779334975407e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  5.98663064010907e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  7.922428267193027e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  1.4087285308050923e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  7.517026006098604e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0032
# val Acc : 0.8805
# VAL EPOCH corrects: 398.000000 | total: 452.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  5.398372377385385e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  2.1317770006135106e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  5.592983870883472e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  1.97600729734404e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  1.2231792425154708e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  1.0788868166855536e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  2.6481846362003125e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  3.015788934135344e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  9.743003829498775e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  0.0001621191913727671
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4051.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  6.162734644021839e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  4.706280378741212e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  2.303947439941112e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  1.844727376010269e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  1.4092837773205247e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  1.715983307803981e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  1.2260471521585714e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scnym\api.py:427: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['scNym_train_results'] = results
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.19568521529436111
# EVAL ACC :  0.9482071713147411
# Predictions | Labels
# [[10 12]
#  [ 0  0]
#  [10 10]
#  [ 3  3]
#  [12 12]
#  [10 10]
#  [ 3  3]
#  [11 11]
#  [ 0  0]
#  [ 0  0]
#  [10 10]
#  [ 8  8]
#  [ 0  0]
#  [10 10]
#  [ 3  3]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 15 classes from 2000 features
# ['Central_venous_LSECs' 'Cholangiocytes' 'Erythroid_Cells'
#  'Hepatic_Stellate_Cells' 'Hepatocyte_1' 'Hepatocyte_2' 'Hepatocyte_3'
#  'Hepatocyte_4' 'Hepatocyte_5' 'Hepatocyte_6' 'Inflammatory_Macrophage'
#  'NK-like_Cells' 'Non-inflammatory_Macrophage' 'Periportal_LSECs'
#  'Portal_endothelial_Cells']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 43.48it/s]
# Extracting model embeddings...
# C:\Users\user\AppData\Local\Temp\ipykernel_10672\3628955413.py:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   adata_test.obs['scNym'].iloc[i] = "Novel"
# C:\Users\user\AppData\Local\Temp\ipykernel_10672\3628955413.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adata_test.obs['scNym'].iloc[i] = "Novel"
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (5018, 2000)
# y:  (5018,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.011121857911348343
# running_acc  :  0.06640625
# corrects: 17.000000 | total: 256.000000
# train Loss : 0.0055
# train Acc : 0.5898
# TRAIN EPOCH corrects: 2397.000000 | total: 4064.000000
# val Loss : 0.0029
# val Acc : 0.8274
# VAL EPOCH corrects: 374.000000 | total: 452.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0028940504416823387
# running_acc  :  0.7578125
# corrects: 194.000000 | total: 256.000000
# train Loss : 0.0022
# train Acc : 0.8408
# TRAIN EPOCH corrects: 3417.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.8827
# VAL EPOCH corrects: 399.000000 | total: 452.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.001644224626943469
# running_acc  :  0.88671875
# corrects: 227.000000 | total: 256.000000
# train Loss : 0.0013
# train Acc : 0.9102
# TRAIN EPOCH corrects: 3699.000000 | total: 4064.000000
# val Loss : 0.0032
# val Acc : 0.8097
# VAL EPOCH corrects: 366.000000 | total: 452.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0013757902197539806
# running_acc  :  0.88671875
# corrects: 227.000000 | total: 256.000000
# train Loss : 0.0011
# train Acc : 0.9146
# TRAIN EPOCH corrects: 3717.000000 | total: 4064.000000
# val Loss : 0.0008
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.0007322612800635397
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# train Loss : 0.0008
# train Acc : 0.9405
# TRAIN EPOCH corrects: 3822.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0008614675607532263
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# train Loss : 0.0007
# train Acc : 0.9471
# TRAIN EPOCH corrects: 3849.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0015
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.00032703482429496944
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9604
# TRAIN EPOCH corrects: 3903.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0007533456664532423
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9663
# TRAIN EPOCH corrects: 3927.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0008
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.00019516531028784811
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9747
# TRAIN EPOCH corrects: 3961.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.00030875022639520466
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9761
# TRAIN EPOCH corrects: 3967.000000 | total: 4064.000000
# val Loss : 0.0025
# val Acc : 0.8872
# VAL EPOCH corrects: 401.000000 | total: 452.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.0004447629617061466
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9739
# TRAIN EPOCH corrects: 3958.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0008
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.00030122208409011364
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9838
# TRAIN EPOCH corrects: 3998.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.000291795062366873
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9823
# TRAIN EPOCH corrects: 3992.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.000244592665694654
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9808
# TRAIN EPOCH corrects: 3986.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  0.00019819708541035652
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9843
# TRAIN EPOCH corrects: 4000.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  0.0002767816185951233
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9838
# TRAIN EPOCH corrects: 3998.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  0.00017215570551343262
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9872
# TRAIN EPOCH corrects: 4012.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  0.000224581643124111
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9857
# TRAIN EPOCH corrects: 4006.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  0.00012690928997471929
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9902
# TRAIN EPOCH corrects: 4024.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  0.0003836965188384056
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9870
# TRAIN EPOCH corrects: 4011.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  9.011079237097874e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9867
# TRAIN EPOCH corrects: 4010.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  0.00011815200559794903
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9931
# TRAIN EPOCH corrects: 4036.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  0.00027287050033919513
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9904
# TRAIN EPOCH corrects: 4025.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  0.00010410692630102858
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9938
# TRAIN EPOCH corrects: 4039.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  4.121951133129187e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 4044.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  5.191347736399621e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9941
# TRAIN EPOCH corrects: 4040.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  8.75173500389792e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9919
# TRAIN EPOCH corrects: 4031.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  8.463837730232626e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9938
# TRAIN EPOCH corrects: 4039.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  4.125975101487711e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9919
# TRAIN EPOCH corrects: 4031.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  0.00010997221397701651
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9934
# TRAIN EPOCH corrects: 4037.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  9.918414434650913e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9904
# TRAIN EPOCH corrects: 4025.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  3.865424150717445e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9938
# TRAIN EPOCH corrects: 4039.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  0.00015521427849307656
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 4043.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  5.3683266742154956e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9946
# TRAIN EPOCH corrects: 4042.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  5.113043880555779e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9941
# TRAIN EPOCH corrects: 4040.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 35/99
# ----------
# Iter :  0
# ...
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  7.425961666740477e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4052.000000 | total: 4066.000000
# val Loss : 0.0011
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  3.380644920980558e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4056.000000 | total: 4066.000000
# val Loss : 0.0021
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  1.9815925043076277e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4056.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  1.688524935161695e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4057.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  1.1738030480046291e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4053.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  2.7381323889130726e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  1.750025330693461e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  7.661823474336416e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4055.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  3.2506315619684756e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9963
# TRAIN EPOCH corrects: 4051.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  6.192918226588517e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4053.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  1.962952228495851e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4058.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  3.453843964962289e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4056.000000 | total: 4066.000000
# val Loss : 0.0018
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  2.7005351512343623e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  1.0242873031529598e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4054.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  6.359279723255895e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  1.363048158964375e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  1.9016202713828534e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4057.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  1.6093354133772664e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  5.8599230214895215e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  1.2392754797474481e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4064.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9535
# VAL EPOCH corrects: 431.000000 | total: 452.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  1.1030510904674884e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4055.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  1.6330975995515473e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4057.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  4.344320041127503e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  8.347101356775966e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0020
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  4.9403985030949116e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 4046.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  1.5854502635193057e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  2.954817091449513e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  8.305572919198312e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  4.131272362428717e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0018
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  5.704306022380479e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  8.31929446576396e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  5.049827814218588e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4054.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  2.0089659301447682e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4060.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  8.486767910653725e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4058.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  4.062512016389519e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4060.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  6.0616486734943464e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  2.1355970602598973e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4056.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  0.0001038422342389822
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4053.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  2.336282341275364e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4056.000000 | total: 4066.000000
# val Loss : 0.0018
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  6.748136911483016e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4058.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  1.622169293113984e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4054.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  9.426005817658734e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  6.91237801220268e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scnym\api.py:427: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['scNym_train_results'] = results
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.20550469309091568
# EVAL ACC :  0.9383697813121272
# Predictions | Labels
# [[10 12]
#  [10 10]
#  [ 0  0]
#  [10 10]
#  [11 11]
#  [ 0  0]
#  [10 10]
#  [ 0  0]
#  [ 8  8]
#  [ 0  0]
#  [ 8  8]
#  [ 0  0]
#  [10 10]
#  [ 0  0]
#  [10 10]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 15 classes from 2000 features
# ['Central_venous_LSECs' 'Cholangiocytes' 'Erythroid_Cells'
#  'Hepatic_Stellate_Cells' 'Hepatocyte_1' 'Hepatocyte_2' 'Hepatocyte_3'
#  'Hepatocyte_4' 'Hepatocyte_5' 'Hepatocyte_6' 'Inflammatory_Macrophage'
#  'NK-like_Cells' 'Non-inflammatory_Macrophage' 'Periportal_LSECs'
#  'Portal_endothelial_Cells']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 30.77it/s]
# Extracting model embeddings...
# C:\Users\user\AppData\Local\Temp\ipykernel_10672\3628955413.py:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   adata_test.obs['scNym'].iloc[i] = "Novel"
# C:\Users\user\AppData\Local\Temp\ipykernel_10672\3628955413.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adata_test.obs['scNym'].iloc[i] = "Novel"

# %%
# Save results
results.to_csv('results/scNym_hvgs_output.csv', index=True)
