# %% [markdown]
# ## scNym: https://github.com/calico/scnym

# %%
import scnym
from scnym.api import scnym_api
import torch
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import scanpy as sc
# Out:
# WARNING:tensorflow:From c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def split_data(data_path: str, 
               fold: int=1,
               folds: int=5,
               batch_key: str="patientID", 
               label_key: str="cell_type",
               seed: int=42,
               HVG: bool=True,
               HVGs: int=2000):
    
    adata = sc.read(data_path, cache=True)

    adata.obs["batch"] = adata.obs[batch_key]

    # Ensure reproducibility
    def rep_seed(seed):
        # Check if a GPU is available
        if torch.cuda.is_available():
            # Set the random seed for PyTorch CUDA (GPU) operations
            torch.cuda.manual_seed(seed)
            # Set the random seed for all CUDA devices (if multiple GPUs are available)
            torch.cuda.manual_seed_all(seed)
        
        # Set the random seed for CPU-based PyTorch operations
        torch.manual_seed(seed)
        
        # Set the random seed for NumPy
        np.random.seed(seed)
        
        # Set the random seed for Python's built-in 'random' module
        random.seed(seed)
        
        # Set the random seed for TensorFlow
        tf.random.set_seed(seed)
        
        # Set CuDNN to deterministic mode for PyTorch (GPU)
        torch.backends.cudnn.deterministic = True
        
        # Disable CuDNN's benchmarking mode for deterministic behavior
        torch.backends.cudnn.benchmark = False

    rep_seed(seed)

    # Initialize Stratified K-Fold
    stratified_kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)

    # Iterate through the folds
    adata_original = adata.copy()
    test_adata_original = adata.copy()
    fold_counter = 0
    for train_index, test_index in stratified_kfold.split(adata_original.X, adata_original.obs[label_key]):
        fold_counter += 1
        
        adata = adata_original[train_index, :].copy()
        test_adata = test_adata_original[test_index, :].copy()

        # Define cell types to exclude
        exclude_cell_types = ['Mature_B_Cells', 
                            'Plasma_Cells', 
                            'alpha-beta_T_Cells', 
                            'gamma-delta_T_Cells_1', 
                            'gamma-delta_T_Cells_2']

        # Create a boolean mask to select cells that are not in the exclude list
        mask = ~adata.obs['cell_type'].isin(exclude_cell_types)

        # Apply the mask to AnnData object
        adata = adata[mask]

        if HVG:
            sc.pp.highly_variable_genes(adata, n_top_genes=HVGs, flavor="cell_ranger")
            test_adata = test_adata[:, adata.var["highly_variable"]].copy()
            adata = adata[:, adata.var["highly_variable"]].copy()
        
        if fold_counter == fold:
            
            return adata, test_adata

# %%
data_path = "../../../data/processed/data_for_evaluating_cell_type_annotation/MacParland.h5ad"

# Iterate through folds
results = None
for fold_idx in range(5):
    fold = fold_idx + 1

    adata_train, adata_test = split_data(data_path=data_path, fold=fold)

    # Train model
    scnym_api(
        adata=adata_train,
        task='train',
        groupby='cell_type',
        out_path='./scnym_outputs',
        config='no_new_identity',
    )

    # Predict test data
    scnym_api(
        adata=adata_test,
        task='predict',
        key_added='scNym',
        config='no_new_identity',
        trained_model='./scnym_outputs'
    )

    # Define cell as Novel if the confidence is below 0.5
    max_scores = adata_test.obs['scNym_confidence']
    for i, max_score in enumerate(max_scores):
        if max_score < 0.5:
            adata_test.obs['scNym'].iloc[i] = "Novel"

    # Save results in dataframe
    if fold == 1:
        results = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                "true_label": adata_test.obs["cell_type"].to_list(), 
                                "fold": [fold]*adata_test.obs['scNym'].shape[0]})
    else:   
        dataframe_temp = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                    "true_label": adata_test.obs["cell_type"].to_list(), 
                                    "fold": [fold]*adata_test.obs['scNym'].shape[0]})
        results = pd.concat([results,dataframe_temp], axis=0)

# Reset index
results.reset_index(drop=True, inplace=True)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:544: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['hvg'] = {'flavor': flavor}
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (5018, 2000)
# y:  (5018,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.011131412349641323
# running_acc  :  0.0625
# corrects: 16.000000 | total: 256.000000
# train Loss : 0.0055
# train Acc : 0.5871
# TRAIN EPOCH corrects: 2386.000000 | total: 4064.000000
# val Loss : 0.0033
# val Acc : 0.8119
# VAL EPOCH corrects: 367.000000 | total: 452.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0026288963854312897
# running_acc  :  0.84375
# corrects: 216.000000 | total: 256.000000
# train Loss : 0.0021
# train Acc : 0.8509
# TRAIN EPOCH corrects: 3458.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9027
# VAL EPOCH corrects: 408.000000 | total: 452.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0012724515981972218
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# train Loss : 0.0013
# train Acc : 0.9058
# TRAIN EPOCH corrects: 3681.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.8827
# VAL EPOCH corrects: 399.000000 | total: 452.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0008016328210942447
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# train Loss : 0.0009
# train Acc : 0.9338
# TRAIN EPOCH corrects: 3795.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.8518
# VAL EPOCH corrects: 385.000000 | total: 452.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.0006404767045751214
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# train Loss : 0.0007
# train Acc : 0.9491
# TRAIN EPOCH corrects: 3857.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0004892467986792326
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9547
# TRAIN EPOCH corrects: 3880.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0021
# val Acc : 0.8628
# VAL EPOCH corrects: 390.000000 | total: 452.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0005118641420267522
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9567
# TRAIN EPOCH corrects: 3888.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0012
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0003798613033723086
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9619
# TRAIN EPOCH corrects: 3909.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.0003860517463181168
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9638
# TRAIN EPOCH corrects: 3917.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.8473
# VAL EPOCH corrects: 383.000000 | total: 452.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.0004713810922112316
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9734
# TRAIN EPOCH corrects: 3956.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9004
# VAL EPOCH corrects: 407.000000 | total: 452.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.00020041491370648146
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9737
# TRAIN EPOCH corrects: 3957.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.8960
# VAL EPOCH corrects: 405.000000 | total: 452.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.00034274047357030213
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9759
# TRAIN EPOCH corrects: 3966.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.00022563648235518485
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9845
# TRAIN EPOCH corrects: 4001.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.00016497931210324168
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9843
# TRAIN EPOCH corrects: 4000.000000 | total: 4064.000000
# val Loss : 0.0024
# val Acc : 0.8673
# VAL EPOCH corrects: 392.000000 | total: 452.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  0.0002624362532515079
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9845
# TRAIN EPOCH corrects: 4001.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  0.00017893430776894093
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9847
# TRAIN EPOCH corrects: 4002.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  8.968869951786473e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9887
# TRAIN EPOCH corrects: 4018.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  0.00019370960944797844
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9803
# TRAIN EPOCH corrects: 3984.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  0.00013671403576154262
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9897
# TRAIN EPOCH corrects: 4022.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9049
# VAL EPOCH corrects: 409.000000 | total: 452.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  0.00019860672182403505
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9887
# TRAIN EPOCH corrects: 4018.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  6.711241439916193e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9894
# TRAIN EPOCH corrects: 4021.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.8938
# VAL EPOCH corrects: 404.000000 | total: 452.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  9.116539877140895e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9929
# TRAIN EPOCH corrects: 4035.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  7.425216608680785e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9943
# TRAIN EPOCH corrects: 4041.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9004
# VAL EPOCH corrects: 407.000000 | total: 452.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  6.477138958871365e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 4044.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  2.914519063779153e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9943
# TRAIN EPOCH corrects: 4041.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  0.00019216747023165226
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 4043.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  4.476214598980732e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9926
# TRAIN EPOCH corrects: 4034.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  9.66410298133269e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9956
# TRAIN EPOCH corrects: 4046.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9049
# VAL EPOCH corrects: 409.000000 | total: 452.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  0.00010155597556149587
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9926
# TRAIN EPOCH corrects: 4034.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  8.229958621086553e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4050.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9159
# VAL EPOCH corrects: 414.000000 | total: 452.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  2.1053045202279463e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9921
# TRAIN EPOCH corrects: 4032.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9049
# VAL EPOCH corrects: 409.000000 | total: 452.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  9.985236829379573e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9934
# TRAIN EPOCH corrects: 4037.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9159
# VAL EPOCH corrects: 414.000000 | total: 452.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  4.6548080717911944e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9902
# TRAIN EPOCH corrects: 4024.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  4.6252502215793356e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9956
# TRAIN EPOCH corrects: 4046.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  5.0028273108182475e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9929
# TRAIN EPOCH corrects: 4035.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  6.416618271032348e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4050.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9049
# VAL EPOCH corrects: 409.000000 | total: 452.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  3.959978130296804e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4051.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  6.710522575303912e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9958
# TRAIN EPOCH corrects: 4047.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  3.1975298043107614e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9934
# TRAIN EPOCH corrects: 4037.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.8960
# VAL EPOCH corrects: 405.000000 | total: 452.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  7.861624180804938e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 4044.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  0.0001201905106427148
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 41/99
# ----------
# Iter :  0
# running_loss :  6.937060243217275e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.8827
# VAL EPOCH corrects: 399.000000 | total: 452.000000
# Epoch 42/99
# ----------
# Iter :  0
# running_loss :  7.853812712710351e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0027
# val Acc : 0.8761
# VAL EPOCH corrects: 396.000000 | total: 452.000000
# Epoch 43/99
# ----------
# Iter :  0
# running_loss :  1.7895576092996635e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 44/99
# ----------
# Iter :  0
# running_loss :  9.998297173297033e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4050.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 45/99
# ----------
# Iter :  0
# running_loss :  4.325330883148126e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 46/99
# ----------
# Iter :  0
# running_loss :  1.4833203749731183e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 47/99
# ----------
# Iter :  0
# running_loss :  4.202100171823986e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4051.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 48/99
# ----------
# Iter :  0
# running_loss :  3.4834767575375736e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 4044.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 49/99
# ----------
# Iter :  0
# running_loss :  2.5479634132352658e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0025
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 50/99
# ----------
# Iter :  0
# running_loss :  4.571618410409428e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0027
# val Acc : 0.8872
# VAL EPOCH corrects: 401.000000 | total: 452.000000
# Epoch 51/99
# ----------
# Iter :  0
# running_loss :  3.0222960049286485e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  1.5134549357753713e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9963
# TRAIN EPOCH corrects: 4049.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  3.039776856894605e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  1.1916346920770593e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9049
# VAL EPOCH corrects: 409.000000 | total: 452.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  2.5993691451731138e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9963
# TRAIN EPOCH corrects: 4049.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9004
# VAL EPOCH corrects: 407.000000 | total: 452.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  1.0366554306528997e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9115
# VAL EPOCH corrects: 412.000000 | total: 452.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  8.534199878340587e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  8.471753972116858e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.9027
# VAL EPOCH corrects: 408.000000 | total: 452.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  5.78146546104108e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4051.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.8938
# VAL EPOCH corrects: 404.000000 | total: 452.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  4.4068481656722724e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  1.4585787539544981e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.9115
# VAL EPOCH corrects: 412.000000 | total: 452.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  2.089241024805233e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  3.541122350725345e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9115
# VAL EPOCH corrects: 412.000000 | total: 452.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  3.173250661347993e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4051.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  2.71611352218315e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0024
# val Acc : 0.8850
# VAL EPOCH corrects: 400.000000 | total: 452.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  5.235488060861826e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  5.649897502735257e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  8.432846698269714e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  1.8781263861455955e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9159
# VAL EPOCH corrects: 414.000000 | total: 452.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  7.4665645115601365e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  3.3298561902483925e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  2.5246379664167762e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4050.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  7.078958878992125e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0025
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  5.75754984311061e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  3.1295920052798465e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  2.002581641136203e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  6.22474544798024e-05
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.9027
# VAL EPOCH corrects: 408.000000 | total: 452.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  1.8123037079931237e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.8960
# VAL EPOCH corrects: 405.000000 | total: 452.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  2.47688567469595e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.9115
# VAL EPOCH corrects: 412.000000 | total: 452.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  7.725102477706969e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  2.1341109459172003e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  2.503297400835436e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0030
# val Acc : 0.8783
# VAL EPOCH corrects: 397.000000 | total: 452.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  6.030739314155653e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  5.0170074246125296e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0024
# val Acc : 0.9027
# VAL EPOCH corrects: 408.000000 | total: 452.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  1.7012129319482483e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0025
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  3.8452497392427176e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0025
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  6.605513590329792e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  1.3462984497891739e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  3.49510955857113e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0022
# val Acc : 0.9115
# VAL EPOCH corrects: 412.000000 | total: 452.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  1.3667964594787918e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  7.727685442660004e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.9004
# VAL EPOCH corrects: 407.000000 | total: 452.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  2.210820821346715e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0023
# val Acc : 0.8982
# VAL EPOCH corrects: 406.000000 | total: 452.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  1.441978383809328e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  3.527306398609653e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  2.1007599571021274e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0026
# val Acc : 0.8960
# VAL EPOCH corrects: 405.000000 | total: 452.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  8.871439786162227e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9071
# VAL EPOCH corrects: 410.000000 | total: 452.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  5.9920148487435654e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0020
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  4.364566848380491e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9115
# VAL EPOCH corrects: 412.000000 | total: 452.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  1.7168320482596755e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0024
# val Acc : 0.9159
# VAL EPOCH corrects: 414.000000 | total: 452.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.21996811032295227
# EVAL ACC :  0.9262948207171314
# Predictions | Labels
# [[10 12]
#  [ 0  0]
#  [10 10]
#  [13  3]
#  [12 12]
#  [10 10]
#  [11  3]
#  [11 11]
#  [ 0  0]
#  [ 0  0]
#  [10 10]
#  [ 8  8]
#  [ 0  0]
#  [10 10]
#  [14  3]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 15 classes from 2000 features
# ['Central_venous_LSECs' 'Cholangiocytes' 'Erythroid_Cells'
#  'Hepatic_Stellate_Cells' 'Hepatocyte_1' 'Hepatocyte_2' 'Hepatocyte_3'
#  'Hepatocyte_4' 'Hepatocyte_5' 'Hepatocyte_6' 'Inflammatory_Macrophage'
#  'NK-like_Cells' 'Non-inflammatory_Macrophage' 'Periportal_LSECs'
#  'Portal_endothelial_Cells']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 37.74it/s]
# Extracting model embeddings...
# C:\Users\user\AppData\Local\Temp\ipykernel_13628\3628955413.py:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   adata_test.obs['scNym'].iloc[i] = "Novel"
# C:\Users\user\AppData\Local\Temp\ipykernel_13628\3628955413.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adata_test.obs['scNym'].iloc[i] = "Novel"
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:544: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['hvg'] = {'flavor': flavor}
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:544: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['hvg'] = {'flavor': flavor}
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (5018, 2000)
# y:  (5018,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.010900573804974556
# running_acc  :  0.08984375
# corrects: 23.000000 | total: 256.000000
# train Loss : 0.0055
# train Acc : 0.5829
# TRAIN EPOCH corrects: 2369.000000 | total: 4064.000000
# val Loss : 0.0032
# val Acc : 0.8363
# VAL EPOCH corrects: 378.000000 | total: 452.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0031315451487898827
# running_acc  :  0.73828125
# corrects: 189.000000 | total: 256.000000
# train Loss : 0.0022
# train Acc : 0.8356
# TRAIN EPOCH corrects: 3396.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9159
# VAL EPOCH corrects: 414.000000 | total: 452.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0015604594955220819
# running_acc  :  0.89453125
# corrects: 229.000000 | total: 256.000000
# train Loss : 0.0013
# train Acc : 0.9114
# TRAIN EPOCH corrects: 3704.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9159
# VAL EPOCH corrects: 414.000000 | total: 452.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0009143720380961895
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# train Loss : 0.0010
# train Acc : 0.9232
# TRAIN EPOCH corrects: 3752.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.0006627491675317287
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# train Loss : 0.0008
# train Acc : 0.9370
# TRAIN EPOCH corrects: 3808.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0007328193169087172
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# train Loss : 0.0007
# train Acc : 0.9471
# TRAIN EPOCH corrects: 3849.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0010
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.00043579278280958533
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9579
# TRAIN EPOCH corrects: 3893.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9093
# VAL EPOCH corrects: 411.000000 | total: 452.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0007950161816552281
# running_acc  :  0.9296875
# corrects: 238.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9692
# TRAIN EPOCH corrects: 3939.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0009
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.00022825867927167565
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9744
# TRAIN EPOCH corrects: 3960.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0008
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.00031966844107955694
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9796
# TRAIN EPOCH corrects: 3981.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.00019520093337632716
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9702
# TRAIN EPOCH corrects: 3943.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.00028687348822131753
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9737
# TRAIN EPOCH corrects: 3957.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.00023374418378807604
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9860
# TRAIN EPOCH corrects: 4007.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.0001253937225556001
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9830
# TRAIN EPOCH corrects: 3995.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  0.0002562041918281466
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9820
# TRAIN EPOCH corrects: 3991.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  0.0002482777344994247
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9860
# TRAIN EPOCH corrects: 4007.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  0.00018280730000697076
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9889
# TRAIN EPOCH corrects: 4019.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  0.00011437139619374648
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9894
# TRAIN EPOCH corrects: 4021.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  0.00010161135287489742
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9879
# TRAIN EPOCH corrects: 4015.000000 | total: 4064.000000
# val Loss : 0.0040
# val Acc : 0.8650
# VAL EPOCH corrects: 391.000000 | total: 452.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  0.0003913997206836939
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9914
# TRAIN EPOCH corrects: 4029.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  4.517325578490272e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9919
# TRAIN EPOCH corrects: 4031.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  0.0001610227336641401
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9921
# TRAIN EPOCH corrects: 4032.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  6.869464414194226e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9924
# TRAIN EPOCH corrects: 4033.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  5.014577618567273e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4050.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  5.039218012825586e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9906
# TRAIN EPOCH corrects: 4026.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  6.0242240579100326e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9931
# TRAIN EPOCH corrects: 4036.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  4.746483682538383e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9961
# TRAIN EPOCH corrects: 4048.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  2.759878225333523e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9953
# TRAIN EPOCH corrects: 4045.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  3.115869913017377e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 4043.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  7.172784535214305e-05
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 4043.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  0.0001254094677278772
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9919
# TRAIN EPOCH corrects: 4031.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  1.7891776224132627e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9958
# TRAIN EPOCH corrects: 4047.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  0.0001249457272933796
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9938
# TRAIN EPOCH corrects: 4039.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  9.79958422249183e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9958
# ...
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4058.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  1.6325373508152552e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0011
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  5.057369344285689e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4057.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  3.116167863481678e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4052.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  9.489375952398404e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4054.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  7.246914719871711e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9963
# TRAIN EPOCH corrects: 4051.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  7.589701999677345e-05
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4054.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  1.3804573427478317e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 4045.000000 | total: 4066.000000
# val Loss : 0.0019
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  1.6392987163271755e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4055.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  4.099932630197145e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0018
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  1.01889590951032e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  5.139044878887944e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  1.1578267731238157e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4054.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  1.1183127753611188e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  2.4160381144611165e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4060.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  7.684819138376042e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  3.9166476199170575e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4060.000000 | total: 4066.000000
# val Loss : 0.0026
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  4.710492794401944e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4057.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  1.3157518878870178e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4054.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  1.8609012840897776e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4057.000000 | total: 4066.000000
# val Loss : 0.0021
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  7.773876859573647e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  1.5202096619759686e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4064.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  1.4482965525530744e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  2.380890873610042e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  1.3985195437271614e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4053.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  2.109090746671427e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4060.000000 | total: 4066.000000
# val Loss : 0.0019
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  1.9768922356888652e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4060.000000 | total: 4066.000000
# val Loss : 0.0018
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  5.402944589150138e-05
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9961
# TRAIN EPOCH corrects: 4050.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  8.06666721473448e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4054.000000 | total: 4066.000000
# val Loss : 0.0020
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  2.7417367164161988e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0018
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  6.430535722756758e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4057.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  2.1794301574118435e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4060.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  5.2754523494513705e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4058.000000 | total: 4066.000000
# val Loss : 0.0019
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  5.5119571698014624e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4055.000000 | total: 4066.000000
# val Loss : 0.0018
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  1.6121932276291773e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  1.737141610647086e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  7.06269929651171e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  1.952904676727485e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4059.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  1.8127951989299618e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4060.000000 | total: 4066.000000
# val Loss : 0.0017
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  2.182288335461635e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  2.2569725842913613e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  4.947087745676981e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  8.372557203983888e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0020
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  4.628824626706773e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4064.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.26787909120321274
# EVAL ACC :  0.9264413518886679
# Predictions | Labels
# [[10 12]
#  [10 10]
#  [ 0  0]
#  [10 10]
#  [11 11]
#  [ 0  0]
#  [10 10]
#  [ 0  0]
#  [ 8  8]
#  [ 0  0]
#  [ 8  8]
#  [ 0  0]
#  [10 10]
#  [ 0  0]
#  [10 10]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 15 classes from 2000 features
# ['Central_venous_LSECs' 'Cholangiocytes' 'Erythroid_Cells'
#  'Hepatic_Stellate_Cells' 'Hepatocyte_1' 'Hepatocyte_2' 'Hepatocyte_3'
#  'Hepatocyte_4' 'Hepatocyte_5' 'Hepatocyte_6' 'Inflammatory_Macrophage'
#  'NK-like_Cells' 'Non-inflammatory_Macrophage' 'Periportal_LSECs'
#  'Portal_endothelial_Cells']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 36.36it/s]
# Extracting model embeddings...
# C:\Users\user\AppData\Local\Temp\ipykernel_13628\3628955413.py:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   adata_test.obs['scNym'].iloc[i] = "Novel"
# C:\Users\user\AppData\Local\Temp\ipykernel_13628\3628955413.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adata_test.obs['scNym'].iloc[i] = "Novel"

# %%
# Save results
results.to_csv('results/scNym_hvgs_output.csv', index=True)
