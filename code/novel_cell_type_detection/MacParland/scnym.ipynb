# %% [markdown]
# ## scNym: https://github.com/calico/scnym

# %%
import scnym
from scnym.api import scnym_api
import torch
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import scanpy as sc
# Out:
# WARNING:tensorflow:From c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def split_data(data_path: str, 
               fold: int=1,
               folds: int=5,
               batch_key: str="patientID", 
               label_key: str="cell_type",
               seed: int=42,
               HVG: bool=False,
               HVGs: int=2000):
    
    adata = sc.read(data_path, cache=True)

    adata.obs["batch"] = adata.obs[batch_key]

    # Ensure reproducibility
    def rep_seed(seed):
        # Check if a GPU is available
        if torch.cuda.is_available():
            # Set the random seed for PyTorch CUDA (GPU) operations
            torch.cuda.manual_seed(seed)
            # Set the random seed for all CUDA devices (if multiple GPUs are available)
            torch.cuda.manual_seed_all(seed)
        
        # Set the random seed for CPU-based PyTorch operations
        torch.manual_seed(seed)
        
        # Set the random seed for NumPy
        np.random.seed(seed)
        
        # Set the random seed for Python's built-in 'random' module
        random.seed(seed)
        
        # Set the random seed for TensorFlow
        tf.random.set_seed(seed)
        
        # Set CuDNN to deterministic mode for PyTorch (GPU)
        torch.backends.cudnn.deterministic = True
        
        # Disable CuDNN's benchmarking mode for deterministic behavior
        torch.backends.cudnn.benchmark = False

    rep_seed(seed)

    # Initialize Stratified K-Fold
    stratified_kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)

    # Iterate through the folds
    adata_original = adata.copy()
    test_adata_original = adata.copy()
    fold_counter = 0
    for train_index, test_index in stratified_kfold.split(adata_original.X, adata_original.obs[label_key]):
        fold_counter += 1
        
        adata = adata_original[train_index, :].copy()
        test_adata = test_adata_original[test_index, :].copy()

        # Define cell types to exclude
        exclude_cell_types = ['Mature_B_Cells', 
                            'Plasma_Cells', 
                            'alpha-beta_T_Cells', 
                            'gamma-delta_T_Cells_1', 
                            'gamma-delta_T_Cells_2']

        # Create a boolean mask to select cells that are not in the exclude list
        mask = ~adata.obs['cell_type'].isin(exclude_cell_types)

        # Apply the mask to AnnData object
        adata = adata[mask]

        if HVG:
            sc.pp.highly_variable_genes(adata, n_top_genes=HVGs, flavor="cell_ranger")
            test_adata = test_adata[:, adata.var["highly_variable"]].copy()
            adata = adata[:, adata.var["highly_variable"]].copy()
        
        if fold_counter == fold:
            
            return adata, test_adata

# %%
data_path = "../../../data/processed/data_for_evaluating_cell_type_annotation/MacParland.h5ad"

# Iterate through folds
results = None
for fold_idx in range(5):
    fold = fold_idx + 1

    adata_train, adata_test = split_data(data_path=data_path, fold=fold)

    # Train model
    scnym_api(
        adata=adata_train,
        task='train',
        groupby='cell_type',
        out_path='./scnym_outputs',
        config='no_new_identity',
    )

    # Predict test data
    scnym_api(
        adata=adata_test,
        task='predict',
        key_added='scNym',
        config='no_new_identity',
        trained_model='./scnym_outputs'
    )

    # Define cell as Novel if the confidence is below 0.5
    max_scores = adata_test.obs['scNym_confidence']
    for i, max_score in enumerate(max_scores):
        if max_score < 0.5:
            adata_test.obs['scNym'].iloc[i] = "Novel"

    # Save results in dataframe
    if fold == 1:
        results = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                "true_label": adata_test.obs["cell_type"].to_list(), 
                                "fold": [fold]*adata_test.obs['scNym'].shape[0]})
    else:   
        dataframe_temp = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                    "true_label": adata_test.obs["cell_type"].to_list(), 
                                    "fold": [fold]*adata_test.obs['scNym'].shape[0]})
        results = pd.concat([results,dataframe_temp], axis=0)

# Reset index
results.reset_index(drop=True, inplace=True)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (5018, 15386)
# y:  (5018,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.011137683875858784
# running_acc  :  0.0546875
# corrects: 14.000000 | total: 256.000000
# train Loss : 0.0053
# train Acc : 0.6139
# TRAIN EPOCH corrects: 2495.000000 | total: 4064.000000
# val Loss : 0.0030
# val Acc : 0.7854
# VAL EPOCH corrects: 355.000000 | total: 452.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0025729616172611713
# running_acc  :  0.80078125
# corrects: 205.000000 | total: 256.000000
# train Loss : 0.0019
# train Acc : 0.8625
# TRAIN EPOCH corrects: 3505.000000 | total: 4064.000000
# val Loss : 0.0027
# val Acc : 0.8230
# VAL EPOCH corrects: 372.000000 | total: 452.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0013017504243180156
# running_acc  :  0.921875
# corrects: 236.000000 | total: 256.000000
# train Loss : 0.0010
# train Acc : 0.9375
# TRAIN EPOCH corrects: 3810.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.000644549319986254
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9690
# TRAIN EPOCH corrects: 3938.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.00048759166384115815
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9783
# TRAIN EPOCH corrects: 3976.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.8827
# VAL EPOCH corrects: 399.000000 | total: 452.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0003323883574921638
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9847
# TRAIN EPOCH corrects: 4002.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0012
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0003056908317375928
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9882
# TRAIN EPOCH corrects: 4016.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9159
# VAL EPOCH corrects: 414.000000 | total: 452.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  7.288639608304948e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9902
# TRAIN EPOCH corrects: 4024.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0009
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.00017205228505190462
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9916
# TRAIN EPOCH corrects: 4030.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0009
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.0001416503801010549
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9938
# TRAIN EPOCH corrects: 4039.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  6.527916411869228e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  4.671978604164906e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.00010492673027329147
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9968
# TRAIN EPOCH corrects: 4051.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.00013019060133956373
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 4044.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  2.9605565941892564e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9966
# TRAIN EPOCH corrects: 4050.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  7.361572352238e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9958
# TRAIN EPOCH corrects: 4047.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  2.627760659379419e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  4.137494761380367e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  2.109341585310176e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  2.5934927180060185e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  4.61200688732788e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  0.00011284288484603167
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  2.3100215912563726e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  7.874668517615646e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  1.8081365851685405e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  1.7549204130773433e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  2.7530932129593566e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  1.1822157830465585e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  2.2446998627856374e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  4.003650974482298e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  2.741007847362198e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  3.7696056551794754e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  9.724741175887175e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  1.0895057130255736e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  1.2163462088210508e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  1.7886235582409427e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  2.5143504899460822e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  9.355597285320982e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  1.744375185808167e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  6.0422248679969925e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  1.5749303202028386e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 41/99
# ----------
# Iter :  0
# running_loss :  1.4625539733970072e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 42/99
# ----------
# Iter :  0
# running_loss :  3.5588811442721635e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 43/99
# ----------
# Iter :  0
# running_loss :  6.294336799328448e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 44/99
# ----------
# Iter :  0
# running_loss :  1.0508852938073687e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 45/99
# ----------
# Iter :  0
# running_loss :  5.400071131589357e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 46/99
# ----------
# Iter :  0
# running_loss :  7.697378350712825e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 47/99
# ----------
# Iter :  0
# running_loss :  2.526366188249085e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 48/99
# ----------
# Iter :  0
# running_loss :  7.148460281314328e-05
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 49/99
# ----------
# Iter :  0
# running_loss :  6.945429504412459e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 50/99
# ----------
# Iter :  0
# running_loss :  1.6708589100744575e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 51/99
# ----------
# Iter :  0
# running_loss :  1.2147031156928279e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  3.0652969144284725e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  6.479300736828009e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  3.214041862520389e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  5.6395783758489415e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  4.209033249935601e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  6.056469828763511e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  1.3179672350815963e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  3.187176480423659e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  2.6745368813863024e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  2.998949639732018e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  3.3977248676819727e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  1.0910440323641524e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  2.972894208141952e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  7.069898856570944e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  1.1086352060374338e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  8.937387974583544e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  1.3318033779796679e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  1.962313490366796e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0028
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  7.810906936356332e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  1.6811161913210526e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  3.40362794304383e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  5.4996648941596504e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  1.579757190484088e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  9.117853551288135e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  5.613724624708993e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  3.38363679475151e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0021
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  5.345630142983282e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0019
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  3.4610709462867817e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  6.755610229447484e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9270
# VAL EPOCH corrects: 419.000000 | total: 452.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  5.830260306538548e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  1.7015568118949886e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  2.8017502700095065e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  2.4731989469728433e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  5.594229605776491e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9137
# VAL EPOCH corrects: 413.000000 | total: 452.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  8.326442184625193e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  1.5239604181260802e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  8.450000677839853e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  2.2451933546108194e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  2.94311416837445e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  1.879098022072867e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  6.352050149871502e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  4.346092282503378e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  1.5496758351218887e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  6.800294158892939e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  2.221755721620866e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  3.610462499636924e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  3.02363559967489e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  6.4985388235072605e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4064.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.17392557859420776
# EVAL ACC :  0.9462151394422311
# Predictions | Labels
# [[10 12]
#  [ 0  0]
#  [10 10]
#  [13  3]
#  [12 12]
#  [10 10]
#  [10  3]
#  [11 11]
#  [ 0  0]
#  [ 0  0]
#  [10 10]
#  [ 8  8]
#  [ 0  0]
#  [10 10]
#  [ 3  3]]
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scnym\api.py:427: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['scNym_train_results'] = results
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 15 classes from 15386 features
# ['Central_venous_LSECs' 'Cholangiocytes' 'Erythroid_Cells'
#  'Hepatic_Stellate_Cells' 'Hepatocyte_1' 'Hepatocyte_2' 'Hepatocyte_3'
#  'Hepatocyte_4' 'Hepatocyte_5' 'Hepatocyte_6' 'Inflammatory_Macrophage'
#  'NK-like_Cells' 'Non-inflammatory_Macrophage' 'Periportal_LSECs'
#  'Portal_endothelial_Cells']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 16.26it/s]
# C:\Users\user\AppData\Local\Temp\ipykernel_10632\3628955413.py:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   adata_test.obs['scNym'].iloc[i] = "Novel"
# C:\Users\user\AppData\Local\Temp\ipykernel_10632\3628955413.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adata_test.obs['scNym'].iloc[i] = "Novel"
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Extracting model embeddings...
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (5018, 15386)
# y:  (5018,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.01104919146746397
# running_acc  :  0.08984375
# corrects: 23.000000 | total: 256.000000
# train Loss : 0.0055
# train Acc : 0.5987
# TRAIN EPOCH corrects: 2433.000000 | total: 4064.000000
# val Loss : 0.0034
# val Acc : 0.7478
# VAL EPOCH corrects: 338.000000 | total: 452.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0026039942167699337
# running_acc  :  0.83203125
# corrects: 213.000000 | total: 256.000000
# train Loss : 0.0020
# train Acc : 0.8632
# TRAIN EPOCH corrects: 3508.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.8938
# VAL EPOCH corrects: 404.000000 | total: 452.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0013054218143224716
# running_acc  :  0.90234375
# corrects: 231.000000 | total: 256.000000
# train Loss : 0.0011
# train Acc : 0.9321
# TRAIN EPOCH corrects: 3788.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9181
# VAL EPOCH corrects: 415.000000 | total: 452.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0010385912610217929
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9641
# TRAIN EPOCH corrects: 3918.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9027
# VAL EPOCH corrects: 408.000000 | total: 452.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.000416229828260839
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0005
# train Acc : 0.9724
# TRAIN EPOCH corrects: 3952.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0002757813490461558
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9843
# TRAIN EPOCH corrects: 4000.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0011
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0002675336436368525
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9875
# TRAIN EPOCH corrects: 4013.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0011
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.00019302144937682897
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9906
# TRAIN EPOCH corrects: 4026.000000 | total: 4064.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0009
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.00012759410310536623
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 4043.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9336
# VAL EPOCH corrects: 422.000000 | total: 452.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.00012014274398097768
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9951
# TRAIN EPOCH corrects: 4044.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  6.881602166686207e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.0001231624628417194
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9956
# TRAIN EPOCH corrects: 4046.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  9.137245069723576e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  3.7897636502748355e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  4.037776670884341e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0009
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  2.651200702530332e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  2.868985575332772e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  1.413805421179859e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  3.7882513424847275e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  0.00010832292900886387
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  2.2049884137231857e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  4.324202745920047e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9970
# TRAIN EPOCH corrects: 4052.000000 | total: 4064.000000
# val Loss : 0.0017
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  7.336135604418814e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9973
# TRAIN EPOCH corrects: 4053.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  4.6184628445189446e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  1.6075056919362396e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 4056.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  5.035595677327365e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0013
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  2.7851350751006976e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  1.9516697648214176e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9975
# TRAIN EPOCH corrects: 4054.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  1.733633689582348e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4063.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  5.581775440077763e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  2.0526918888208456e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9985
# TRAIN EPOCH corrects: 4058.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  1.3067775398667436e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0015
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  1.663173497945536e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4059.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  2.0098508684895933e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 4055.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9535
# VAL EPOCH corrects: 431.000000 | total: 452.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  7.926226680865511e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4060.000000 | total: 4064.000000
# val Loss : 0.0010
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  1.9286842871224508e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0016
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  3.226755143259652e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0018
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  9.003303603094537e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4061.000000 | total: 4064.000000
# val Loss : 0.0012
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  2.6473890102352016e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9983
# TRAIN EPOCH corrects: 4057.000000 | total: 4064.000000
# val Loss : 0.0011
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  1.7027410649461672e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4062.000000 | total: 4064.000000
# val Loss : 0.0014
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  4.347804861026816e-05
# running_acc  :  0.99609375
# ...
# val Loss : 0.0013
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  1.5254379832185805e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  4.9718355512595735e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  2.6531761250225827e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  5.554521067097085e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  2.27906389227428e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  2.6723178052634466e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  8.320127562910784e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0011
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  6.867130196042126e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4064.000000 | total: 4066.000000
# val Loss : 0.0023
# val Acc : 0.9159
# VAL EPOCH corrects: 414.000000 | total: 452.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  7.995604391908273e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4064.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  2.8171318717795657e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9226
# VAL EPOCH corrects: 417.000000 | total: 452.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  4.661570073949406e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4064.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  2.8738704713759944e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  4.528596491581993e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  6.1538735280919354e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  6.148210377432406e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0010
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  5.664610398525838e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0020
# val Acc : 0.9248
# VAL EPOCH corrects: 418.000000 | total: 452.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  2.1528576326090842e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  3.7516936117754085e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  4.2184151425317395e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4064.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9204
# VAL EPOCH corrects: 416.000000 | total: 452.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  5.865591447218321e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0011
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  1.8555697351985145e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0008
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  1.76367677795497e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0011
# val Acc : 0.9358
# VAL EPOCH corrects: 423.000000 | total: 452.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  4.007057668786729e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  4.521677510638256e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0010
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  1.678473381616641e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0010
# val Acc : 0.9381
# VAL EPOCH corrects: 424.000000 | total: 452.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  2.3761700504110195e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9990
# TRAIN EPOCH corrects: 4062.000000 | total: 4066.000000
# val Loss : 0.0011
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  3.6118474326940486e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  3.769324848690303e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9988
# TRAIN EPOCH corrects: 4061.000000 | total: 4066.000000
# val Loss : 0.0011
# val Acc : 0.9513
# VAL EPOCH corrects: 430.000000 | total: 452.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  2.2971371436142363e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  5.341888936527539e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4064.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  7.113442734407727e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9314
# VAL EPOCH corrects: 421.000000 | total: 452.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  3.2523171284992713e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0016
# val Acc : 0.9292
# VAL EPOCH corrects: 420.000000 | total: 452.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  2.3026708731777035e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  1.064108801074326e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0010
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  2.6403831725474447e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0014
# val Acc : 0.9403
# VAL EPOCH corrects: 425.000000 | total: 452.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  2.795812633848982e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  5.219054855842842e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  5.193982360651717e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0013
# val Acc : 0.9447
# VAL EPOCH corrects: 427.000000 | total: 452.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  4.379460733616725e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 4065.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  5.376488388719736e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0012
# val Acc : 0.9469
# VAL EPOCH corrects: 428.000000 | total: 452.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  2.820143890858162e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 4066.000000 | total: 4066.000000
# val Loss : 0.0015
# val Acc : 0.9425
# VAL EPOCH corrects: 426.000000 | total: 452.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  3.62974378731451e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 4063.000000 | total: 4066.000000
# val Loss : 0.0011
# val Acc : 0.9558
# VAL EPOCH corrects: 432.000000 | total: 452.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  2.088073415507097e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 4064.000000 | total: 4066.000000
# val Loss : 0.0010
# val Acc : 0.9491
# VAL EPOCH corrects: 429.000000 | total: 452.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.1799781545996666
# EVAL ACC :  0.9443339960238568
# Predictions | Labels
# [[10 12]
#  [10 10]
#  [ 0  0]
#  [10 10]
#  [11 11]
#  [ 0  0]
#  [10 10]
#  [ 0  0]
#  [ 8  8]
#  [ 0  0]
#  [ 8  8]
#  [ 0  0]
#  [10 10]
#  [ 0  0]
#  [10 10]]
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scnym\api.py:427: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['scNym_train_results'] = results
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 15 classes from 15386 features
# ['Central_venous_LSECs' 'Cholangiocytes' 'Erythroid_Cells'
#  'Hepatic_Stellate_Cells' 'Hepatocyte_1' 'Hepatocyte_2' 'Hepatocyte_3'
#  'Hepatocyte_4' 'Hepatocyte_5' 'Hepatocyte_6' 'Inflammatory_Macrophage'
#  'NK-like_Cells' 'Non-inflammatory_Macrophage' 'Periportal_LSECs'
#  'Portal_endothelial_Cells']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00,  8.33it/s]
# C:\Users\user\AppData\Local\Temp\ipykernel_10632\3628955413.py:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   adata_test.obs['scNym'].iloc[i] = "Novel"
# Extracting model embeddings...
# C:\Users\user\AppData\Local\Temp\ipykernel_10632\3628955413.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adata_test.obs['scNym'].iloc[i] = "Novel"

# %%
# Save results
results.to_csv('results/scNym_output.csv', index=True)
