# %%
# Import packages
from functions.visualization_functions import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %% [markdown]
# ### Read benchmark files

# %%
files = ["../cell_type_representation/benchmarks/results/Bone_marrow/Benchmark_results",
         "../cell_type_representation/benchmarks/results/Bone_marrow/Benchmark_results_check_repoducibility"]

VisEnv.read_csv(files=files)

# %% [markdown]
# ### Visualize with table

# %%
VisEnv.visualize_results()
# Out:
# <style type="text/css">
# #T_eb2d1_row0_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_eb2d1_row0_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_eb2d1_row0_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_eb2d1_row0_col4 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_eb2d1_row0_col5 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_eb2d1_row0_col6 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_eb2d1_row0_col7, #T_eb2d1_row0_col9, #T_eb2d1_row0_col12, #T_eb2d1_row0_col23, #T_eb2d1_row1_col1, #T_eb2d1_row1_col2, #T_eb2d1_row1_col4, #T_eb2d1_row1_col6, #T_eb2d1_row1_col11, #T_eb2d1_row1_col13, #T_eb2d1_row1_col16, #T_eb2d1_row1_col17, #T_eb2d1_row1_col20, #T_eb2d1_row1_col21, #T_eb2d1_row2_col8, #T_eb2d1_row2_col10, #T_eb2d1_row2_col14, #T_eb2d1_row2_col18, #T_eb2d1_row2_col19, #T_eb2d1_row2_col22, #T_eb2d1_row2_col24, #T_eb2d1_row5_col3, #T_eb2d1_row6_col5, #T_eb2d1_row9_col15 {
# ...

# %% [markdown]
# ### Boxplot visualization

# %%
image_path = "figures/Bone_marrow_metrics"
VisEnv.BarPlotVisualization(image_path=image_path)
