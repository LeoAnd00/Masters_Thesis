# %%
# Import packages
from functions.visualization_functions import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %% [markdown]
# ### Read benchmark files

# %%
files = ["../cell_type_representation/benchmarks/results/Bone_marrow/Benchmark_results",
         "../cell_type_representation/benchmarks/results/Bone_marrow/Benchmark_results_check_repoducibility"]

VisEnv.read_csv(files=files)

# %% [markdown]
# ### Visualize with table

# %%
VisEnv.visualize_results()
# Out:
# <style type="text/css">
# #T_98d5e_row0_col1 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col2 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col3 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col4 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col5 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col6 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_98d5e_row0_col7, #T_98d5e_row0_col9, #T_98d5e_row0_col12, #T_98d5e_row0_col23, #T_98d5e_row1_col1, #T_98d5e_row1_col2, #T_98d5e_row1_col4, #T_98d5e_row1_col6, #T_98d5e_row1_col11, #T_98d5e_row1_col13, #T_98d5e_row1_col16, #T_98d5e_row1_col17, #T_98d5e_row1_col20, #T_98d5e_row1_col21, #T_98d5e_row2_col8, #T_98d5e_row2_col10, #T_98d5e_row2_col14, #T_98d5e_row2_col18, #T_98d5e_row2_col19, #T_98d5e_row2_col22, #T_98d5e_row2_col24, #T_98d5e_row5_col3, #T_98d5e_row6_col5, #T_98d5e_row9_col15 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col8 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_98d5e_row0_col10 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col11 {
#   background-color: #0a539e;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col13, #T_98d5e_row7_col9 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col14 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_98d5e_row0_col15 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_98d5e_row0_col16 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_98d5e_row0_col17, #T_98d5e_row1_col7, #T_98d5e_row1_col23 {
#   background-color: #083979;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col18 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_98d5e_row0_col19 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col20 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_98d5e_row0_col21 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_98d5e_row0_col22 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_98d5e_row0_col24, #T_98d5e_row5_col23 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_98d5e_row1_col3 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_98d5e_row1_col5, #T_98d5e_row7_col21 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_98d5e_row1_col8 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_98d5e_row1_col9 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_98d5e_row1_col10 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_98d5e_row1_col12 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_98d5e_row1_col14 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_98d5e_row1_col15 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_98d5e_row1_col18 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_98d5e_row1_col19, #T_98d5e_row3_col5 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_98d5e_row1_col22 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_98d5e_row1_col24 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_98d5e_row2_col1 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_98d5e_row2_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_98d5e_row2_col3, #T_98d5e_row2_col5, #T_98d5e_row4_col9 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_98d5e_row2_col4 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_98d5e_row2_col6 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_98d5e_row2_col7 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_98d5e_row2_col9 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_98d5e_row2_col11, #T_98d5e_row7_col11 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_98d5e_row2_col12 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_98d5e_row2_col13, #T_98d5e_row8_col11 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_98d5e_row2_col15, #T_98d5e_row3_col2, #T_98d5e_row3_col4, #T_98d5e_row3_col6, #T_98d5e_row3_col8, #T_98d5e_row3_col10, #T_98d5e_row3_col12, #T_98d5e_row3_col14, #T_98d5e_row3_col16, #T_98d5e_row3_col18, #T_98d5e_row3_col20, #T_98d5e_row3_col22, #T_98d5e_row3_col24, #T_98d5e_row4_col2, #T_98d5e_row4_col4, #T_98d5e_row4_col6, #T_98d5e_row4_col8, #T_98d5e_row4_col10, #T_98d5e_row4_col12, #T_98d5e_row4_col14, #T_98d5e_row4_col16, #T_98d5e_row4_col18, #T_98d5e_row4_col20, #T_98d5e_row4_col22, #T_98d5e_row4_col24, #T_98d5e_row5_col2, #T_98d5e_row5_col4, #T_98d5e_row5_col6, #T_98d5e_row5_col8, #T_98d5e_row5_col10, #T_98d5e_row5_col12, #T_98d5e_row5_col14, #T_98d5e_row5_col16, #T_98d5e_row5_col18, #T_98d5e_row5_col20, #T_98d5e_row5_col22, #T_98d5e_row5_col24, #T_98d5e_row6_col1, #T_98d5e_row6_col2, #T_98d5e_row6_col4, #T_98d5e_row6_col6, #T_98d5e_row6_col8, #T_98d5e_row6_col9, #T_98d5e_row6_col10, #T_98d5e_row6_col11, #T_98d5e_row6_col12, #T_98d5e_row6_col13, #T_98d5e_row6_col14, #T_98d5e_row6_col16, #T_98d5e_row6_col17, #T_98d5e_row6_col18, #T_98d5e_row6_col20, #T_98d5e_row6_col21, #T_98d5e_row6_col22, #T_98d5e_row6_col24, #T_98d5e_row7_col2, #T_98d5e_row7_col4, #T_98d5e_row7_col5, #T_98d5e_row7_col6, #T_98d5e_row7_col8, #T_98d5e_row7_col10, #T_98d5e_row7_col12, #T_98d5e_row7_col14, #T_98d5e_row7_col16, #T_98d5e_row7_col18, #T_98d5e_row7_col20, #T_98d5e_row7_col22, #T_98d5e_row7_col24, #T_98d5e_row8_col2, #T_98d5e_row8_col3, #T_98d5e_row8_col4, #T_98d5e_row8_col6, #T_98d5e_row8_col7, #T_98d5e_row8_col8, #T_98d5e_row8_col10, #T_98d5e_row8_col12, #T_98d5e_row8_col14, #T_98d5e_row8_col16, #T_98d5e_row8_col18, #T_98d5e_row8_col20, #T_98d5e_row8_col22, #T_98d5e_row8_col24, #T_98d5e_row9_col2, #T_98d5e_row9_col4, #T_98d5e_row9_col5, #T_98d5e_row9_col6, #T_98d5e_row9_col8, #T_98d5e_row9_col10, #T_98d5e_row9_col12, #T_98d5e_row9_col14, #T_98d5e_row9_col16, #T_98d5e_row9_col18, #T_98d5e_row9_col19, #T_98d5e_row9_col20, #T_98d5e_row9_col22, #T_98d5e_row9_col23, #T_98d5e_row9_col24 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_98d5e_row2_col16 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_98d5e_row2_col17 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_98d5e_row2_col20 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_98d5e_row2_col21 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_98d5e_row2_col23 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_98d5e_row3_col1 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_98d5e_row3_col3 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_98d5e_row3_col7, #T_98d5e_row4_col13 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_98d5e_row3_col9 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_98d5e_row3_col11 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_98d5e_row3_col13, #T_98d5e_row4_col7 {
#   background-color: #3d8dc4;
#   color: #f1f1f1;
# }
# #T_98d5e_row3_col15 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_98d5e_row3_col17 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_98d5e_row3_col19 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_98d5e_row3_col21 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_98d5e_row3_col23 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_98d5e_row4_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_98d5e_row4_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_98d5e_row4_col5 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_98d5e_row4_col11 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_98d5e_row4_col15 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_98d5e_row4_col17 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_98d5e_row4_col19 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_98d5e_row4_col21 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_98d5e_row4_col23 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_98d5e_row5_col1 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_98d5e_row5_col5 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_98d5e_row5_col7, #T_98d5e_row5_col19 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_98d5e_row5_col9 {
#   background-color: #4a98c9;
#   color: #f1f1f1;
# }
# #T_98d5e_row5_col11 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_98d5e_row5_col13 {
#   back

# %% [markdown]
# ### Boxplot visualization

# %%
image_path = "figures/Bone_marrow_metrics"
VisEnv.BarPlotVisualization(image_path=image_path)
