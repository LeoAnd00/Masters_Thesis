# %%
# Import packages
from visualize_metrics import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %%
file = "results_and_visualizations/Benchmark_results"
VisEnv.read_csv(file=file)

# %% [markdown]
# ### All datasets

# %%
VisEnv.BoxPlotVisualization()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\novel_cell_type_detection_at_dif_thresholds\visualize_metrics.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model1 |HVGs"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\novel_cell_type_detection_at_dif_thresholds\visualize_metrics.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Excluded Cell Type'][metrics['Excluded Cell Type'] == "Mature_B_Cells"] = "Mature B Cells"
# ...

# %%
VisEnv.BoxPlotVisualization()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\novel_cell_type_detection_at_dif_thresholds\visualize_metrics.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model1 |HVGs"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\novel_cell_type_detection_at_dif_thresholds\visualize_metrics.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Excluded Cell Type'][metrics['Excluded Cell Type'] == "Mature_B_Cells"] = "Mature B Cells"
# ...
