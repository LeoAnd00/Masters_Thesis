# %%
# Import packages
from visualize_metrics import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %%
file = "results_and_visualizations/results_benchmark"
VisEnv.read_csv(file=file)

# %% [markdown]
# ### All datasets

# %%
image_path = "figures/Annotation_metrics"
VisEnv.BoxPlotVisualization(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model1 | HVGs"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "TOSICA"] = "TOSICA | HVGs"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:144: SettingWithCopyWarning:
# ...

# %% [markdown]
# ### Normalized average across datasets for each metric

# %%
image_path = "figures/Annotation_average_metrics"
VisEnv.BarPlotAverageMetricsVisualization(image_path=image_path)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model1 | HVGs"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "TOSICA"] = "TOSICA | HVGs"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:263: SettingWithCopyWarning:
# ...
