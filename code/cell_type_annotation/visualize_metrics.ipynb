# %%
# Import packages
from visualize_metrics import VisualizeEnv as VisualizeEnv

# %%
# Initialize Env
VisEnv = VisualizeEnv()

# %%
file = "results_and_visualizations/results_benchmark"
VisEnv.read_csv(file=file)

# %% [markdown]
# ### All datasets

# %%
VisEnv.BoxPlotVisualization()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model1_HVGs"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "TOSICA"] = "TOSICA_HVGs"

# %% [markdown]
# ### Compare different loss options

# %%
file = "results_and_visualizations/results_loss_comparison"
VisEnv.read_csv(file=file)

# %%
VisEnv.LossCompBoxPlotVisualization()
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:243: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1"] = "Model1 | Centroid + CL Loss"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1_CL"] = "Model1 | CL Loss"
# c:\Users\user\Documents\GitHub\Masters_Thesis\code\cell_type_annotation\visualize_metrics.py:245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metrics['Method'][metrics['Method'] == "Model1_Centroid"] = "Model1 | Centroid Loss"

# %% [markdown]
# ### Segerstolpe

# %%
file = "results_and_visualizations/results_benchmark"
VisEnv.read_csv(file=file)

# %%
VisEnv.BarPlotVisualization(dataset_name="Segerstolpe")

# %% [markdown]
# ### MacParland

# %%
VisEnv.BarPlotVisualization(dataset_name="MacParland")

# %% [markdown]
# ### Baron

# %%
VisEnv.BarPlotVisualization(dataset_name="Baron")
