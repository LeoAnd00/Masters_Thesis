# %% [markdown]
# ## scNym: https://github.com/calico/scnym

# %%
import scnym
from scnym.api import scnym_api
import torch
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import scanpy as sc
# Out:
# WARNING:tensorflow:From c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def split_data(data_path: str, 
               fold: int=1,
               folds: int=5,
               batch_key: str="patientID", 
               label_key: str="cell_type",
               seed: int=42,
               HVG: bool=True,
               HVGs: int=2000):
    
    adata = sc.read(data_path, cache=True)

    adata.obs["batch"] = adata.obs[batch_key]

    # Ensure reproducibility
    def rep_seed(seed):
        # Check if a GPU is available
        if torch.cuda.is_available():
            # Set the random seed for PyTorch CUDA (GPU) operations
            torch.cuda.manual_seed(seed)
            # Set the random seed for all CUDA devices (if multiple GPUs are available)
            torch.cuda.manual_seed_all(seed)
        
        # Set the random seed for CPU-based PyTorch operations
        torch.manual_seed(seed)
        
        # Set the random seed for NumPy
        np.random.seed(seed)
        
        # Set the random seed for Python's built-in 'random' module
        random.seed(seed)
        
        # Set the random seed for TensorFlow
        tf.random.set_seed(seed)
        
        # Set CuDNN to deterministic mode for PyTorch (GPU)
        torch.backends.cudnn.deterministic = True
        
        # Disable CuDNN's benchmarking mode for deterministic behavior
        torch.backends.cudnn.benchmark = False

    rep_seed(seed)

    # Initialize Stratified K-Fold
    stratified_kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)

    # Iterate through the folds
    adata_original = adata
    test_adata_original = adata
    fold_counter = 0
    for train_index, test_index in stratified_kfold.split(adata_original.X, adata_original.obs[label_key]):
        fold_counter += 1
        
        if fold_counter == fold:

            adata = adata_original[train_index, :]
            test_adata = test_adata_original[test_index, :]

            if HVG:
                sc.pp.highly_variable_genes(adata, n_top_genes=HVGs, flavor="cell_ranger")
                test_adata = test_adata[:, adata.var["highly_variable"]]
                adata = adata[:, adata.var["highly_variable"]]
            
            return adata, test_adata

# %%
data_path = "../../../data/processed/data_for_evaluating_cell_type_annotation/Zheng68k.h5ad"

# Iterate through folds
results = None
for fold_idx in range(5):
    fold = fold_idx + 1

    adata_train, adata_test = split_data(data_path=data_path, fold=fold)

    # Train model
    scnym_api(
        adata=adata_train,
        task='train',
        groupby='cell_type',
        out_path='./scnym_outputs',
        config='no_new_identity',
    )

    # Predict test data
    scnym_api(
        adata=adata_test,
        task='predict',
        key_added='scNym',
        config='no_new_identity',
        trained_model='./scnym_outputs'
    )

    # Save results in dataframe
    if fold == 1:
        results = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                "true_label": adata_test.obs["cell_type"].to_list(), 
                                "fold": [fold]*adata_test.obs['scNym'].shape[0]})
    else:   
        dataframe_temp = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                    "true_label": adata_test.obs["cell_type"].to_list(), 
                                    "fold": [fold]*adata_test.obs['scNym'].shape[0]})
        results = pd.concat([results,dataframe_temp], axis=0)

# Reset index
results.reset_index(drop=True, inplace=True)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:544: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['hvg'] = {'flavor': flavor}
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (54863, 2000)
# y:  (54863,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.009999463334679604
# running_acc  :  0.11328125
# corrects: 29.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0037505616143456485
# running_acc  :  0.6573329207920792
# corrects: 16996.000000 | total: 25856.000000
# train Loss : 0.0034
# train Acc : 0.6813
# TRAIN EPOCH corrects: 30277.000000 | total: 44438.000000
# val Loss : 0.0029
# val Acc : 0.7477
# VAL EPOCH corrects: 3692.000000 | total: 4938.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0022940856870263815
# running_acc  :  0.7734375
# corrects: 198.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0027050662665895307
# running_acc  :  0.7420714727722773
# corrects: 19187.000000 | total: 25856.000000
# train Loss : 0.0027
# train Acc : 0.7452
# TRAIN EPOCH corrects: 33117.000000 | total: 44438.000000
# val Loss : 0.0026
# val Acc : 0.7710
# VAL EPOCH corrects: 3807.000000 | total: 4938.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0023777808528393507
# running_acc  :  0.78515625
# corrects: 201.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.002420898934936907
# running_acc  :  0.765625
# corrects: 19796.000000 | total: 25856.000000
# train Loss : 0.0025
# train Acc : 0.7641
# TRAIN EPOCH corrects: 33957.000000 | total: 44438.000000
# val Loss : 0.0027
# val Acc : 0.7801
# VAL EPOCH corrects: 3852.000000 | total: 4938.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.0020395261235535145
# running_acc  :  0.78125
# corrects: 200.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0022559003411137526
# running_acc  :  0.7837639232673267
# corrects: 20265.000000 | total: 25856.000000
# train Loss : 0.0023
# train Acc : 0.7826
# TRAIN EPOCH corrects: 34779.000000 | total: 44438.000000
# val Loss : 0.0024
# val Acc : 0.7855
# VAL EPOCH corrects: 3879.000000 | total: 4938.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.0018669022247195244
# running_acc  :  0.8515625
# corrects: 218.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.002102756321817489
# running_acc  :  0.799737004950495
# corrects: 20678.000000 | total: 25856.000000
# train Loss : 0.0021
# train Acc : 0.7956
# TRAIN EPOCH corrects: 35357.000000 | total: 44438.000000
# val Loss : 0.0025
# val Acc : 0.7787
# VAL EPOCH corrects: 3845.000000 | total: 4938.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0018857154063880444
# running_acc  :  0.828125
# corrects: 212.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0020208192509737345
# running_acc  :  0.8083616955445545
# corrects: 20901.000000 | total: 25856.000000
# train Loss : 0.0021
# train Acc : 0.8059
# TRAIN EPOCH corrects: 35813.000000 | total: 44438.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0029
# val Acc : 0.7509
# VAL EPOCH corrects: 3708.000000 | total: 4938.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0016671685734763741
# running_acc  :  0.87109375
# corrects: 223.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0018812199964621428
# running_acc  :  0.8224783415841584
# corrects: 21266.000000 | total: 25856.000000
# train Loss : 0.0019
# train Acc : 0.8198
# TRAIN EPOCH corrects: 36429.000000 | total: 44438.000000
# val Loss : 0.0030
# val Acc : 0.7382
# VAL EPOCH corrects: 3645.000000 | total: 4938.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0015597172314301133
# running_acc  :  0.84765625
# corrects: 217.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0017867939578977846
# running_acc  :  0.8334622524752475
# corrects: 21550.000000 | total: 25856.000000
# train Loss : 0.0018
# train Acc : 0.8303
# TRAIN EPOCH corrects: 36899.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7080
# VAL EPOCH corrects: 3496.000000 | total: 4938.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.0017980493139475584
# running_acc  :  0.8359375
# corrects: 214.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0016914988731928538
# running_acc  :  0.8403465346534653
# corrects: 21728.000000 | total: 25856.000000
# train Loss : 0.0017
# train Acc : 0.8377
# TRAIN EPOCH corrects: 37224.000000 | total: 44438.000000
# val Loss : 0.0038
# val Acc : 0.6916
# VAL EPOCH corrects: 3415.000000 | total: 4938.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.0015579215250909328
# running_acc  :  0.8515625
# corrects: 218.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0016503973638104035
# running_acc  :  0.8427444306930693
# corrects: 21790.000000 | total: 25856.000000
# train Loss : 0.0017
# train Acc : 0.8417
# TRAIN EPOCH corrects: 37402.000000 | total: 44438.000000
# val Loss : 0.0038
# val Acc : 0.6942
# VAL EPOCH corrects: 3428.000000 | total: 4938.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.001189877511933446
# running_acc  :  0.8828125
# corrects: 226.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0015449853767272048
# running_acc  :  0.8525680693069307
# corrects: 22044.000000 | total: 25856.000000
# train Loss : 0.0016
# train Acc : 0.8500
# TRAIN EPOCH corrects: 37772.000000 | total: 44438.000000
# val Loss : 0.0044
# val Acc : 0.6640
# VAL EPOCH corrects: 3279.000000 | total: 4938.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.0015340400859713554
# running_acc  :  0.87109375
# corrects: 223.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.001477176233628156
# running_acc  :  0.8609220297029703
# corrects: 22260.000000 | total: 25856.000000
# train Loss : 0.0015
# train Acc : 0.8589
# TRAIN EPOCH corrects: 38168.000000 | total: 44438.000000
# val Loss : 0.0053
# val Acc : 0.6355
# VAL EPOCH corrects: 3138.000000 | total: 4938.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.001474063959904015
# running_acc  :  0.8671875
# corrects: 222.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0013863355184139886
# running_acc  :  0.8693146658415841
# corrects: 22477.000000 | total: 25856.000000
# train Loss : 0.0014
# train Acc : 0.8675
# TRAIN EPOCH corrects: 38549.000000 | total: 44438.000000
# val Loss : 0.0050
# val Acc : 0.6574
# VAL EPOCH corrects: 3246.000000 | total: 4938.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.0015097587602213025
# running_acc  :  0.86328125
# corrects: 221.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0013179837231579615
# running_acc  :  0.8788288985148515
# corrects: 22723.000000 | total: 25856.000000
# train Loss : 0.0014
# train Acc : 0.8758
# TRAIN EPOCH corrects: 38919.000000 | total: 44438.000000
# val Loss : 0.0050
# val Acc : 0.6539
# VAL EPOCH corrects: 3229.000000 | total: 4938.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  0.0010486594401299953
# running_acc  :  0.88671875
# corrects: 227.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.00126580594310371
# running_acc  :  0.8833926361386139
# corrects: 22841.000000 | total: 25856.000000
# train Loss : 0.0013
# train Acc : 0.8773
# TRAIN EPOCH corrects: 38985.000000 | total: 44438.000000
# val Loss : 0.0055
# val Acc : 0.6430
# VAL EPOCH corrects: 3175.000000 | total: 4938.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  0.001101747271604836
# running_acc  :  0.90234375
# corrects: 231.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0011988096555814811
# running_acc  :  0.887762995049505
# corrects: 22954.000000 | total: 25856.000000
# train Loss : 0.0012
# train Acc : 0.8848
# TRAIN EPOCH corrects: 39319.000000 | total: 44438.000000
# val Loss : 0.0058
# val Acc : 0.6426
# VAL EPOCH corrects: 3173.000000 | total: 4938.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  0.0012826758902519941
# running_acc  :  0.90234375
# corrects: 231.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0011779965220784566
# running_acc  :  0.8918626237623762
# corrects: 23060.000000 | total: 25856.000000
# train Loss : 0.0012
# train Acc : 0.8861
# TRAIN EPOCH corrects: 39375.000000 | total: 44438.000000
# val Loss : 0.0057
# val Acc : 0.6333
# VAL EPOCH corrects: 3127.000000 | total: 4938.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  0.0012600466143339872
# running_acc  :  0.8828125
# corrects: 226.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.001131667681776061
# running_acc  :  0.8968517945544554
# corrects: 23189.000000 | total: 25856.000000
# train Loss : 0.0012
# train Acc : 0.8931
# TRAIN EPOCH corrects: 39688.000000 | total: 44438.000000
# val Loss : 0.0057
# val Acc : 0.6474
# VAL EPOCH corrects: 3197.000000 | total: 4938.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  0.0008798713097348809
# running_acc  :  0.91015625
# corrects: 233.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0010708039666821093
# running_acc  :  0.9026144801980198
# corrects: 23338.000000 | total: 25856.000000
# train Loss : 0.0011
# train Acc : 0.8966
# TRAIN EPOCH corrects: 39845.000000 | total: 44438.000000
# val Loss : 0.0049
# val Acc : 0.6493
# VAL EPOCH corrects: 3206.000000 | total: 4938.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  0.0008277692832052708
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0010579908237847878
# running_acc  :  0.9041615099009901
# corrects: 23378.000000 | total: 25856.000000
# train Loss : 0.0011
# train Acc : 0.9024
# TRAIN EPOCH corrects: 40100.000000 | total: 44438.000000
# val Loss : 0.0060
# val Acc : 0.6405
# VAL EPOCH corrects: 3163.000000 | total: 4938.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  0.000933481496758759
# running_acc  :  0.91796875
# corrects: 235.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0010141476062080353
# running_acc  :  0.9075649752475248
# corrects: 23466.000000 | total: 25856.000000
# train Loss : 0.0010
# train Acc : 0.9054
# TRAIN EPOCH corrects: 40233.000000 | total: 44438.000000
# val Loss : 0.0056
# val Acc : 0.6460
# VAL EPOCH corrects: 3190.000000 | total: 4938.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  0.0012433272786438465
# running_acc  :  0.89453125
# corrects: 229.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0009666462267500044
# running_acc  :  0.9123220915841584
# corrects: 23589.000000 | total: 25856.000000
# train Loss : 0.0010
# train Acc : 0.9085
# TRAIN EPOCH corrects: 40372.000000 | total: 44438.000000
# val Loss : 0.0058
# val Acc : 0.6373
# VAL EPOCH corrects: 3147.000000 | total: 4938.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  0.0007691193022765219
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0009707895454508022
# running_acc  :  0.9135597153465347
# corrects: 23621.000000 | total: 25856.000000
# train Loss : 0.0010
# train Acc : 0.9118
# TRAIN EPOCH corrects: 40518.000000 | total: 44438.000000
# val Loss : 0.0056
# val Acc : 0.6385
# VAL EPOCH corrects: 3153.000000 | total: 4938.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  0.0005847937427461147
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0009213234966454825
# running_acc  :  0.9162283415841584
# corrects: 23690.000000 | total: 25856.000000
# train Loss : 0.0010
# train Acc : 0.9128
# TRAIN EPOCH corrects: 40563.000000 | total: 44438.000000
# val Loss : 0.0063
# val Acc : 0.6306
# VAL EPOCH corrects: 3114.000000 | total: 4938.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  0.0010032932041212916
# running_acc  :  0.92578125
# corrects: 237.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008823756545800532
# running_acc  :  0.9211788366336634
# corrects: 23818.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9168
# TRAIN EPOCH corrects: 40742.000000 | total: 44438.000000
# val Loss : 0.0049
# val Acc : 0.6620
# VAL EPOCH corrects: 3269.000000 | total: 4938.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  0.0008135513635352254
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008729132483621119
# running_acc  :  0.9225711633663366
# corrects: 23854.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9193
# TRAIN EPOCH corrects: 40854.000000 | total: 44438.000000
# val Loss : 0.0051
# val Acc : 0.6634
# VAL EPOCH corrects: 3276.000000 | total: 4938.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  0.0005258810706436634
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008568567552921906
# running_acc  :  0.9231512995049505
# corrects: 23869.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9210
# TRAIN EPOCH corrects: 40926.000000 | total: 44438.000000
# val Loss : 0.0054
# val Acc : 0.6569
# VAL EPOCH corrects: 3244.000000 | total: 4938.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  0.0008273457060568035
# running_acc  :  0.91796875
# corrects: 235.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008354437638922493
# running_acc  :  0.9261680074257426
# corrects: 23947.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9240
# TRAIN EPOCH corrects: 41061.000000 | total: 44438.000000
# val Loss : 0.0053
# val Acc : 0.6553
# VAL EPOCH corrects: 3236.000000 | total: 4938.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  0.0007819195743650198
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008416552105826317
# running_acc  :  0.9253558168316832
# corrects: 23926.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9220
# TRAIN EPOCH corrects: 40972.000000 | total: 44438.000000
# val Loss : 0.0051
# val Acc : 0.6539
# VAL EPOCH corrects: 3229.000000 | total: 4938.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  0.0007243385771289468
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008082625903949916
# running_acc  :  0.9260519801980198
# corrects: 23944.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9259
# TRAIN EPOCH corrects: 41143.000000 | total: 44438.000000
# val Loss : 0.0049
# val Acc : 0.6531
# VAL EPOCH corrects: 3225.000000 | total: 4938.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  0.0007220794213935733
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007642519618223172
# running_acc  :  0.9316986386138614
# corrects: 24090.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9276
# TRAIN EPOCH corrects: 41221.000000 | total: 44438.000000
# val Loss : 0.0059
# val Acc : 0.6377
# VAL EPOCH corrects: 3149.000000 | total: 4938.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  0.000804662297014147
# running_acc  :  0.92578125
# corrects: 237.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007502527997971946
# running_acc  :  0.932240099009901
# corrects: 24104.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9292
# TRAIN EPOCH corrects: 41293.000000 | total: 44438.000000
# val Loss : 0.0055
# val Acc : 0.6312
# VAL EPOCH corrects: 3117.000000 | total: 4938.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  0.0007494291639886796
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007633341624433784
# running_acc  :  0.9336711014851485
# corrects: 24141.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9322
# TRAIN EPOCH corrects: 41425.000000 | total: 44438.000000
# val Loss : 0.0056
# val Acc : 0.6428
# VAL EPOCH corrects: 3174.000000 | total: 4938.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  0.0005130837089382112
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007404177815602669
# running_acc  :  0.9330522896039604
# corrects: 24125.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9306
# TRAIN EPOCH corrects: 41355.000000 | total: 44438.000000
# val Loss : 0.0050
# val Acc : 0.6657
# VAL EPOCH corrects: 3287.000000 | total: 4938.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  0.0007437249296344817
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007227493737049696
# running_acc  :  0.9367264851485149
# corrects: 24220.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9342
# TRAIN EPOCH corrects: 41516.000000 | total: 44438.000000
# val Loss : 0.0048
# val Acc : 0.6703
# VAL EPOCH corrects: 3310.000000 | total: 4938.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  0.0006236637127585709
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007233398855262721
# running_acc  :  0.9365331064356436
# corrects: 24215.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9339
# TRAIN EPOCH corrects: 41499.000000 | total: 44438.000000
# val Loss : 0.0041
# val Acc : 0.6881
# VAL EPOCH corrects: 3398.000000 | total: 4938.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  0.0007840694743208587
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007045468390979205
# running_acc  :  0.9380414603960396
# corrects: 24254.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9363
# TRAIN EPOCH corrects: 41608.000000 | total: 44438.000000
# val Loss : 0.0040
# val Acc : 0.6930
# VAL EPOCH corrects: 3422.000000 | total: 4938.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  0.0005904017598368227
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006805514337006256
# running_acc  :  0.9397818688118812
# corrects: 24299.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9379
# TRAIN EPOCH corrects: 41677.000000 | total: 44438.000000
# val Loss : 0.0047
# val Acc : 0.6665
# VAL EPOCH corrects: 3291.000000 | total: 4938.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  0.0004829745157621801
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006874321094289938
# running_acc  :  0.9386215965346535
# corrects: 24269.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9357
# TRAIN EPOCH corrects: 41581.000000 | total: 44438.000000
# val Loss : 0.0045
# val Acc : 0.6754
# VAL EPOCH corrects: 3335.000000 | total: 4938.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  0.0006324726273305714
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006755014442340793
# running_acc  :  0.9405940594059405
# corrects: 24320.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9394
# TRAIN EPOCH corrects: 41745.000000 | total: 44438.000000
# val Loss : 0.0044
# val Acc : 0.6906
# VAL EPOCH corrects: 3410.000000 | total: 4938.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  0.0007818876765668392
# running_acc  :  0.92578125
# corrects: 237.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006911378557849122
# running_acc  :  0.9392017326732673
# corrects: 24284.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9384
# TRAIN EPOCH corrects: 41701.000000 | total: 44438.000000
# val Loss : 0.0047
# val Acc : 0.6764
# VAL EPOCH corrects: 3340.000000 | total: 4938.000000
# Epoch 41/99
# ----------
# Iter :  0
# running_loss :  0.0008556938264518976
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006734435089246029
# running_acc  :  0.9415996287128713
# corrects: 24346.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9389
# TRAIN EPOCH corrects: 41724.000000 | total: 44438.000000
# val Loss : 0.0047
# val Acc : 0.6804
# VAL EPOCH corrects: 3360.000000 | total: 4938.000000
# Epoch 42/99
# ----------
# Iter :  0
# running_loss :  0.0007284030434675515
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006486730250105778
# running_acc  :  0.9429919554455446
# corrects: 24382.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9406
# TRAIN EPOCH corrects: 41799.000000 | total: 44438.000000
# val Loss : 0.0048
# val Acc : 0.6655
# VAL EPOCH corrects: 3286.000000 | total: 4938.000000
# Epoch 43/99
# ----------
# Iter :  0
# running_loss :  0.0005631716921925545
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006273497584146807
# running_acc  :  0.9468208539603961
# corrects: 24481.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9446
# TRAIN EPOCH corrects: 41978.000000 | total: 44438.000000
# val Loss : 0.0050
# val Acc : 0.6533
# VAL EPOCH corrects: 3226.000000 | total: 4938.000000
# Epoch 44/99
# ----------
# Iter :  0
# running_loss :  0.0007552779861725867
# running_acc  :  0.91796875
# corrects: 235.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006474985477127282
# running_acc  :  0.9453511757425742
# corrects: 24443.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9434
# TRAIN EPOCH corrects: 41924.000000 | total: 44438.000000
# val Loss : 0.0046
# val Acc : 0.6804
# VAL EPOCH corrects: 3360.000000 | total: 4938.000000
# Epoch 45/99
# ----------
# Iter :  0
# running_loss :  0.000517929729539901
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006462472276577707
# running_acc  :  0.9427985767326733
# corrects: 24377.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9419
# TRAIN EPOCH corrects: 41858.000000 | total: 44438.000000
# val Loss : 0.0046
# val Acc : 0.6750
# VAL EPOCH corrects: 3333.000000 | total: 4938.000000
# Epoch 46/99
# ----------
# Iter :  0
# running_loss :  0.0004963233368471265
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006533148989547044
# running_acc  :  0.9439201732673267
# corrects: 24406.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9421
# TRAIN EPOCH corrects: 41864.000000 | total: 44438.000000
# val Loss : 0.0042
# val Acc : 0.7084
# VAL EPOCH corrects: 3498.000000 | total: 4938.000000
# Epoch 47/99
# ----------
# Iter :  0
# running_loss :  0.00038669619243592024
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006172740549577566
# running_acc  :  0.9470142326732673
# corrects: 24486.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9437
# TRAIN EPOCH corrects: 41934.000000 | total: 44438.000000
# val Loss : 0.0043
# val Acc : 0.6934
# VAL EPOCH corrects: 3424.000000 | total: 4938.000000
# Epoch 48/99
# ----------
# Iter :  0
# running_loss :  0.0005182818276807666
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006243164915047439
# running_acc  :  0.9468208539603961
# corrects: 24481.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9449
# TRAIN EPOCH corrects: 41989.000000 | total: 44438.000000
# val Loss : 0.0043
# val Acc : 0.6833
# VAL EPOCH corrects: 3374.000000 | total: 4938.000000
# Epoch 49/99
# ----------
# Iter :  0
# running_loss :  0.0004617065715137869
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000599643745457311
# running_acc  :  0.9472462871287128
# corrects: 24492.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9445
# TRAIN EPOCH corrects: 41973.000000 | total: 44438.000000
# val Loss : 0.0038
# val Acc : 0.7122
# VAL EPOCH corrects: 3517.000000 | total: 4938.000000
# Epoch 50/99
# ----------
# Iter :  0
# running_loss :  0.0007242359570227563
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005897009318191927
# running_acc  :  0.9479424504950495
# corrects: 24510.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9463
# TRAIN EPOCH corrects: 42052.000000 | total: 44438.000000
# val Loss : 0.0046
# val Acc : 0.6792
# VAL EPOCH corrects: 3354.000000 | total: 4938.000000
# Epoch 51/99
# ----------
# Iter :  0
# running_loss :  0.0006394824013113976
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006423924797753997
# running_acc  :  0.9448097153465347
# corrects: 24429.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9446
# TRAIN EPOCH corrects: 41976.000000 | total: 44438.000000
# val Loss : 0.0040
# val Acc : 0.7072
# VAL EPOCH corrects: 3492.000000 | total: 4938.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  0.0006927387439645827
# running_acc  :  0.9296875
# corrects: 238.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006032557457819176
# running_acc  :  0.9490640470297029
# corrects: 24539.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9475
# TRAIN EPOCH corrects: 42103.000000 | total: 44438.000000
# val Loss : 0.0036
# val Acc : 0.7361
# VAL EPOCH corrects: 3635.000000 | total: 4938.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  0.00036628227098844945
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000607999936691347
# running_acc  :  0.9469368811881188
# corrects: 24484.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9462
# TRAIN EPOCH corrects: 42048.000000 | total: 44438.000000
# val Loss : 0.0040
# val Acc : 0.7082
# VAL EPOCH corrects: 3497.000000 | total: 4938.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  0.0003214552125427872
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006091131584944738
# running_acc  :  0.9477877475247525
# corrects: 24506.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9470
# TRAIN EPOCH corrects: 42081.000000 | total: 44438.000000
# val Loss : 0.0039
# val Acc : 0.7238
# VAL EPOCH corrects: 3574.000000 | total: 4938.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  0.0004583497066050768
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000578897380751862
# running_acc  :  0.9487933168316832
# corrects: 24532.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9464
# TRAIN EPOCH corrects: 42056.000000 | total: 44438.000000
# val Loss : 0.0042
# val Acc : 0.6968
# VAL EPOCH corrects: 3441.000000 | total: 4938.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  0.00037211563903838396
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005882872216113023
# running_acc  :  0.9494894801980198
# corrects: 24550.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9485
# TRAIN EPOCH corrects: 42150.000000 | total: 44438.000000
# val Loss : 0.0037
# val Acc : 0.7343
# VAL EPOCH corrects: 3626.000000 | total: 4938.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  0.00046320550609380007
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005892398539529467
# running_acc  :  0.9486386138613861
# corrects: 24528.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9479
# TRAIN EPOCH corrects: 42123.000000 | total: 44438.000000
# val Loss : 0.0043
# val Acc : 0.6960
# VAL EPOCH corrects: 3437.000000 | total: 4938.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  0.0004948059795424342
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005666432924693137
# running_acc  :  0.9516166460396039
# corrects: 24605.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9492
# TRAIN EPOCH corrects: 42180.000000 | total: 44438.000000
# val Loss : 0.0043
# val Acc : 0.6869
# VAL EPOCH corrects: 3392.000000 | total: 4938.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  0.00043717160588130355
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005835162845698398
# running_acc  :  0.9486772896039604
# corrects: 24529.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9469
# TRAIN EPOCH corrects: 42080.000000 | total: 44438.000000
# val Loss : 0.0040
# val Acc : 0.7043
# VAL EPOCH corrects: 3478.000000 | total: 4938.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  0.0007252409704960883
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005611376557383907
# running_acc  :  0.9521581064356436
# corrects: 24619.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9506
# TRAIN EPOCH corrects: 42241.000000 | total: 44438.000000
# val Loss : 0.0041
# val Acc : 0.7116
# VAL EPOCH corrects: 3514.000000 | total: 4938.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  0.0008245049393735826
# running_acc  :  0.92578125
# corrects: 237.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005960760947598126
# running_acc  :  0.9484839108910891
# corrects: 24524.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9475
# TRAIN EPOCH corrects: 42105.000000 | total: 44438.000000
# val Loss : 0.0035
# val Acc : 0.7305
# VAL EPOCH corrects: 3607.000000 | total: 4938.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  0.000525960058439523
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005542506324934156
# running_acc  :  0.9521967821782178
# corrects: 24620.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9487
# TRAIN EPOCH corrects: 42158.000000 | total: 44438.000000
# val Loss : 0.0036
# val Acc : 0.7418
# VAL EPOCH corrects: 3663.000000 | total: 4938.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  0.0002959295525215566
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005695458045137106
# running_acc  :  0.9497988861386139
# corrects: 24558.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9492
# TRAIN EPOCH corrects: 42179.000000 | total: 44438.000000
# val Loss : 0.0036
# val Acc : 0.7230
# VAL EPOCH corrects: 3570.000000 | total: 4938.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  0.0005019994569011033
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005580726342441717
# running_acc  :  0.9524675123762376
# corrects: 24627.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9504
# TRAIN EPOCH corrects: 42232.000000 | total: 44438.000000
# val Loss : 0.0038
# val Acc : 0.7114
# VAL EPOCH corrects: 3513.000000 | total: 4938.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  0.0006984584033489227
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005623746411482997
# running_acc  :  0.9515006188118812
# corrects: 24602.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9489
# TRAIN EPOCH corrects: 42165.000000 | total: 44438.000000
# val Loss : 0.0038
# val Acc : 0.7175
# VAL EPOCH corrects: 3543.000000 | total: 4938.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  0.0002962964354082942
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005491528323491906
# running_acc  :  0.9520034034653465
# corrects: 24615.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9502
# TRAIN EPOCH corrects: 42227.000000 | total: 44438.000000
# val Loss : 0.0035
# val Acc : 0.7418
# VAL EPOCH corrects: 3663.000000 | total: 4938.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  0.0005424087285064161
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000560760691111889
# running_acc  :  0.9506110767326733
# corrects: 24579.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9503
# TRAIN EPOCH corrects: 42229.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7327
# VAL EPOCH corrects: 3618.000000 | total: 4938.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  0.0005644398042932153
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005278301618055044
# running_acc  :  0.9535504331683168
# corrects: 24655.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9520
# TRAIN EPOCH corrects: 42305.000000 | total: 44438.000000
# val Loss : 0.0035
# val Acc : 0.7402
# VAL EPOCH corrects: 3655.000000 | total: 4938.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  0.0006937021389603615
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005594508043527234
# running_acc  :  0.9515392945544554
# corrects: 24603.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9508
# TRAIN EPOCH corrects: 42252.000000 | total: 44438.000000
# val Loss : 0.0035
# val Acc : 0.7323
# VAL EPOCH corrects: 3616.000000 | total: 4938.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  0.00042195303831249475
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005319466042715023
# running_acc  :  0.9540918935643564
# corrects: 24669.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9511
# TRAIN EPOCH corrects: 42267.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7475
# VAL EPOCH corrects: 3691.000000 | total: 4938.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  0.0004970483714714646
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005541058743630748
# running_acc  :  0.953125
# corrects: 24644.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9513
# TRAIN EPOCH corrects: 42273.000000 | total: 44438.000000
# val Loss : 0.0037
# val Acc : 0.7201
# VAL EPOCH corrects: 3556.000000 | total: 4938.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  0.00033414625795558095
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005549594830827658
# running_acc  :  0.9530863242574258
# corrects: 24643.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9520
# TRAIN EPOCH corrects: 42304.000000 | total: 44438.000000
# val Loss : 0.0040
# val Acc : 0.7128
# VAL EPOCH corrects: 3520.000000 | total: 4938.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  0.0005673455307260156
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000524750502381271
# running_acc  :  0.9554455445544554
# corrects: 24704.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9517
# TRAIN EPOCH corrects: 42293.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7394
# VAL EPOCH corrects: 3651.000000 | total: 4938.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  0.0006232308223843575
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005673839830814188
# running_acc  :  0.9517326732673267
# corrects: 24608.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9503
# TRAIN EPOCH corrects: 42230.000000 | total: 44438.000000
# val Loss : 0.0041
# val Acc : 0.6979
# VAL EPOCH corrects: 3446.000000 | total: 4938.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  0.0006505659548565745
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005582518291217044
# running_acc  :  0.9525448638613861
# corrects: 24629.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9507
# TRAIN EPOCH corrects: 42245.000000 | total: 44438.000000
# val Loss : 0.0036
# val Acc : 0.7264
# VAL EPOCH corrects: 3587.000000 | total: 4938.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  0.0003966964432038367
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005370956839242083
# running_acc  :  0.9540532178217822
# corrects: 24668.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9530
# TRAIN EPOCH corrects: 42348.000000 | total: 44438.000000
# val Loss : 0.0035
# val Acc : 0.7392
# VAL EPOCH corrects: 3650.000000 | total: 4938.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  0.0003314047062303871
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005398010111778126
# running_acc  :  0.9532797029702971
# corrects: 24648.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9515
# TRAIN EPOCH corrects: 42283.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7458
# VAL EPOCH corrects: 3683.000000 | total: 4938.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  0.00031679283711127937
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005351048724214076
# running_acc  :  0.9559096534653465
# corrects: 24716.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9546
# TRAIN EPOCH corrects: 42421.000000 | total: 44438.000000
# val Loss : 0.0036
# val Acc : 0.7353
# VAL EPOCH corrects: 3631.000000 | total: 4938.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  0.0005301853525452316
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005556816305206756
# running_acc  :  0.9512298886138614
# corrects: 24595.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9510
# TRAIN EPOCH corrects: 42262.000000 | total: 44438.000000
# val Loss : 0.0035
# val Acc : 0.7341
# VAL EPOCH corrects: 3625.000000 | total: 4938.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  0.0006357852253131568
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005191346462746842
# running_acc  :  0.9552908415841584
# corrects: 24700.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9532
# TRAIN EPOCH corrects: 42358.000000 | total: 44438.000000
# val Loss : 0.0035
# val Acc : 0.7580
# VAL EPOCH corrects: 3743.000000 | total: 4938.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  0.0003936390858143568
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005300524785750463
# running_acc  :  0.9537438118811881
# corrects: 24660.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9525
# TRAIN EPOCH corrects: 42328.000000 | total: 44438.000000
# val Loss : 0.0033
# val Acc : 0.7452
# VAL EPOCH corrects: 3680.000000 | total: 4938.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  0.0005505176959559321
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005190841564597415
# running_acc  :  0.9545946782178217
# corrects: 24682.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9525
# TRAIN EPOCH corrects: 42327.000000 | total: 44438.000000
# val Loss : 0.0033
# val Acc : 0.7347
# VAL EPOCH corrects: 3628.000000 | total: 4938.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  0.0007236494566313922
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005354225902938017
# running_acc  :  0.9533570544554455
# corrects: 24650.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9513
# TRAIN EPOCH corrects: 42273.000000 | total: 44438.000000
# val Loss : 0.0033
# val Acc : 0.7416
# VAL EPOCH corrects: 3662.000000 | total: 4938.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  0.0005280420882627368
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005252929712705646
# running_acc  :  0.9549814356435643
# corrects: 24692.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9525
# TRAIN EPOCH corrects: 42327.000000 | total: 44438.000000
# val Loss : 0.0031
# val Acc : 0.7616
# VAL EPOCH corrects: 3761.000000 | total: 4938.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  0.0003752749471459538
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005367315347804365
# running_acc  :  0.9552521658415841
# corrects: 24699.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9539
# TRAIN EPOCH corrects: 42389.000000 | total: 44438.000000
# val Loss : 0.0032
# val Acc : 0.7614
# VAL EPOCH corrects: 3760.000000 | total: 4938.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  0.0005596654373221099
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005061264878304878
# running_acc  :  0.955677599009901
# corrects: 24710.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9556
# TRAIN EPOCH corrects: 42464.000000 | total: 44438.000000
# val Loss : 0.0035
# val Acc : 0.7718
# VAL EPOCH corrects: 3811.000000 | total: 4938.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  0.00042313727317377925
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005073824116215571
# running_acc  :  0.9559096534653465
# corrects: 24716.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9541
# TRAIN EPOCH corrects: 42400.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7552
# VAL EPOCH corrects: 3729.000000 | total: 4938.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  0.0008675386779941618
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005058275420728167
# running_acc  :  0.9565671410891089
# corrects: 24733.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9545
# TRAIN EPOCH corrects: 42417.000000 | total: 44438.000000
# val Loss : 0.0032
# val Acc : 0.7663
# VAL EPOCH corrects: 3784.000000 | total: 4938.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  0.0006819925038143992
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005078291365448016
# running_acc  :  0.9562577351485149
# corrects: 24725.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9552
# TRAIN EPOCH corrects: 42448.000000 | total: 44438.000000
# val Loss : 0.0037
# val Acc : 0.7333
# VAL EPOCH corrects: 3621.000000 | total: 4938.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  0.00039196870056912303
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005203951918116614
# running_acc  :  0.9548654084158416
# corrects: 24689.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9536
# TRAIN EPOCH corrects: 42375.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7380
# VAL EPOCH corrects: 3644.000000 | total: 4938.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  0.0004260066489223391
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005401300459738249
# running_acc  :  0.9534730816831684
# corrects: 24653.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9534
# TRAIN EPOCH corrects: 42369.000000 | total: 44438.000000
# val Loss : 0.0037
# val Acc : 0.7252
# VAL EPOCH corrects: 3581.000000 | total: 4938.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  0.00047763955080881715
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000523724830375136
# running_acc  :  0.9560256806930693
# corrects: 24719.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9524
# TRAIN EPOCH corrects: 42322.000000 | total: 44438.000000
# val Loss : 0.0037
# val Acc : 0.7276
# VAL EPOCH corrects: 3593.000000 | total: 4938.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  0.0005501187406480312
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005062152320371553
# running_acc  :  0.9561030321782178
# corrects: 24721.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9552
# TRAIN EPOCH corrects: 42446.000000 | total: 44438.000000
# val Loss : 0.0037
# val Acc : 0.7139
# VAL EPOCH corrects: 3525.000000 | total: 4938.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  0.0005603631143458188
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005257702990156128
# running_acc  :  0.9557549504950495
# corrects: 24712.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9536
# TRAIN EPOCH corrects: 42377.000000 | total: 44438.000000
# val Loss : 0.0032
# val Acc : 0.7602
# VAL EPOCH corrects: 3754.000000 | total: 4938.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  0.00046870202641002834
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005450940965836186
# running_acc  :  0.9537438118811881
# corrects: 24660.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9517
# TRAIN EPOCH corrects: 42291.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7495
# VAL EPOCH corrects: 3701.000000 | total: 4938.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  0.0007331243250519037
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005160062210772666
# running_acc  :  0.9549427599009901
# corrects: 24691.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9538
# TRAIN EPOCH corrects: 42386.000000 | total: 44438.000000
# val Loss : 0.0037
# val Acc : 0.7375
# VAL EPOCH corrects: 3642.000000 | total: 4938.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  0.0006945098866708577
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005012815792256468
# running_acc  :  0.9566444925742574
# corrects: 24735.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9549
# TRAIN EPOCH corrects: 42433.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7539
# VAL EPOCH corrects: 3723.000000 | total: 4938.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  0.0004167445295024663
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005130023133046556
# running_acc  :  0.9572246287128713
# corrects: 24750.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9555
# TRAIN EPOCH corrects: 42461.000000 | total: 44438.000000
# val Loss : 0.0036
# val Acc : 0.7240
# VAL EPOCH corrects: 3575.000000 | total: 4938.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  0.0003596720052883029
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005210505453823595
# running_acc  :  0.955987004950495
# corrects: 24718.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9540
# TRAIN EPOCH corrects: 42394.000000 | total: 44438.000000
# val Loss : 0.0034
# val Acc : 0.7519
# VAL EPOCH corrects: 3713.000000 | total: 4938.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.5883086838505485
# EVAL ACC :  0.768726079825041
# Predictions | Labels
# [[ 6  6]
#  [ 1  1]
#  [ 8  8]
#  [ 8  9]
#  [ 8  9]
#  [ 9  9]
#  [10  0]
#  [ 9  9]
#  [ 9  9]
#  [ 9  9]
#  [ 8  8]
#  [10  0]
#  [ 1  1]
#  [ 7  7]
#  [ 8  8]]
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scnym\api.py:427: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['scNym_train_results'] = results
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 11 classes from 2000 features
# ['CD14+ Monocyte' 'CD19+ B' 'CD34+' 'CD4+ T Helper2' 'CD4+/CD25 T Reg'
#  'CD4+/CD45RA+/CD25- Naive T' 'CD4+/CD45RO+ Memory' 'CD56+ NK'
#  'CD8+ Cytotoxic T' 'CD8+/CD45RA+ Naive Cytotoxic' 'Dendritic']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 14/14 [00:00<00:00, 26.77it/s]
# Extracting model embeddings...
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scnym\api.py:550: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs[config['key_added']] = names
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 8
#       5 for fold_idx in range(5):
#       6     fold = fold_idx + 1
# ----> 8     adata_train, adata_test = split_data(data_path=data_path, fold=fold)
#      10     # Train model
#      11     scnym_api(
#      12         adata=adata_train,
#      13         task='train',
#    (...)
#      16         config='no_new_identity',
#      17     )
#
# Cell In[2], line 10, in split_data(data_path, fold, folds, batch_key, label_key, seed, HVG, HVGs)
#       1 def split_data(data_path: str,
#       2                fold: int=1,
#       3                folds: int=5,
#    (...)
#       7                HVG: bool=True,
#       8                HVGs: int=2000):
# ---> 10     adata = sc.read(data_path, cache=True)
#      12     adata.obs["batch"] = adata.obs[batch_key]
#      14     # Ensure reproducibility
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\readwrite.py:111, in read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, **kwargs)
#     109 filename = Path(filename)  # allow passing strings
#     110 if is_valid_filename(filename):
# --> 111     return _read(
#     112         filename,
#     113         backed=backed,
#     114         sheet=sheet,
#     115         ext=ext,
#     116         delimiter=delimiter,
#     117         first_column_names=first_column_names,
#     118         backup_url=backup_url,
#     119         cache=cache,
#     120         cache_compression=cache_compression,
#     121         **kwargs,
#     122     )
#     123 # generate filename and read to dict
#     124 filekey = str(filename)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\readwrite.py:721, in _read(filename, backed, sheet, ext, delimiter, first_column_names, backup_url, cache, cache_compression, suppress_cache_warning, **kwargs)
#     719 if ext in {'h5', 'h5ad'}:
#     720     if sheet is None:
# --> 721         return read_h5ad(filename, backed=backed)
#     722     else:
#     723         logg.debug(f'reading sheet {sheet} from file {filename}')
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:56, in read(*args, **kwargs)
#      49 import warnings
#      51 warnings.warn(
#      52     "`anndata.read` is deprecated, use `anndata.read_h5ad` instead. "
#      53     "`ad.read` will be removed in mid 2024.",
#      54     FutureWarning,
#      55 )
# ---> 56 return read_h5ad(*args, **kwargs)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\h5ad.py:261, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     258         return read_dataframe(elem)
#     259     return func(elem)
# --> 261 adata = read_dispatched(f, callback=callback)
#     263 # Backwards compat (should figure out which version)
#     264 if "raw.X" in f:
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\experimental\_dispatch_io.py:48, in read_dispatched(elem, callback)
#      44 from anndata._io.specs import _REGISTRY, Reader
#      46 reader = Reader(_REGISTRY, callback=callback)
# ---> 48 return reader.read_elem(elem)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\utils.py:207, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     205     raise ValueError("No element found in args.")
#     206 try:
# --> 207     return func(*args, **kwargs)
#     208 except Exception as e:
#     209     path, key = _get_display_path(store).rsplit("/", 1)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\specs\registry.py:256, in Reader.read_elem(self, elem, modifiers)
#     254 if self.callback is None:
#     255     return read_func(elem)
# --> 256 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\h5ad.py:242, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     239 def callback(func, elem_name: str, elem, iospec):
#     240     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     241         return AnnData(
# --> 242             **{
#     243                 # This is covering up backwards compat in the anndata initializer
#     244                 # In most cases we should be able to call `func(elen[k])` instead
#     245                 k: read_dispatched(elem[k], callback)
#     246                 for k in elem.keys()
#     247                 if not k.startswith("raw.")
#     248             }
#     249         )
#     250     elif elem_name.startswith("/raw."):
#     251         return None
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\h5ad.py:245, in <dictcomp>(.0)
#     239 def callback(func, elem_name: str, elem, iospec):
#     240     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     241         return AnnData(
#     242             **{
#     243                 # This is covering up backwards compat in the anndata initializer
#     244                 # In most cases we should be able to call `func(elen[k])` instead
# --> 245                 k: read_dispatched(elem[k], callback)
#     246                 for k in elem.keys()
#     247                 if not k.startswith("raw.")
#     248             }
#     249         )
#     250     elif elem_name.startswith("/raw."):
#     251         return None
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\experimental\_dispatch_io.py:48, in read_dispatched(elem, callback)
#      44 from anndata._io.specs import _REGISTRY, Reader
#      46 reader = Reader(_REGISTRY, callback=callback)
# ---> 48 return reader.read_elem(elem)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\utils.py:207, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     205     raise ValueError("No element found in args.")
#     206 try:
# --> 207     return func(*args, **kwargs)
#     208 except Exception as e:
#     209     path, key = _get_display_path(store).rsplit("/", 1)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\specs\registry.py:256, in Reader.read_elem(self, elem, modifiers)
#     254 if self.callback is None:
#     255     return read_func(elem)
# --> 256 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\h5ad.py:259, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     256 elif elem_name in {"/obs", "/var"}:
#     257     # Backwards compat
#     258     return read_dataframe(elem)
# --> 259 return func(elem)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\specs\methods.py:304, in read_mapping(elem, _reader)
#     301 @_REGISTRY.register_read(H5Group, IOSpec("dict", "0.1.0"))
#     302 @_REGISTRY.register_read(ZarrGroup, IOSpec("dict", "0.1.0"))
#     303 def read_mapping(elem, _reader):
# --> 304     return {k: _reader.read_elem(v) for k, v in elem.items()}
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\specs\methods.py:304, in <dictcomp>(.0)
#     301 @_REGISTRY.register_read(H5Group, IOSpec("dict", "0.1.0"))
#     302 @_REGISTRY.register_read(ZarrGroup, IOSpec("dict", "0.1.0"))
#     303 def read_mapping(elem, _reader):
# --> 304     return {k: _reader.read_elem(v) for k, v in elem.items()}
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\utils.py:207, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     205     raise ValueError("No element found in args.")
#     206 try:
# --> 207     return func(*args, **kwargs)
#     208 except Exception as e:
#     209     path, key = _get_display_path(store).rsplit("/", 1)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\specs\registry.py:256, in Reader.read_elem(self, elem, modifiers)
#     254 if self.callback is None:
#     255     return read_func(elem)
# --> 256 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\h5ad.py:259, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     256 elif elem_name in {"/obs", "/var"}:
#     257     # Backwards compat
#     258     return read_dataframe(elem)
# --> 259 return func(elem)
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_io\specs\methods.py:378, in read_array(elem, _reader)
#     374 @_REGISTRY.register_read(H5Array, IOSpec("array", "0.2.0"))
#     375 @_REGISTRY.register_read(ZarrArray, IOSpec("array", "0.2.0"))
#     376 @_REGISTRY.register_read(ZarrArray, IOSpec("string-array", "0.2.0"))
#     377 def read_array(elem, _reader):
# --> 378     return elem[()]
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\h5py\_hl\dataset.py:758, in Dataset.__getitem__(self, args, new_dtype)
#     756 if self._fast_read_ok and (new_dtype is None):
#     757     try:
# --> 758         return self._fast_reader.read(args)
#     759     except TypeError:
#     760         pass  # Fall back to Python read pathway below
#
# File h5py\_selector.pyx:368, in h5py._selector.Reader.read()
#
# File h5py\_selector.pyx:342, in h5py._selector.Reader.make_array()
#
# MemoryError: Unable to allocate 7.19 GiB for an array with shape (68579, 14066) and data type float64
# Error raised while reading key 'log1p_counts' of <class 'h5py._hl.dataset.Dataset'> from /layers

# %%
results = pd.read_csv('results/scNym_hvgs_output.csv', index_col=0)

# %%
data_path = "../../../data/processed/data_for_evaluating_cell_type_annotation/Zheng68k.h5ad"

# Iterate through folds
fold = 5

adata_train, adata_test = split_data(data_path=data_path, fold=fold)

# Train model
scnym_api(
    adata=adata_train,
    task='train',
    groupby='cell_type',
    out_path='./scnym_outputs',
    config='no_new_identity',
)

# Predict test data
scnym_api(
    adata=adata_test,
    task='predict',
    key_added='scNym',
    config='no_new_identity',
    trained_model='./scnym_outputs'
)

# Save results in dataframe
if fold == 1:
    results = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                            "true_label": adata_test.obs["cell_type"].to_list(), 
                            "fold": [fold]*adata_test.obs['scNym'].shape[0]})
else:   
    dataframe_temp = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                "true_label": adata_test.obs["cell_type"].to_list(), 
                                "fold": [fold]*adata_test.obs['scNym'].shape[0]})
    results = pd.concat([results,dataframe_temp], axis=0)

results.reset_index(drop=True, inplace=True)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:544: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['hvg'] = {'flavor': flavor}
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (54864, 2000)
# y:  (54864,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.010007387027144432
# running_acc  :  0.0703125
# corrects: 18.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0037538731207905135
# running_acc  :  0.6531946163366337
# corrects: 16889.000000 | total: 25856.000000
# train Loss : 0.0034
# train Acc : 0.6786
# TRAIN EPOCH corrects: 30157.000000 | total: 44439.000000
# val Loss : 0.0028
# val Acc : 0.7485
# VAL EPOCH corrects: 3696.000000 | total: 4938.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0022753924131393433
# running_acc  :  0.8125
# corrects: 208.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.002692130182196598
# running_acc  :  0.7427289603960396
# corrects: 19204.000000 | total: 25856.000000
# train Loss : 0.0027
# train Acc : 0.7443
# TRAIN EPOCH corrects: 33075.000000 | total: 44439.000000
# val Loss : 0.0026
# val Acc : 0.7934
# VAL EPOCH corrects: 3918.000000 | total: 4938.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0023351653944700956
# running_acc  :  0.77734375
# corrects: 199.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.002445703619021443
# running_acc  :  0.7647354579207921
# corrects: 19773.000000 | total: 25856.000000
# train Loss : 0.0025
# train Acc : 0.7648
# TRAIN EPOCH corrects: 33985.000000 | total: 44439.000000
# val Loss : 0.0023
# val Acc : 0.8011
# VAL EPOCH corrects: 3956.000000 | total: 4938.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.00243577198125422
# running_acc  :  0.7578125
# corrects: 194.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.002264940401188808
# running_acc  :  0.7835318688118812
# corrects: 20259.000000 | total: 25856.000000
# train Loss : 0.0023
# train Acc : 0.7841
# TRAIN EPOCH corrects: 34845.000000 | total: 44439.000000
# val Loss : 0.0023
# val Acc : 0.8011
# VAL EPOCH corrects: 3956.000000 | total: 4938.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.002295759739354253
# running_acc  :  0.78125
# corrects: 200.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0021587133679612735
# running_acc  :  0.7943997524752475
# corrects: 20540.000000 | total: 25856.000000
# train Loss : 0.0021
# train Acc : 0.7961
# TRAIN EPOCH corrects: 35379.000000 | total: 44439.000000
# val Loss : 0.0022
# val Acc : 0.8107
# VAL EPOCH corrects: 4003.000000 | total: 4938.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.002257015323266387
# running_acc  :  0.796875
# corrects: 204.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.00198720788034509
# running_acc  :  0.8131574876237624
# corrects: 21025.000000 | total: 25856.000000
# train Loss : 0.0020
# train Acc : 0.8098
# TRAIN EPOCH corrects: 35987.000000 | total: 44439.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0025
# val Acc : 0.7774
# VAL EPOCH corrects: 3839.000000 | total: 4938.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.0015639228513464332
# running_acc  :  0.859375
# corrects: 220.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.001861119730453385
# running_acc  :  0.8247602103960396
# corrects: 21325.000000 | total: 25856.000000
# train Loss : 0.0019
# train Acc : 0.8196
# TRAIN EPOCH corrects: 36421.000000 | total: 44439.000000
# val Loss : 0.0028
# val Acc : 0.7511
# VAL EPOCH corrects: 3709.000000 | total: 4938.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.0015259974170476198
# running_acc  :  0.8515625
# corrects: 218.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0017722705217760684
# running_acc  :  0.8319925742574258
# corrects: 21512.000000 | total: 25856.000000
# train Loss : 0.0018
# train Acc : 0.8295
# TRAIN EPOCH corrects: 36862.000000 | total: 44439.000000
# val Loss : 0.0028
# val Acc : 0.7635
# VAL EPOCH corrects: 3770.000000 | total: 4938.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.0013077539624646306
# running_acc  :  0.890625
# corrects: 228.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0016718882938275242
# running_acc  :  0.841197400990099
# corrects: 21750.000000 | total: 25856.000000
# train Loss : 0.0017
# train Acc : 0.8380
# TRAIN EPOCH corrects: 37240.000000 | total: 44439.000000
# val Loss : 0.0030
# val Acc : 0.7296
# VAL EPOCH corrects: 3603.000000 | total: 4938.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  0.0015383604913949966
# running_acc  :  0.84375
# corrects: 216.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0016248536026474125
# running_acc  :  0.8466893564356436
# corrects: 21892.000000 | total: 25856.000000
# train Loss : 0.0017
# train Acc : 0.8434
# TRAIN EPOCH corrects: 37480.000000 | total: 44439.000000
# val Loss : 0.0036
# val Acc : 0.6938
# VAL EPOCH corrects: 3426.000000 | total: 4938.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  0.0016971922013908625
# running_acc  :  0.82421875
# corrects: 211.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.001547648858435747
# running_acc  :  0.8543858292079208
# corrects: 22091.000000 | total: 25856.000000
# train Loss : 0.0016
# train Acc : 0.8528
# TRAIN EPOCH corrects: 37897.000000 | total: 44439.000000
# val Loss : 0.0046
# val Acc : 0.6620
# VAL EPOCH corrects: 3269.000000 | total: 4938.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  0.0011625279439613223
# running_acc  :  0.90625
# corrects: 232.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0014402016347255743
# running_acc  :  0.8639387376237624
# corrects: 22338.000000 | total: 25856.000000
# train Loss : 0.0015
# train Acc : 0.8597
# TRAIN EPOCH corrects: 38202.000000 | total: 44439.000000
# val Loss : 0.0039
# val Acc : 0.6806
# VAL EPOCH corrects: 3361.000000 | total: 4938.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.0014156840043142438
# running_acc  :  0.8828125
# corrects: 226.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0013912860367511686
# running_acc  :  0.8722540222772277
# corrects: 22553.000000 | total: 25856.000000
# train Loss : 0.0014
# train Acc : 0.8663
# TRAIN EPOCH corrects: 38498.000000 | total: 44439.000000
# val Loss : 0.0041
# val Acc : 0.6766
# VAL EPOCH corrects: 3341.000000 | total: 4938.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  0.0013140314258635044
# running_acc  :  0.87109375
# corrects: 223.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0013268142736904175
# running_acc  :  0.8736076732673267
# corrects: 22588.000000 | total: 25856.000000
# train Loss : 0.0014
# train Acc : 0.8703
# TRAIN EPOCH corrects: 38674.000000 | total: 44439.000000
# val Loss : 0.0049
# val Acc : 0.6616
# VAL EPOCH corrects: 3267.000000 | total: 4938.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  0.001281360862776637
# running_acc  :  0.85546875
# corrects: 219.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0012846414788192746
# running_acc  :  0.8764696782178217
# corrects: 22662.000000 | total: 25856.000000
# train Loss : 0.0013
# train Acc : 0.8766
# TRAIN EPOCH corrects: 38955.000000 | total: 44439.000000
# val Loss : 0.0045
# val Acc : 0.6646
# VAL EPOCH corrects: 3282.000000 | total: 4938.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  0.001450016861781478
# running_acc  :  0.87109375
# corrects: 223.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0012403032719388162
# running_acc  :  0.885674504950495
# corrects: 22900.000000 | total: 25856.000000
# train Loss : 0.0013
# train Acc : 0.8828
# TRAIN EPOCH corrects: 39231.000000 | total: 44439.000000
# val Loss : 0.0044
# val Acc : 0.6630
# VAL EPOCH corrects: 3274.000000 | total: 4938.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  0.0010359548032283783
# running_acc  :  0.8984375
# corrects: 230.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0011760031615411586
# running_acc  :  0.8900061881188119
# corrects: 23012.000000 | total: 25856.000000
# train Loss : 0.0012
# train Acc : 0.8899
# TRAIN EPOCH corrects: 39547.000000 | total: 44439.000000
# val Loss : 0.0046
# val Acc : 0.6650
# VAL EPOCH corrects: 3284.000000 | total: 4938.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  0.0011343093356117606
# running_acc  :  0.89453125
# corrects: 229.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0011378715655047187
# running_acc  :  0.8942991955445545
# corrects: 23123.000000 | total: 25856.000000
# train Loss : 0.0012
# train Acc : 0.8916
# TRAIN EPOCH corrects: 39621.000000 | total: 44439.000000
# val Loss : 0.0043
# val Acc : 0.6814
# VAL EPOCH corrects: 3365.000000 | total: 4938.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  0.0011053333291783929
# running_acc  :  0.91015625
# corrects: 233.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0011046288505030593
# running_acc  :  0.900100556930693
# corrects: 23273.000000 | total: 25856.000000
# train Loss : 0.0011
# train Acc : 0.8960
# TRAIN EPOCH corrects: 39817.000000 | total: 44439.000000
# val Loss : 0.0041
# val Acc : 0.6881
# VAL EPOCH corrects: 3398.000000 | total: 4938.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  0.0014600502327084541
# running_acc  :  0.86328125
# corrects: 221.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0010381455027203231
# running_acc  :  0.9054764851485149
# corrects: 23412.000000 | total: 25856.000000
# train Loss : 0.0011
# train Acc : 0.9013
# TRAIN EPOCH corrects: 40055.000000 | total: 44439.000000
# val Loss : 0.0046
# val Acc : 0.6731
# VAL EPOCH corrects: 3324.000000 | total: 4938.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  0.000990982400253415
# running_acc  :  0.91796875
# corrects: 235.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0010400998791089595
# running_acc  :  0.9056698638613861
# corrects: 23417.000000 | total: 25856.000000
# train Loss : 0.0011
# train Acc : 0.9032
# TRAIN EPOCH corrects: 40137.000000 | total: 44439.000000
# val Loss : 0.0044
# val Acc : 0.6683
# VAL EPOCH corrects: 3300.000000 | total: 4938.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  0.0009956068824976683
# running_acc  :  0.9296875
# corrects: 238.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0010050196254782673
# running_acc  :  0.9077970297029703
# corrects: 23472.000000 | total: 25856.000000
# train Loss : 0.0010
# train Acc : 0.9057
# TRAIN EPOCH corrects: 40250.000000 | total: 44439.000000
# val Loss : 0.0046
# val Acc : 0.6705
# VAL EPOCH corrects: 3311.000000 | total: 4938.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  0.0008531700004823506
# running_acc  :  0.9140625
# corrects: 234.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.00096004958884643
# running_acc  :  0.911819306930693
# corrects: 23576.000000 | total: 25856.000000
# train Loss : 0.0010
# train Acc : 0.9096
# TRAIN EPOCH corrects: 40420.000000 | total: 44439.000000
# val Loss : 0.0045
# val Acc : 0.6788
# VAL EPOCH corrects: 3352.000000 | total: 4938.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  0.0006586334202438593
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0009166262306199215
# running_acc  :  0.9178527227722773
# corrects: 23732.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9164
# TRAIN EPOCH corrects: 40726.000000 | total: 44439.000000
# val Loss : 0.0050
# val Acc : 0.6636
# VAL EPOCH corrects: 3277.000000 | total: 4938.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  0.0008490927284583449
# running_acc  :  0.921875
# corrects: 236.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0009078532532272437
# running_acc  :  0.9184715346534653
# corrects: 23748.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9173
# TRAIN EPOCH corrects: 40765.000000 | total: 44439.000000
# val Loss : 0.0043
# val Acc : 0.6962
# VAL EPOCH corrects: 3438.000000 | total: 4938.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  0.0007005927618592978
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008842684227701202
# running_acc  :  0.9202506188118812
# corrects: 23794.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9173
# TRAIN EPOCH corrects: 40763.000000 | total: 44439.000000
# val Loss : 0.0042
# val Acc : 0.6814
# VAL EPOCH corrects: 3365.000000 | total: 4938.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  0.000667929241899401
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008601666690947691
# running_acc  :  0.9226098391089109
# corrects: 23855.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9207
# TRAIN EPOCH corrects: 40914.000000 | total: 44439.000000
# val Loss : 0.0040
# val Acc : 0.7039
# VAL EPOCH corrects: 3476.000000 | total: 4938.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  0.0007445580558851361
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008350873480108336
# running_acc  :  0.9252011138613861
# corrects: 23922.000000 | total: 25856.000000
# train Loss : 0.0009
# train Acc : 0.9214
# TRAIN EPOCH corrects: 40947.000000 | total: 44439.000000
# val Loss : 0.0041
# val Acc : 0.6859
# VAL EPOCH corrects: 3387.000000 | total: 4938.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  0.0008315360173583031
# running_acc  :  0.921875
# corrects: 236.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008186019817597722
# running_acc  :  0.9252011138613861
# corrects: 23922.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9230
# TRAIN EPOCH corrects: 41015.000000 | total: 44439.000000
# val Loss : 0.0043
# val Acc : 0.6885
# VAL EPOCH corrects: 3400.000000 | total: 4938.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  0.0007808055961504579
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0008042860043691564
# running_acc  :  0.928643254950495
# corrects: 24011.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9264
# TRAIN EPOCH corrects: 41167.000000 | total: 44439.000000
# val Loss : 0.0044
# val Acc : 0.6977
# VAL EPOCH corrects: 3445.000000 | total: 4938.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  0.0006951967952772975
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007926615907137495
# running_acc  :  0.9291073638613861
# corrects: 24023.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9266
# TRAIN EPOCH corrects: 41176.000000 | total: 44439.000000
# val Loss : 0.0036
# val Acc : 0.7043
# VAL EPOCH corrects: 3478.000000 | total: 4938.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  0.0007247395114973187
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007367410609443294
# running_acc  :  0.9355275371287128
# corrects: 24189.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9299
# TRAIN EPOCH corrects: 41326.000000 | total: 44439.000000
# val Loss : 0.0039
# val Acc : 0.7041
# VAL EPOCH corrects: 3477.000000 | total: 4938.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  0.000659481855109334
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007745095852550377
# running_acc  :  0.9295714727722773
# corrects: 24035.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9295
# TRAIN EPOCH corrects: 41306.000000 | total: 44439.000000
# val Loss : 0.0038
# val Acc : 0.7234
# VAL EPOCH corrects: 3572.000000 | total: 4938.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  0.0007357921567745507
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007343478227094148
# running_acc  :  0.9345993193069307
# corrects: 24165.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9314
# TRAIN EPOCH corrects: 41392.000000 | total: 44439.000000
# val Loss : 0.0041
# val Acc : 0.7058
# VAL EPOCH corrects: 3485.000000 | total: 4938.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  0.000708334322553128
# running_acc  :  0.921875
# corrects: 236.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007153208595746667
# running_acc  :  0.9358756188118812
# corrects: 24198.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9320
# TRAIN EPOCH corrects: 41415.000000 | total: 44439.000000
# val Loss : 0.0041
# val Acc : 0.6995
# VAL EPOCH corrects: 3454.000000 | total: 4938.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  0.0009077657596208155
# running_acc  :  0.92578125
# corrects: 237.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007215355609953957
# running_acc  :  0.935256806930693
# corrects: 24182.000000 | total: 25856.000000
# train Loss : 0.0008
# train Acc : 0.9326
# TRAIN EPOCH corrects: 41445.000000 | total: 44439.000000
# val Loss : 0.0036
# val Acc : 0.7149
# VAL EPOCH corrects: 3530.000000 | total: 4938.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  0.0005886523867957294
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006936009299577131
# running_acc  :  0.9401686262376238
# corrects: 24309.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9381
# TRAIN EPOCH corrects: 41687.000000 | total: 44439.000000
# val Loss : 0.0040
# val Acc : 0.7098
# VAL EPOCH corrects: 3505.000000 | total: 4938.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  0.0006260699592530727
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006792101104822157
# running_acc  :  0.9400139232673267
# corrects: 24305.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9365
# TRAIN EPOCH corrects: 41619.000000 | total: 44439.000000
# val Loss : 0.0038
# val Acc : 0.7130
# VAL EPOCH corrects: 3521.000000 | total: 4938.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  0.0008602929883636534
# running_acc  :  0.91796875
# corrects: 235.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0007217399857242103
# running_acc  :  0.9373452970297029
# corrects: 24236.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9361
# TRAIN EPOCH corrects: 41601.000000 | total: 44439.000000
# val Loss : 0.0037
# val Acc : 0.7238
# VAL EPOCH corrects: 3574.000000 | total: 4938.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  0.000500704743899405
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006617066850378593
# running_acc  :  0.9429146039603961
# corrects: 24380.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9395
# TRAIN EPOCH corrects: 41749.000000 | total: 44439.000000
# val Loss : 0.0041
# val Acc : 0.6936
# VAL EPOCH corrects: 3425.000000 | total: 4938.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  0.0005722135538235307
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000651722624644379
# running_acc  :  0.9418316831683168
# corrects: 24352.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9389
# TRAIN EPOCH corrects: 41724.000000 | total: 44439.000000
# val Loss : 0.0035
# val Acc : 0.7244
# VAL EPOCH corrects: 3577.000000 | total: 4938.000000
# Epoch 41/99
# ----------
# Iter :  0
# running_loss :  0.0004700878052972257
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006758604869523113
# running_acc  :  0.940362004950495
# corrects: 24314.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9394
# TRAIN EPOCH corrects: 41745.000000 | total: 44439.000000
# val Loss : 0.0036
# val Acc : 0.7187
# VAL EPOCH corrects: 3549.000000 | total: 4938.000000
# Epoch 42/99
# ----------
# Iter :  0
# running_loss :  0.00039744118112139404
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006603495186738817
# running_acc  :  0.9429532797029703
# corrects: 24381.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9410
# TRAIN EPOCH corrects: 41817.000000 | total: 44439.000000
# val Loss : 0.0033
# val Acc : 0.7432
# VAL EPOCH corrects: 3670.000000 | total: 4938.000000
# Epoch 43/99
# ----------
# Iter :  0
# running_loss :  0.0005936477682553232
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006664661096413574
# running_acc  :  0.9411741955445545
# corrects: 24335.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9396
# TRAIN EPOCH corrects: 41755.000000 | total: 44439.000000
# val Loss : 0.0038
# val Acc : 0.7193
# VAL EPOCH corrects: 3552.000000 | total: 4938.000000
# Epoch 44/99
# ----------
# Iter :  0
# running_loss :  0.0008054394274950027
# running_acc  :  0.92578125
# corrects: 237.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006638659904296002
# running_acc  :  0.9417543316831684
# corrects: 24350.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9403
# TRAIN EPOCH corrects: 41785.000000 | total: 44439.000000
# val Loss : 0.0034
# val Acc : 0.7296
# VAL EPOCH corrects: 3603.000000 | total: 4938.000000
# Epoch 45/99
# ----------
# Iter :  0
# running_loss :  0.000626591790933162
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006143889954143047
# running_acc  :  0.9465887995049505
# corrects: 24475.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9438
# TRAIN EPOCH corrects: 41941.000000 | total: 44439.000000
# val Loss : 0.0033
# val Acc : 0.7446
# VAL EPOCH corrects: 3677.000000 | total: 4938.000000
# Epoch 46/99
# ----------
# Iter :  0
# running_loss :  0.0007605275604873896
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006547512908438497
# running_acc  :  0.9427212252475248
# corrects: 24375.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9417
# TRAIN EPOCH corrects: 41847.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7351
# VAL EPOCH corrects: 3630.000000 | total: 4938.000000
# Epoch 47/99
# ----------
# Iter :  0
# running_loss :  0.0005645974888466299
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006337881798275036
# running_acc  :  0.9434560643564357
# corrects: 24394.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9412
# TRAIN EPOCH corrects: 41824.000000 | total: 44439.000000
# val Loss : 0.0035
# val Acc : 0.7345
# VAL EPOCH corrects: 3627.000000 | total: 4938.000000
# Epoch 48/99
# ----------
# Iter :  0
# running_loss :  0.0006451201043091714
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006478693521245023
# running_acc  :  0.9439975247524752
# corrects: 24408.000000 | total: 25856.000000
# train Loss : 0.0007
# train Acc : 0.9422
# TRAIN EPOCH corrects: 41871.000000 | total: 44439.000000
# val Loss : 0.0035
# val Acc : 0.7278
# VAL EPOCH corrects: 3594.000000 | total: 4938.000000
# Epoch 49/99
# ----------
# Iter :  0
# running_loss :  0.0004566666320897639
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006344434571807448
# running_acc  :  0.9443456064356436
# corrects: 24417.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9438
# TRAIN EPOCH corrects: 41941.000000 | total: 44439.000000
# val Loss : 0.0037
# val Acc : 0.7102
# VAL EPOCH corrects: 3507.000000 | total: 4938.000000
# Epoch 50/99
# ----------
# Iter :  0
# running_loss :  0.0005257356679067016
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006203137445932089
# running_acc  :  0.9461246905940595
# corrects: 24463.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9443
# TRAIN EPOCH corrects: 41965.000000 | total: 44439.000000
# val Loss : 0.0038
# val Acc : 0.7157
# VAL EPOCH corrects: 3534.000000 | total: 4938.000000
# Epoch 51/99
# ----------
# Iter :  0
# running_loss :  0.000475801236461848
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006254324741375697
# running_acc  :  0.9437267945544554
# corrects: 24401.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9436
# TRAIN EPOCH corrects: 41933.000000 | total: 44439.000000
# val Loss : 0.0034
# val Acc : 0.7396
# VAL EPOCH corrects: 3652.000000 | total: 4938.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  0.0005515071097761393
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006053181296551028
# running_acc  :  0.9479037747524752
# corrects: 24509.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9461
# TRAIN EPOCH corrects: 42044.000000 | total: 44439.000000
# val Loss : 0.0033
# val Acc : 0.7442
# VAL EPOCH corrects: 3675.000000 | total: 4938.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  0.0004660974955186248
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005960911231422059
# running_acc  :  0.9481358292079208
# corrects: 24515.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9460
# TRAIN EPOCH corrects: 42039.000000 | total: 44439.000000
# val Loss : 0.0030
# val Acc : 0.7444
# VAL EPOCH corrects: 3676.000000 | total: 4938.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  0.0005501218256540596
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0006173919632196389
# running_acc  :  0.9465501237623762
# corrects: 24474.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9463
# TRAIN EPOCH corrects: 42054.000000 | total: 44439.000000
# val Loss : 0.0034
# val Acc : 0.7394
# VAL EPOCH corrects: 3651.000000 | total: 4938.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  0.000635479053016752
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005814350097172774
# running_acc  :  0.9487546410891089
# corrects: 24531.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9467
# TRAIN EPOCH corrects: 42069.000000 | total: 44439.000000
# val Loss : 0.0035
# val Acc : 0.7290
# VAL EPOCH corrects: 3600.000000 | total: 4938.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  0.0006561172776855528
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005919281716025112
# running_acc  :  0.9484839108910891
# corrects: 24524.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9468
# TRAIN EPOCH corrects: 42075.000000 | total: 44439.000000
# val Loss : 0.0030
# val Acc : 0.7625
# VAL EPOCH corrects: 3765.000000 | total: 4938.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  0.00047161791007965803
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005890036403491982
# running_acc  :  0.9503403465346535
# corrects: 24572.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9491
# TRAIN EPOCH corrects: 42177.000000 | total: 44439.000000
# val Loss : 0.0035
# val Acc : 0.7270
# VAL EPOCH corrects: 3590.000000 | total: 4938.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  0.0006336121587082744
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005651303739310011
# running_acc  :  0.9504563737623762
# corrects: 24575.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9473
# TRAIN EPOCH corrects: 42096.000000 | total: 44439.000000
# val Loss : 0.0033
# val Acc : 0.7438
# VAL EPOCH corrects: 3673.000000 | total: 4938.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  0.0005424701957963407
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000570521679865934
# running_acc  :  0.9494508044554455
# corrects: 24549.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9487
# TRAIN EPOCH corrects: 42161.000000 | total: 44439.000000
# val Loss : 0.0037
# val Acc : 0.7149
# VAL EPOCH corrects: 3530.000000 | total: 4938.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  0.0006277533248066902
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005879772620709004
# running_acc  :  0.9492961014851485
# corrects: 24545.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9484
# TRAIN EPOCH corrects: 42147.000000 | total: 44439.000000
# val Loss : 0.0036
# val Acc : 0.7132
# VAL EPOCH corrects: 3522.000000 | total: 4938.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  0.0005487655871547759
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000576647522393614
# running_acc  :  0.9488706683168316
# corrects: 24534.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9480
# TRAIN EPOCH corrects: 42128.000000 | total: 44439.000000
# val Loss : 0.0033
# val Acc : 0.7292
# VAL EPOCH corrects: 3601.000000 | total: 4938.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  0.0007198748644441366
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005642837766410395
# running_acc  :  0.9511138613861386
# corrects: 24592.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9493
# TRAIN EPOCH corrects: 42185.000000 | total: 44439.000000
# val Loss : 0.0031
# val Acc : 0.7509
# VAL EPOCH corrects: 3708.000000 | total: 4938.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  0.0004256200627423823
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005777330445540645
# running_acc  :  0.9487933168316832
# corrects: 24532.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9479
# TRAIN EPOCH corrects: 42125.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7454
# VAL EPOCH corrects: 3681.000000 | total: 4938.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  0.00045063323341310024
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005589648542377065
# running_acc  :  0.9530089727722773
# corrects: 24641.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9517
# TRAIN EPOCH corrects: 42294.000000 | total: 44439.000000
# val Loss : 0.0034
# val Acc : 0.7390
# VAL EPOCH corrects: 3649.000000 | total: 4938.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  0.0006647492409683764
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005681196465110867
# running_acc  :  0.951926051980198
# corrects: 24613.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9500
# TRAIN EPOCH corrects: 42215.000000 | total: 44439.000000
# val Loss : 0.0031
# val Acc : 0.7558
# VAL EPOCH corrects: 3732.000000 | total: 4938.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  0.0005515575176104903
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005636843071794045
# running_acc  :  0.9511138613861386
# corrects: 24592.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9498
# TRAIN EPOCH corrects: 42206.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7542
# VAL EPOCH corrects: 3724.000000 | total: 4938.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  0.0005956594250164926
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005616195889484912
# running_acc  :  0.9503403465346535
# corrects: 24572.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9496
# TRAIN EPOCH corrects: 42200.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7408
# VAL EPOCH corrects: 3658.000000 | total: 4938.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  0.0003804895677603781
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005627802891845788
# running_acc  :  0.9525448638613861
# corrects: 24629.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9512
# TRAIN EPOCH corrects: 42269.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7734
# VAL EPOCH corrects: 3819.000000 | total: 4938.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  0.00038044192478992045
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005597084432743527
# running_acc  :  0.9511525371287128
# corrects: 24593.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9507
# TRAIN EPOCH corrects: 42250.000000 | total: 44439.000000
# val Loss : 0.0030
# val Acc : 0.7629
# VAL EPOCH corrects: 3767.000000 | total: 4938.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  0.0004049625713378191
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005594737433579446
# running_acc  :  0.9525061881188119
# corrects: 24628.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9508
# TRAIN EPOCH corrects: 42251.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7434
# VAL EPOCH corrects: 3671.000000 | total: 4938.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  0.0004738714196719229
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005752293258734822
# running_acc  :  0.9496441831683168
# corrects: 24554.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9502
# TRAIN EPOCH corrects: 42227.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7627
# VAL EPOCH corrects: 3766.000000 | total: 4938.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  0.0003925398050341755
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005506323045350169
# running_acc  :  0.9521581064356436
# corrects: 24619.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9497
# TRAIN EPOCH corrects: 42203.000000 | total: 44439.000000
# val Loss : 0.0031
# val Acc : 0.7594
# VAL EPOCH corrects: 3750.000000 | total: 4938.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  0.0003295641508884728
# running_acc  :  0.97265625
# corrects: 249.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005601871793854539
# running_acc  :  0.9512298886138614
# corrects: 24595.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9499
# TRAIN EPOCH corrects: 42211.000000 | total: 44439.000000
# val Loss : 0.0033
# val Acc : 0.7418
# VAL EPOCH corrects: 3663.000000 | total: 4938.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  0.000493790430482477
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005390615554614048
# running_acc  :  0.9525448638613861
# corrects: 24629.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9506
# TRAIN EPOCH corrects: 42242.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7649
# VAL EPOCH corrects: 3777.000000 | total: 4938.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  0.000496643187943846
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005466415357227336
# running_acc  :  0.952080754950495
# corrects: 24617.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9507
# TRAIN EPOCH corrects: 42246.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7823
# VAL EPOCH corrects: 3863.000000 | total: 4938.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  0.0007756066625006497
# running_acc  :  0.9375
# corrects: 240.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005775405376997435
# running_acc  :  0.9497602103960396
# corrects: 24557.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9495
# TRAIN EPOCH corrects: 42193.000000 | total: 44439.000000
# val Loss : 0.0033
# val Acc : 0.7414
# VAL EPOCH corrects: 3661.000000 | total: 4938.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  0.0006664652610197663
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000552175764517748
# running_acc  :  0.9524288366336634
# corrects: 24626.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9514
# TRAIN EPOCH corrects: 42278.000000 | total: 44439.000000
# val Loss : 0.0026
# val Acc : 0.7945
# VAL EPOCH corrects: 3923.000000 | total: 4938.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  0.00041337328730151057
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005332266656557412
# running_acc  :  0.9543626237623762
# corrects: 24676.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9517
# TRAIN EPOCH corrects: 42291.000000 | total: 44439.000000
# val Loss : 0.0030
# val Acc : 0.7560
# VAL EPOCH corrects: 3733.000000 | total: 4938.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  0.0007013878202997148
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.000551814737696302
# running_acc  :  0.9520420792079208
# corrects: 24616.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9510
# TRAIN EPOCH corrects: 42263.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7501
# VAL EPOCH corrects: 3704.000000 | total: 4938.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  0.0007359032751992345
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005443480904882608
# running_acc  :  0.9545560024752475
# corrects: 24681.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9527
# TRAIN EPOCH corrects: 42335.000000 | total: 44439.000000
# val Loss : 0.0028
# val Acc : 0.7758
# VAL EPOCH corrects: 3831.000000 | total: 4938.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  0.0007235771045088768
# running_acc  :  0.9296875
# corrects: 238.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005563066705789343
# running_acc  :  0.952080754950495
# corrects: 24617.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9498
# TRAIN EPOCH corrects: 42208.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7444
# VAL EPOCH corrects: 3676.000000 | total: 4938.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  0.0004463504010345787
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005222199364256409
# running_acc  :  0.9559483292079208
# corrects: 24717.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9526
# TRAIN EPOCH corrects: 42333.000000 | total: 44439.000000
# val Loss : 0.0028
# val Acc : 0.7825
# VAL EPOCH corrects: 3864.000000 | total: 4938.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  0.0006717509822919965
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005388405622965149
# running_acc  :  0.9549427599009901
# corrects: 24691.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9525
# TRAIN EPOCH corrects: 42327.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7746
# VAL EPOCH corrects: 3825.000000 | total: 4938.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  0.0004992621834389865
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005437880852444116
# running_acc  :  0.9539371905940595
# corrects: 24665.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9523
# TRAIN EPOCH corrects: 42320.000000 | total: 44439.000000
# val Loss : 0.0033
# val Acc : 0.7517
# VAL EPOCH corrects: 3712.000000 | total: 4938.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  0.0006479604635387659
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005255177132105271
# running_acc  :  0.9544399752475248
# corrects: 24678.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9535
# TRAIN EPOCH corrects: 42372.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7732
# VAL EPOCH corrects: 3818.000000 | total: 4938.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  0.0004380804020911455
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005323773006203188
# running_acc  :  0.9547107054455446
# corrects: 24685.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9535
# TRAIN EPOCH corrects: 42372.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7760
# VAL EPOCH corrects: 3832.000000 | total: 4938.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  0.00033953230013139546
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005553091788609134
# running_acc  :  0.9526608910891089
# corrects: 24632.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9510
# TRAIN EPOCH corrects: 42262.000000 | total: 44439.000000
# val Loss : 0.0030
# val Acc : 0.7746
# VAL EPOCH corrects: 3825.000000 | total: 4938.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  0.0005690005491487682
# running_acc  :  0.95703125
# corrects: 245.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005155806805728704
# running_acc  :  0.9563350866336634
# corrects: 24727.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9543
# TRAIN EPOCH corrects: 42406.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7748
# VAL EPOCH corrects: 3826.000000 | total: 4938.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  0.0007157433428801596
# running_acc  :  0.93359375
# corrects: 239.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005176741774493626
# running_acc  :  0.9550587871287128
# corrects: 24694.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9526
# TRAIN EPOCH corrects: 42332.000000 | total: 44439.000000
# val Loss : 0.0028
# val Acc : 0.7908
# VAL EPOCH corrects: 3905.000000 | total: 4938.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  0.00037635257467627525
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005217579456788515
# running_acc  :  0.9561417079207921
# corrects: 24722.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9545
# TRAIN EPOCH corrects: 42417.000000 | total: 44439.000000
# val Loss : 0.0030
# val Acc : 0.7681
# VAL EPOCH corrects: 3793.000000 | total: 4938.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  0.0005594264948740602
# running_acc  :  0.94140625
# corrects: 241.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005160037239109821
# running_acc  :  0.9554842202970297
# corrects: 24705.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9529
# TRAIN EPOCH corrects: 42348.000000 | total: 44439.000000
# val Loss : 0.0032
# val Acc : 0.7635
# VAL EPOCH corrects: 3770.000000 | total: 4938.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  0.0007466757670044899
# running_acc  :  0.9296875
# corrects: 238.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005308008188840537
# running_acc  :  0.954788056930693
# corrects: 24687.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9547
# TRAIN EPOCH corrects: 42428.000000 | total: 44439.000000
# val Loss : 0.0028
# val Acc : 0.7932
# VAL EPOCH corrects: 3917.000000 | total: 4938.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  0.00046930566895753145
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005024263566408288
# running_acc  :  0.9562964108910891
# corrects: 24726.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9538
# TRAIN EPOCH corrects: 42388.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7685
# VAL EPOCH corrects: 3795.000000 | total: 4938.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  0.0005384419346228242
# running_acc  :  0.94921875
# corrects: 243.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005390612442521286
# running_acc  :  0.9542465965346535
# corrects: 24673.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9523
# TRAIN EPOCH corrects: 42321.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7827
# VAL EPOCH corrects: 3865.000000 | total: 4938.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  0.0003774124779738486
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005181091742493249
# running_acc  :  0.9562190594059405
# corrects: 24724.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9524
# TRAIN EPOCH corrects: 42325.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7708
# VAL EPOCH corrects: 3806.000000 | total: 4938.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  0.000645327614620328
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005354357357159957
# running_acc  :  0.9549427599009901
# corrects: 24691.000000 | total: 25856.000000
# train Loss : 0.0006
# train Acc : 0.9526
# TRAIN EPOCH corrects: 42333.000000 | total: 44439.000000
# val Loss : 0.0028
# val Acc : 0.7888
# VAL EPOCH corrects: 3895.000000 | total: 4938.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  0.00043191073928028345
# running_acc  :  0.953125
# corrects: 244.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005079758645145978
# running_acc  :  0.9570699257425742
# corrects: 24746.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9548
# TRAIN EPOCH corrects: 42431.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7695
# VAL EPOCH corrects: 3800.000000 | total: 4938.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  0.00030468159820884466
# running_acc  :  0.984375
# corrects: 252.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005206224388422186
# running_acc  :  0.955368193069307
# corrects: 24702.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9542
# TRAIN EPOCH corrects: 42403.000000 | total: 44439.000000
# val Loss : 0.0030
# val Acc : 0.7819
# VAL EPOCH corrects: 3861.000000 | total: 4938.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  0.00041877522016875446
# running_acc  :  0.96484375
# corrects: 247.000000 | total: 256.000000
# Iter :  100
# running_loss :  0.0005164748088843973
# running_acc  :  0.9560643564356436
# corrects: 24720.000000 | total: 25856.000000
# train Loss : 0.0005
# train Acc : 0.9554
# TRAIN EPOCH corrects: 42459.000000 | total: 44439.000000
# val Loss : 0.0029
# val Acc : 0.7801
# VAL EPOCH corrects: 3852.000000 | total: 4938.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.5923326760530472
# EVAL ACC :  0.7774740295243302
# Predictions | Labels
# [[4 6]
#  [4 4]
#  [7 7]
#  [1 9]
#  [9 9]
#  [7 7]
#  [4 8]
#  [1 1]
#  [9 9]
#  [4 4]
#  [8 9]
#  [2 2]
#  [8 8]
#  [7 7]
#  [1 1]]
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scnym\api.py:427: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns['scNym_train_results'] = results
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 11 classes from 2000 features
# ['CD14+ Monocyte' 'CD19+ B' 'CD34+' 'CD4+ T Helper2' 'CD4+/CD25 T Reg'
#  'CD4+/CD45RA+/CD25- Naive T' 'CD4+/CD45RO+ Memory' 'CD56+ NK'
#  'CD8+ Cytotoxic T' 'CD8+/CD45RA+ Naive Cytotoxic' 'Dendritic']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 14/14 [00:00<00:00, 31.77it/s]
# Extracting model embeddings...
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scnym\api.py:550: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs[config['key_added']] = names

# %%
# Save results
results.to_csv('results/scNym_hvgs_output.csv', index=True)

# %%
# Extract the unique labels
unique_labels1 = np.unique(results.true_label)
unique_labels2 = np.unique(results.pred)
unique_labels = np.unique(np.concatenate([unique_labels1,unique_labels2]))

# Convert string labels to numerical labels
label_encoder_temp = LabelEncoder()
label_encoder_temp.fit(unique_labels)
y_true = label_encoder_temp.transform(results.true_label)
y_pred = label_encoder_temp.transform(results.pred)

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7645634961139708
