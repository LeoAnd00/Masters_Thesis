# %% [markdown]
# ## scNym: https://github.com/calico/scnym

# %%
import scnym
from scnym.api import scnym_api
import torch
import random
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import scanpy as sc
# Out:
# WARNING:tensorflow:From c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def split_data(data_path: str, 
               fold: int=1,
               folds: int=5,
               batch_key: str="patientID", 
               label_key: str="cell_type",
               seed: int=42,
               HVG: bool=True,
               HVGs: int=2000):
    
    adata = sc.read(data_path, cache=True)

    adata.obs["batch"] = adata.obs[batch_key]

    # Ensure reproducibility
    def rep_seed(seed):
        # Check if a GPU is available
        if torch.cuda.is_available():
            # Set the random seed for PyTorch CUDA (GPU) operations
            torch.cuda.manual_seed(seed)
            # Set the random seed for all CUDA devices (if multiple GPUs are available)
            torch.cuda.manual_seed_all(seed)
        
        # Set the random seed for CPU-based PyTorch operations
        torch.manual_seed(seed)
        
        # Set the random seed for NumPy
        np.random.seed(seed)
        
        # Set the random seed for Python's built-in 'random' module
        random.seed(seed)
        
        # Set the random seed for TensorFlow
        tf.random.set_seed(seed)
        
        # Set CuDNN to deterministic mode for PyTorch (GPU)
        torch.backends.cudnn.deterministic = True
        
        # Disable CuDNN's benchmarking mode for deterministic behavior
        torch.backends.cudnn.benchmark = False

    rep_seed(seed)

    # Initialize Stratified K-Fold
    stratified_kfold = StratifiedKFold(n_splits=folds, shuffle=True, random_state=42)

    # Iterate through the folds
    adata_original = adata.copy()
    test_adata_original = adata.copy()
    fold_counter = 0
    for train_index, test_index in stratified_kfold.split(adata_original.X, adata_original.obs[label_key]):
        fold_counter += 1
        
        adata = adata_original[train_index, :].copy()
        test_adata = test_adata_original[test_index, :].copy()

        if HVG:
            sc.pp.highly_variable_genes(adata, n_top_genes=HVGs, flavor="cell_ranger")
            test_adata = test_adata[:, adata.var["highly_variable"]].copy()
            adata = adata[:, adata.var["highly_variable"]].copy()
        
        if fold_counter == fold:
            
            return adata, test_adata

# %%
data_path = "../../../data/processed/data_for_evaluating_cell_type_annotation/Baron.h5ad"

# Iterate through folds
results = None
for fold_idx in range(5):
    fold = fold_idx + 1

    adata_train, adata_test = split_data(data_path=data_path, fold=fold)

    # Train model
    scnym_api(
        adata=adata_train,
        task='train',
        groupby='cell_type',
        out_path='./scnym_outputs',
        config='no_new_identity',
    )

    # Predict test data
    scnym_api(
        adata=adata_test,
        task='predict',
        key_added='scNym',
        config='no_new_identity',
        trained_model='./scnym_outputs'
    )

    # Save results in dataframe
    if fold == 1:
        results = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                "true_label": adata_test.obs["cell_type"].to_list(), 
                                "fold": [fold]*adata_test.obs['scNym'].shape[0]})
    else:   
        dataframe_temp = pd.DataFrame({"pred": adata_test.obs['scNym'].to_list(), 
                                    "true_label": adata_test.obs["cell_type"].to_list(), 
                                    "fold": [fold]*adata_test.obs['scNym'].shape[0]})
        results = pd.concat([results,dataframe_temp], axis=0)

# Reset index
results.reset_index(drop=True, inplace=True)
# Out:
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (6855, 2000)
# y:  (6855,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.010580914095044136
# running_acc  :  0.10546875
# corrects: 27.000000 | total: 256.000000
# train Loss : 0.0027
# train Acc : 0.8354
# TRAIN EPOCH corrects: 4638.000000 | total: 5552.000000
# val Loss : 0.0008
# val Acc : 0.9692
# VAL EPOCH corrects: 598.000000 | total: 617.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.0006648628623224795
# running_acc  :  0.9609375
# corrects: 246.000000 | total: 256.000000
# train Loss : 0.0007
# train Acc : 0.9607
# TRAIN EPOCH corrects: 5334.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9806
# VAL EPOCH corrects: 605.000000 | total: 617.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.000431932567153126
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9778
# TRAIN EPOCH corrects: 5429.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.00041753199184313416
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0003
# train Acc : 0.9847
# TRAIN EPOCH corrects: 5467.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.00017537610256113112
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9865
# TRAIN EPOCH corrects: 5477.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  0.0001937287743203342
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9914
# TRAIN EPOCH corrects: 5504.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0001
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.00015134525892790407
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9932
# TRAIN EPOCH corrects: 5514.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  5.52497040189337e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9937
# TRAIN EPOCH corrects: 5517.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.00019789335783571005
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9935
# TRAIN EPOCH corrects: 5516.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0001
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  4.752451786771417e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9948
# TRAIN EPOCH corrects: 5523.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  1.3398473129200283e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9968
# TRAIN EPOCH corrects: 5534.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  6.408418994396925e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9966
# TRAIN EPOCH corrects: 5533.000000 | total: 5552.000000
# val Loss : 0.0001
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  0.00010781509627122432
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5540.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  3.5587687307270244e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9971
# TRAIN EPOCH corrects: 5536.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  4.165780046605505e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9982
# TRAIN EPOCH corrects: 5542.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0001
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  1.1105155863333493e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9978
# TRAIN EPOCH corrects: 5540.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  4.046330650453456e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5546.000000 | total: 5552.000000
# val Loss : 0.0001
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  9.918157047650311e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5545.000000 | total: 5552.000000
# val Loss : 0.0001
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  8.98782309377566e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5543.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  9.550785762257874e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5545.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  1.1999273738183547e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  4.4112471186963376e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  9.85021051747026e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  3.8380072510335594e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  3.4386546758469194e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0001
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  4.490522769629024e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5545.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  1.6411484466516413e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0001
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  1.891916326712817e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0001
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  9.555096767144278e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  7.66454468248412e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  1.1182772141182795e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9986
# TRAIN EPOCH corrects: 5544.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  7.853870556573384e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5546.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  6.6513416641100775e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  3.1315084925154224e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 34/99
# ----------
# Iter :  0
# running_loss :  3.2716902751417365e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9989
# TRAIN EPOCH corrects: 5546.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 35/99
# ----------
# Iter :  0
# running_loss :  2.789723566820612e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 36/99
# ----------
# Iter :  0
# running_loss :  5.83629916945938e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 37/99
# ----------
# Iter :  0
# running_loss :  1.3395758742262842e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 38/99
# ----------
# Iter :  0
# running_loss :  5.622305707220221e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9991
# TRAIN EPOCH corrects: 5547.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 39/99
# ----------
# Iter :  0
# running_loss :  4.589210220729001e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 40/99
# ----------
# Iter :  0
# running_loss :  6.647463578701718e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 41/99
# ----------
# Iter :  0
# running_loss :  2.033101964116213e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 42/99
# ----------
# Iter :  0
# running_loss :  6.27402823738521e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 43/99
# ----------
# Iter :  0
# running_loss :  2.2842073121864814e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 44/99
# ----------
# Iter :  0
# running_loss :  5.2841319302388e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 45/99
# ----------
# Iter :  0
# running_loss :  1.4553965229424648e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 46/99
# ----------
# Iter :  0
# running_loss :  1.7533011487103067e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 47/99
# ----------
# Iter :  0
# running_loss :  6.082020718167769e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 48/99
# ----------
# Iter :  0
# running_loss :  2.3479581159335794e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 49/99
# ----------
# Iter :  0
# running_loss :  2.0405134364409605e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 50/99
# ----------
# Iter :  0
# running_loss :  3.422851250434178e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 51/99
# ----------
# Iter :  0
# running_loss :  1.0150138223252725e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  8.914805221138522e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  2.183939159294823e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  1.2282592251722235e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  1.5893374438746832e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  4.181779786449624e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  3.808179144471069e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  2.9457485652528703e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  1.343734038528055e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  2.4972089249786222e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  1.1512482842590543e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  1.7667002794041764e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  1.3258480748845614e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  3.819687208306277e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  8.048073141253553e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  8.776624440542946e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  2.968394255731255e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  2.7326088911650004e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  3.036326006622403e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  2.6384557259007124e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  1.6025082913984079e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  2.3409752429870423e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  2.4907880288083106e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  2.614873892525793e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  2.8232261684024706e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  3.023633553311811e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  1.957117319761892e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  2.8334027319942834e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  4.0401946534984745e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  1.326592973782681e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  1.0238711638521636e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  1.7396318980900105e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  2.5335350528621348e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  2.795951786538353e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  1.3702322121389443e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  8.069133400567807e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9935
# VAL EPOCH corrects: 613.000000 | total: 617.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  4.2199334870929306e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  6.738136448802834e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  1.170609380096721e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  9.719303761812625e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  1.7165659755846718e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  4.788163096236531e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  1.1314842822685023e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  1.8317549574931036e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  1.0647338513081195e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  6.809802357565786e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  1.845950919232564e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  1.2043765309499577e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  3.758477078008582e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0002
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.08237467333674431
# EVAL ACC :  0.9912536443148688
# Predictions | Labels
# [[0 0]
#  [3 3]
#  [3 3]
#  [3 3]
#  [3 3]
#  [3 3]
#  [3 3]
#  [3 3]
#  [2 2]
#  [3 3]
#  [0 0]
#  [2 2]
#  [3 3]
#  [3 3]
#  [5 5]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 14 classes from 2000 features
# ['acinar' 'activated_stellate' 'alpha' 'beta' 'delta' 'ductal'
#  'endothelial' 'epsilon' 'gamma' 'macrophage' 'mast' 'quiescent_stellate'
#  'schwann' 't_cell']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 22.73it/s]
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(
# Extracting model embeddings...
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\scanpy\preprocessing\_highly_variable_genes.py:252: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   disp_grouped = df.groupby('mean_bin')['dispersions']
# c:\Users\user\Documents\GitHub\Masters_Thesis\AnnotationEnv\lib\site-packages\anndata\_core\anndata.py:1906: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# No unlabeled data was found.
# Did you forget to set some examples as `"Unlabeled"`?
# Proceeding with purely supervised training.
#
# X:  (6855, 2000)
# y:  (6855,)
# Not weighting classes and not balancing classes.
# Training...
# Epoch 0/99
# ----------
# Iter :  0
# running_loss :  0.010971618816256523
# running_acc  :  0.06640625
# corrects: 17.000000 | total: 256.000000
# train Loss : 0.0027
# train Acc : 0.8354
# TRAIN EPOCH corrects: 4638.000000 | total: 5552.000000
# val Loss : 0.0013
# val Acc : 0.9660
# VAL EPOCH corrects: 596.000000 | total: 617.000000
# Epoch 1/99
# ----------
# Iter :  0
# running_loss :  0.000895762350410223
# running_acc  :  0.9453125
# corrects: 242.000000 | total: 256.000000
# train Loss : 0.0006
# train Acc : 0.9678
# TRAIN EPOCH corrects: 5373.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9789
# VAL EPOCH corrects: 604.000000 | total: 617.000000
# Epoch 2/99
# ----------
# Iter :  0
# running_loss :  0.0005365168326534331
# running_acc  :  0.96875
# corrects: 248.000000 | total: 256.000000
# train Loss : 0.0004
# train Acc : 0.9811
# TRAIN EPOCH corrects: 5447.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9741
# VAL EPOCH corrects: 601.000000 | total: 617.000000
# Epoch 3/99
# ----------
# Iter :  0
# running_loss :  0.00025012047262862325
# running_acc  :  0.98046875
# corrects: 251.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9863
# TRAIN EPOCH corrects: 5476.000000 | total: 5552.000000
# val Loss : 0.0007
# val Acc : 0.9806
# VAL EPOCH corrects: 605.000000 | total: 617.000000
# Epoch 4/99
# ----------
# Iter :  0
# running_loss :  0.00037456414429470897
# running_acc  :  0.9765625
# corrects: 250.000000 | total: 256.000000
# train Loss : 0.0002
# train Acc : 0.9883
# TRAIN EPOCH corrects: 5487.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 5/99
# ----------
# Iter :  0
# running_loss :  8.993189840111881e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9912
# TRAIN EPOCH corrects: 5503.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0003
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 6/99
# ----------
# Iter :  0
# running_loss :  0.00013110294821672142
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9926
# TRAIN EPOCH corrects: 5511.000000 | total: 5552.000000
# val Loss : 0.0004
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 7/99
# ----------
# Iter :  0
# running_loss :  0.00014747031673323363
# running_acc  :  0.9921875
# corrects: 254.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9932
# TRAIN EPOCH corrects: 5514.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0003
# val Acc : 0.9822
# VAL EPOCH corrects: 606.000000 | total: 617.000000
# Epoch 8/99
# ----------
# Iter :  0
# running_loss :  0.0001500173530075699
# running_acc  :  0.98828125
# corrects: 253.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9935
# TRAIN EPOCH corrects: 5516.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9838
# VAL EPOCH corrects: 607.000000 | total: 617.000000
# Epoch 9/99
# ----------
# Iter :  0
# running_loss :  5.375598993850872e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9935
# TRAIN EPOCH corrects: 5516.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 10/99
# ----------
# Iter :  0
# running_loss :  7.575747440569103e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9959
# TRAIN EPOCH corrects: 5529.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 11/99
# ----------
# Iter :  0
# running_loss :  3.734180427272804e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0001
# train Acc : 0.9968
# TRAIN EPOCH corrects: 5534.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 12/99
# ----------
# Iter :  0
# running_loss :  4.672848808695562e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9969
# TRAIN EPOCH corrects: 5535.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 13/99
# ----------
# Iter :  0
# running_loss :  2.4710516299819574e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9977
# TRAIN EPOCH corrects: 5539.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 14/99
# ----------
# Iter :  0
# running_loss :  1.878587318060454e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5541.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 15/99
# ----------
# Iter :  0
# running_loss :  9.119715286942665e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9984
# TRAIN EPOCH corrects: 5543.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 16/99
# ----------
# Iter :  0
# running_loss :  2.7504480385687202e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 17/99
# ----------
# Iter :  0
# running_loss :  1.7597507394384593e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9986
# TRAIN EPOCH corrects: 5544.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 18/99
# ----------
# Iter :  0
# running_loss :  2.9782326237182133e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9986
# TRAIN EPOCH corrects: 5544.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 19/99
# ----------
# Iter :  0
# running_loss :  5.329091891326243e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9980
# TRAIN EPOCH corrects: 5541.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 20/99
# ----------
# Iter :  0
# running_loss :  8.918975254346151e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 21/99
# ----------
# Iter :  0
# running_loss :  3.379905319889076e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 22/99
# ----------
# Iter :  0
# running_loss :  1.445895031793043e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 23/99
# ----------
# Iter :  0
# running_loss :  1.6829122614581138e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9986
# TRAIN EPOCH corrects: 5544.000000 | total: 5552.000000
# Saving best model weights...
# Saved best weights.
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 24/99
# ----------
# Iter :  0
# running_loss :  5.8160048865829594e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9987
# TRAIN EPOCH corrects: 5545.000000 | total: 5552.000000
# val Loss : 0.0008
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 25/99
# ----------
# Iter :  0
# running_loss :  1.1299124707875308e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5548.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 26/99
# ----------
# Iter :  0
# running_loss :  1.0297525477653835e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 27/99
# ----------
# Iter :  0
# running_loss :  4.949361482431414e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 28/99
# ----------
# Iter :  0
# running_loss :  2.4801358449622057e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5550.000000 | total: 5552.000000
# val Loss : 0.0005
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 29/99
# ----------
# Iter :  0
# running_loss :  8.329494448844343e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0003
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 30/99
# ----------
# Iter :  0
# running_loss :  1.6156112906173803e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5552.000000 | total: 5552.000000
# val Loss : 0.0008
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 31/99
# ----------
# Iter :  0
# running_loss :  2.6616874038154492e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5549.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9919
# VAL EPOCH corrects: 612.000000 | total: 617.000000
# Epoch 32/99
# ----------
# Iter :  0
# running_loss :  9.374305591336451e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0006
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 33/99
# ----------
# Iter :  0
# running_loss :  3.884198122250382e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5551.000000 | total: 5552.000000
# val Loss : 0.0009
# val Acc : 0.9903
# VAL EPOCH corrects: 611.000000 | total: 617.000000
# Epoch 34/99
# ----------
# Iter :  0
# ...
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5550.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 52/99
# ----------
# Iter :  0
# running_loss :  5.142078407516237e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 53/99
# ----------
# Iter :  0
# running_loss :  6.010669949318981e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5550.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 54/99
# ----------
# Iter :  0
# running_loss :  1.7903533944263472e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9993
# TRAIN EPOCH corrects: 5549.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 55/99
# ----------
# Iter :  0
# running_loss :  2.781693183351308e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0004
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 56/99
# ----------
# Iter :  0
# running_loss :  1.132834586314857e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 57/99
# ----------
# Iter :  0
# running_loss :  5.110663551022299e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 58/99
# ----------
# Iter :  0
# running_loss :  3.061878032895038e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 59/99
# ----------
# Iter :  0
# running_loss :  2.8937909519299865e-05
# running_acc  :  0.99609375
# corrects: 255.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 60/99
# ----------
# Iter :  0
# running_loss :  2.873014636861626e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9995
# TRAIN EPOCH corrects: 5550.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 61/99
# ----------
# Iter :  0
# running_loss :  7.156311880862631e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 62/99
# ----------
# Iter :  0
# running_loss :  3.6275064303481486e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 63/99
# ----------
# Iter :  0
# running_loss :  2.4301459689013427e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 64/99
# ----------
# Iter :  0
# running_loss :  3.477925474726362e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 65/99
# ----------
# Iter :  0
# running_loss :  4.682014150603209e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0004
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 66/99
# ----------
# Iter :  0
# running_loss :  1.8935193111246917e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 67/99
# ----------
# Iter :  0
# running_loss :  3.4756521927192807e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 68/99
# ----------
# Iter :  0
# running_loss :  3.658432206066209e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 69/99
# ----------
# Iter :  0
# running_loss :  9.784362191567197e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0008
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 70/99
# ----------
# Iter :  0
# running_loss :  2.2806816559750587e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 71/99
# ----------
# Iter :  0
# running_loss :  5.6350081649725325e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 72/99
# ----------
# Iter :  0
# running_loss :  1.6111418972286629e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 73/99
# ----------
# Iter :  0
# running_loss :  3.5422540349827614e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0007
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 74/99
# ----------
# Iter :  0
# running_loss :  2.0549089185806224e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0010
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 75/99
# ----------
# Iter :  0
# running_loss :  1.4400534382730257e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0008
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 76/99
# ----------
# Iter :  0
# running_loss :  1.6586552646913333e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 77/99
# ----------
# Iter :  0
# running_loss :  1.9630431324912934e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 78/99
# ----------
# Iter :  0
# running_loss :  1.966928948604618e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 79/99
# ----------
# Iter :  0
# running_loss :  1.4005692037244444e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 80/99
# ----------
# Iter :  0
# running_loss :  2.1243472474452574e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 81/99
# ----------
# Iter :  0
# running_loss :  1.4312162420537788e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0006
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 82/99
# ----------
# Iter :  0
# running_loss :  2.0840302568103652e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 83/99
# ----------
# Iter :  0
# running_loss :  1.7607018889975734e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 84/99
# ----------
# Iter :  0
# running_loss :  5.556889391300501e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0008
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 85/99
# ----------
# Iter :  0
# running_loss :  1.852843183769437e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 86/99
# ----------
# Iter :  0
# running_loss :  1.1856203627758077e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 87/99
# ----------
# Iter :  0
# running_loss :  7.997130637704686e-07
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 88/99
# ----------
# Iter :  0
# running_loss :  5.847745796927484e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 89/99
# ----------
# Iter :  0
# running_loss :  3.1357426450995263e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 90/99
# ----------
# Iter :  0
# running_loss :  3.8131749988679076e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 91/99
# ----------
# Iter :  0
# running_loss :  1.5362751355496584e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0010
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 92/99
# ----------
# Iter :  0
# running_loss :  1.096073219741811e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9887
# VAL EPOCH corrects: 610.000000 | total: 617.000000
# Epoch 93/99
# ----------
# Iter :  0
# running_loss :  2.7031960598833393e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9996
# TRAIN EPOCH corrects: 5551.000000 | total: 5553.000000
# val Loss : 0.0009
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 94/99
# ----------
# Iter :  0
# running_loss :  5.384262749430491e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 95/99
# ----------
# Iter :  0
# running_loss :  1.310121933784103e-05
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0008
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 96/99
# ----------
# Iter :  0
# running_loss :  3.5431046399025945e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 97/99
# ----------
# Iter :  0
# running_loss :  2.8747112992277835e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0003
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Epoch 98/99
# ----------
# Iter :  0
# running_loss :  1.3771199292023084e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 1.0000
# TRAIN EPOCH corrects: 5553.000000 | total: 5553.000000
# val Loss : 0.0004
# val Acc : 0.9870
# VAL EPOCH corrects: 609.000000 | total: 617.000000
# Epoch 99/99
# ----------
# Iter :  0
# running_loss :  3.4309525744902203e-06
# running_acc  :  1.0
# corrects: 256.000000 | total: 256.000000
# train Loss : 0.0000
# train Acc : 0.9998
# TRAIN EPOCH corrects: 5552.000000 | total: 5553.000000
# val Loss : 0.0005
# val Acc : 0.9854
# VAL EPOCH corrects: 608.000000 | total: 617.000000
# Training complete.
#
# Evaluating model.
# EVAL LOSS:  0.04346479165057341
# EVAL ACC :  0.9897959183673469
# Predictions | Labels
# [[0 0]
#  [2 2]
#  [1 1]
#  [3 3]
#  [3 3]
#  [3 3]
#  [4 4]
#  [5 5]
#  [3 3]
#  [3 3]
#  [3 3]
#  [2 2]
#  [8 8]
#  [3 3]
#  [2 2]]
# No CUDA device found.
# Computations will be performed on the CPU.
# Add a CUDA compute device to improve speed dramatically.
#
# Loaded model predicting 14 classes from 2000 features
# ['acinar' 'activated_stellate' 'alpha' 'beta' 'delta' 'ductal'
#  'endothelial' 'epsilon' 'gamma' 'macrophage' 'mast' 'quiescent_stellate'
#  'schwann' 't_cell']
# Building a classification matrix...
# Gene names match exactly, returning input.
# Predicting cell types...
# Finding cell types: 100%|██████████| 2/2 [00:00<00:00, 42.67it/s]
# Extracting model embeddings...

# %%
# Save results
results.to_csv('results/scNym_hvgs_output.csv', index=True)

# %%
# Extract the unique labels
unique_labels1 = np.unique(results.true_label)
unique_labels2 = np.unique(results.pred)
unique_labels = np.unique(np.concatenate([unique_labels1,unique_labels2]))

# Convert string labels to numerical labels
label_encoder_temp = LabelEncoder()
label_encoder_temp.fit(unique_labels)
y_true = label_encoder_temp.transform(results.true_label)
y_pred = label_encoder_temp.transform(results.pred)

# Calculate accuracy
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9894970241568445
